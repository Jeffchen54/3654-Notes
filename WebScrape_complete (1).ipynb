# %% [markdown]
# # Web Scraping
# by Chris North, Virginia Tech
#
# Topics: Fetch, Parse, and Crawl web pages with Requests and BeautifulSoup

# %% [markdown]
# ## Data on the web
#
# * What data on the web might be useful for analysis?
#     * https://www.yelp.com/search?find_desc=Restaurants&find_loc=Blacksburg%2C+VA+24060&ns=1&sortby=rating
#     * https://www.amazon.com/Hutzler-571-Banana-Slicer/product-reviews/B0047E0EII
#     * https://twitter.com/search?f=tweets&q=march%20madness
#     * ?
# * Vast opportunity space for data science empowerment
#     * https://www.softwarefindr.com/how-many-websites-are-there/
# ![Websites](https://saasscout.com/wp-content/uploads/Total-number-of-Websites.png)
#
#
# ## How web publishing works
#
# * Web publishing process
#     * **Data** &rarr; (server side scripts) &rarr; HTML &rarr; (browser) &rarr; Visual page
# ![Web data](http://i2.sitepoint.com/graphics/1733_first_principles.thumb.jpg)
#
# * HTML5 DOM: Document Object Model
#     * https://en.wikipedia.org/wiki/Document_Object_Model
#     * https://www.w3schools.com/js/js_htmldom.asp
#     * Browser developer menu, view page source, inspector
#         * designed to specify the document structure and page layout
#         * tags
# ![DOM](https://upload.wikimedia.org/wikipedia/commons/5/5a/DOM-model.svg)
#
#
# ## How to get the data?
#
# * Download
#     * https://www.kaggle.com
# * Web DB APIs
#     * REST https://en.wikipedia.org/wiki/Representational_state_transfer
#     * Twitter API
#         * https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets
#         * http://socialmedia-class.org/twittertutorial.html
#         * Twint: https://github.com/twintproject/twint
#     * Spotify API:  https://developer.spotify.com/documentation/web-api/
# * **Scraping**
#     * but Web pages are designed for human consumption

# %% [markdown]
# ## How web scraping works
#
# * Web scraping process:  Fetch, Parse, Crawl
#     * URL &rarr; ([Fetch](#1.-Fetch)) &rarr; HTML &rarr; ([Parse](#2.-Parse)) &rarr; **Data** &rarr; ([Crawl](#3.-Crawl)) &rarr; URL &rarr; ...
# * Need to algorithmically parse HTML DOM structure
#     * Search the DOM for unique tags
#     * Navigate the DOM tree structure
# * Common parsing patterns of page&rarr;data
#     * Page ==> Data row : e.g. product page
#     * Page ==> k data rows : e.g. paginated search result list
#     * Page ==> Data column :  e.g. index page, list
# * Cautions:
#     * Getting blocked by the server
#     * Human activity or cyber attack?
#     * Retrieved page might not look the same as in browser, due to JavaScript
# * Ethical concerns?
#     * Does the provider allow scraping?
#     * Are there commercial restrictions?
#     * Intellectual property?
#     * Will rapid crawling harm the site (eg. denial of service attack)?
#     * Privacy issues?  Personal identifying information?

# %% [markdown]
# ### 1. Fetch
#
# Python "Requests" library
# * http://requests.readthedocs.io/en/latest/user/quickstart/
# * Browser user agent:  https://www.whatismybrowser.com/detect/what-is-my-user-agent
# * Other libraries:
#     * Selenium:  https://pypi.python.org/pypi/selenium
#
# Example:  Yelp review of restaurants near blacksburg
# https://www.yelp.com/search?find_desc=Restaurants&find_loc=Blacksburg%2C+VA+24060&ns=1&sortby=rating

# %%
### Example:  Yelp reviews
import requests

# %%
url = "https://www.yelp.com/search?find_desc=Restaurants&find_loc=Blacksburg%2C+VA+24060&ns=1&sortby=rating"
page = requests.get(url)

# %%
page.reason
# Out:
# 'OK'

# %%
page.text
# Out:
# '<!DOCTYPE html><html lang="en-US" prefix="og: http://ogp.me/ns#" style="margin: 0;padding: 0; border: 0; font-size: 100%; font: inherit; vertical-align: baseline;"><head><script>document.documentElement.className=document.documentElement.className.replace(/\x08no-js\x08/,"js");</script><meta http-equiv="Content-Type" content="text/html; charset=UTF-8" /><meta http-equiv="Content-Language" content="en-US" /><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"><link rel="mask-icon" sizes="any" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b2bb2fb0ec9c/assets/img/logos/yelp_burst.svg" content="#FF1A1A"><link rel="shortcut icon" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b05852393ae5/assets/img/logos/favicon.ico"><script> window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;window.ygaPageStartTime=new Date().getTime();</script><script>\n            window.yelp = window.yelp || {};\n            window.yelp.cookieTypePreferencesHeader = \'["ANALYTICS","FUNCTIONAL","INTERNAL","STRICTLY_NECESSARY","TARGETING"]\';\n\n            function addCookieManagementScript() {\n                var tag = document.createElement(\'script\');\n                tag.async = true;\n                tag.src = \'https://cdn.cookielaw.org/scripttemplates/otSDKStub.js\';\n                tag.type = \'text/javascript\';\n                tag.charset = \'UTF-8\';\n                tag.setAttribute(\'data-domain-script\', \'5fbcd417-fbc1-4fcc-abad-f622f1bba72d\');\n                tag.setAttribute(\'data-document-language\', \'true\');\n\n                document.head.appendChild(tag);\n            }\n\n            if (\'requestIdleCallback\' in window) {\n                requestIdleCallback(addCookieManagementScript, { timeout: 4000 });\n            } else {\n                setTimeout(addCookieManagementScript, 2000);\n            }\n        </script><script async src="https://www.google-analytics.com/analytics.js"></script><meta id="emotion-container"><style data-emotion-css="0 xl0fej ymzf9m ux5mu6 1fygppl 9vivtc 1sb02f4 19sk4h4 qgunke chan6m fohjg7 k04tcy 4mfze4 gutk1c 8f83st 1m051bw 1nrzw89 oxqmph 11pkcdj 6a0jil 1udg11w 79elbk 8dlaw4 xlzvdl ije6j5 1agk4wl 1egxyvc dzq7l1 epvm6 q7yb35 dc6bdr 11bijt4 1v994a0 16lklrv 1wayfxy 1um3nx 4kbcid lcqz66 1oibaro 1italjr 1enow5j m5kq4v foyide 1lx34my 144i0wq 1kq79li 13zsxt e29med dew2bp 1w0hvwb 1sie4w0 ul2hjm 1lnf5f9 2sacua 1keukgz ralh0w yyr98k 1jac6c2 cv1jz2 ddqa90 aurft1 12i50in sw4sjz fksa8h n65gq3 147xtl9 jb5mb6">html,body,div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,address,big,cite,code,del,dfn,em,img,ins,kbd,q,s,samp,small,strike,strong,sub,sup,tt,var,b,u,i,center,dl,dt,dd,ol,ul,li,fieldset,form,label,legend,table,caption,tbody,tfoot,thead,tr,th,td,article,aside,canvas,details,embed,figure,figcaption,footer,header,hgroup,menu,nav,output,ruby,section,summary,time,mark,audio,video{margin:0;padding:0;border:0;font-size:100%;font:inherit;vertical-align:baseline;}article,aside,details,figcaption,figure,footer,header,hgroup,menu,nav,section{display:block;}body{line-height:1;}ol,ul{list-style:none;}blockquote,q{quotes:none;}blockquote:before,blockquote:after,q:before,q:after{content:\'\';content:none;}table{border-collapse:collapse;border-spacing:0;}.hidden-non-responsive-inline,.hidden-non-responsive-inline-block,.hidden-non-responsive-block,.hidden-non-responsive-table-cell{display:none !important;}@media only screen and (max-width:600px){.responsive .responsive-small-display-inline-block{display:inline-block !important;}.responsive .responsive-small-display-block{display:block !important;}.responsive .responsive-small-display-inline{display:inline !important;}}@media only screen and (max-width:780px){.responsive-biz .responsive-small-display-inline-block{display:inline-block !important;}.responsive-biz .responsive-small-display-block{display:block !important;}.responsive-biz  ...

# %%
open('page.html', 'w').write(page.text)
# Out:
# 405099

# %% [markdown]
# ### 2. Parse
#
# Python "BeautifulSoup4" library
# * https://www.crummy.com/software/BeautifulSoup/
# * https://www.crummy.com/software/BeautifulSoup/bs4/doc/
# * "html5lib", and "lxml" also useful for parsing
#
# HTML5 DOM structure:
# * https://www.w3.org/TR/WD-DOM/introduction.html
# * https://html.spec.whatwg.org (section 4: The elements of HTML)
# * Browser's Developer Tools, Inspect Element
#
# Two strategies to parse HTML DOM:
# 1. Search for unique tag attributes (class, id, …)
# 2. Navigate DOM tree structure, top down

# %%
### Put page content into BeautifulSoup for easy parsing
import bs4

# %%
soup = bs4.BeautifulSoup(page.text, 'html5lib')

# %% [markdown]
# #### 2.1 Search
#
# Use browser "Inspect Element" feature to examine the objects you want to extract.
# Look for unique identifiers.  Then search for those uniquie identifiers in soup:
#
# `tag = soup.find('tag', {dictionary of identifiers})`
#
# `tags = soup.find_all('tag', {dictionary of identifiers})`

# %%
## Example: Find the restaurant names

tags = soup.find_all('a', {"class": "css-1m051bw", "rel": "noopener"})
tags
# Out:
# [<a class="css-1m051bw" href="/biz/taqueria-el-paso-christiansburg?osq=Restaurants" name="Taqueria el Paso" rel="noopener" target="_blank">Taqueria el Paso</a>,
#  <a class="css-1m051bw" href="/biz/the-blacksburg-tavern-blacksburg?osq=Restaurants" name="The Blacksburg Tavern" rel="noopener" target="_blank">The Blacksburg Tavern</a>,
#  <a class="css-1m051bw" href="/biz/cabo-fish-taco-blacksburg?osq=Restaurants" name="Cabo Fish Taco" rel="noopener" target="_blank">Cabo Fish Taco</a>,
#  <a class="css-1m051bw" href="/biz/gaucho-brazilian-grille-blacksburg-2?osq=Restaurants" name="Gaucho Brazilian Grille" rel="noopener" target="_blank">Gaucho Brazilian Grille</a>,
#  <a class="css-1m051bw" href="/biz/blacksburg-wine-lab-blacksburg?osq=Restaurants" name="Blacksburg Wine Lab" rel="noopener" target="_blank">Blacksburg Wine Lab</a>,
#  <a class="css-1m051bw" href="/biz/spicity-blacksburg?osq=Restaurants" name="Spicity" rel="noopener" target="_blank">Spicity</a>,
#  <a class="css-1m051bw" href="/biz/joes-diner-blacksburg?osq=Restaurants" name="Joe’s Diner" rel="noopener" target="_blank">Joe’s Diner</a>,
#  <a class="css-1m051bw" href="/biz/our-daily-bread-bakery-and-bistro-blacksburg-2?osq=Restaurants" name="Our Daily Bread Bakery and Bistro" rel="noopener" target="_blank">Our Daily Bread Bakery and Bistro</a>,
#  <a class="css-1m051bw" href="/biz/avellinos-blacksburg?osq=Restaurants" name="Avellinos" rel="noopener" target="_blank">Avellinos</a>,
#  <a class="css-1m051bw" href="/biz/benny-marzanos-blacksburg?osq=Restaurants" name="Benny Marzano’s" rel="noopener" target="_blank">Benny Marzano’s</a>]

# %%
tags[0].text
# Out:
# 'Taqueria el Paso'

# %%
tags[0]['name']
# Out:
# 'Taqueria el Paso'

# %%
names = [t.text for t in tags]
names
# Out:
# ['Taqueria el Paso',
#  'The Blacksburg Tavern',
#  'Cabo Fish Taco',
#  'Gaucho Brazilian Grille',
#  'Blacksburg Wine Lab',
#  'Spicity',
#  'Joe’s Diner',
#  'Our Daily Bread Bakery and Bistro',
#  'Avellinos',
#  'Benny Marzano’s']

# %% [markdown]
# #### 2.2 Navigate
#
# What if we didn't have unique class names to search for?
#
# Use browser DOM viewer to navigate the DOM hierarchy, navigate from Top down to desired target element. Recreate the navigation pattern in code.  Or, Find the closest enclosing unique tag to search for, then navigate down from there.
# Navigate tag children using:
#
# `childtag = tag.contents[childnumber]`

# %%
## Example:  Navigate from the restaurant name to the restaraunt review counts
parent = tags[0].parent.parent.parent.parent.parent.parent

# %%
parent.contents[1]
# Out:
# <div class="border-color--default__09f24__NPAKY"><div aria-hidden="false" class="display--inline-block__09f24__fEDiJ border-color--default__09f24__NPAKY"><div class="border-color--default__09f24__NPAKY"><div class="display--inline-block__09f24__fEDiJ margin-t0-5__09f24__gboxT border-color--default__09f24__NPAKY"><div class="display--inline-block__09f24__fEDiJ margin-r1__09f24__rN_ga border-color--default__09f24__NPAKY"><span class="display--inline__09f24__c6N_k border-color--default__09f24__NPAKY"><div aria-label="5 star rating" class="five-stars__09f24__mBKym five-stars--regular__09f24__DgBNj display--inline-block__09f24__fEDiJ border-color--default__09f24__NPAKY" role="img"><div class="star__09f24__YoVH5 star--regular__09f24__IopbI display--inline-block__09f24__fEDiJ border-color--default__09f24__NPAKY"><svg height="20" viewBox="0 0 20 20" width="20"><path d="M0 4C0 1.79086 1.79086 0 4 0H10V20H4C1.79086 20 0 18.2091 0 16V4Z" fill="rgba(251,67,60,1)" opacity="1"></path><path d="M20 4C20 1.79086 18.2091 0 16 0H10V20H16C18.2091 20 20 18.2091 20 16V4Z" fill="rgba(251,67,60,1)" opacity="1"></path><path clip-rule="evenodd" d="M10 13.3736L12.5949 14.7111C12.7378 14.7848 12.9006 14.8106 13.0593 14.7847C13.4681 14.718 13.7454 14.3325 13.6787 13.9237L13.2085 11.0425L15.2824 8.98796C15.3967 8.8748 15.4715 8.72792 15.4959 8.569C15.5588 8.15958 15.2779 7.77672 14.8685 7.71384L11.983 7.2707L10.6699 4.66338C10.5975 4.51978 10.481 4.40322 10.3374 4.33089C9.96742 4.14458 9.51648 4.29344 9.33017 4.66338L8.01705 7.2707L5.13157 7.71384C4.97265 7.73825 4.82577 7.81309 4.71261 7.92731C4.42109 8.22158 4.42332 8.69645 4.71759 8.98796L6.79152 11.0425L6.32131 13.9237C6.29541 14.0824 6.3212 14.2452 6.39486 14.3881C6.58464 14.7563 7.03696 14.9009 7.40514 14.7111L10 13.3736Z" fill="white" fill-rule="evenodd"></path></svg></div><div class="star__09f24__YoVH5 star--regular__09f24__IopbI display--inline-block__09f24__fEDiJ border-color--default__09f24__NPAKY"><svg height="20" viewBox="0 0 20 20" width="20"><path d="M0 4C0 1.79086 1.79086 0 4 0H10V20H4C1.79086 20 0 18.2091 0 16V4Z" fill="rgba(251,67,60,1)" opacity="1"></path><path d="M20 4C20 1.79086 18.2091 0 16 0H10V20H16C18.2091 20 20 18.2091 20 16V4Z" fill="rgba(251,67,60,1)" opacity="1"></path><path clip-rule="evenodd" d="M10 13.3736L12.5949 14.7111C12.7378 14.7848 12.9006 14.8106 13.0593 14.7847C13.4681 14.718 13.7454 14.3325 13.6787 13.9237L13.2085 11.0425L15.2824 8.98796C15.3967 8.8748 15.4715 8.72792 15.4959 8.569C15.5588 8.15958 15.2779 7.77672 14.8685 7.71384L11.983 7.2707L10.6699 4.66338C10.5975 4.51978 10.481 4.40322 10.3374 4.33089C9.96742 4.14458 9.51648 4.29344 9.33017 4.66338L8.01705 7.2707L5.13157 7.71384C4.97265 7.73825 4.82577 7.81309 4.71261 7.92731C4.42109 8.22158 4.42332 8.69645 4.71759 8.98796L6.79152 11.0425L6.32131 13.9237C6.29541 14.0824 6.3212 14.2452 6.39486 14.3881C6.58464 14.7563 7.03696 14.9009 7.40514 14.7111L10 13.3736Z" fill="white" fill-rule="evenodd"></path></svg></div><div class="star__09f24__YoVH5 star--regular__09f24__IopbI display--inline-block__09f24__fEDiJ border-color--default__09f24__NPAKY"><svg height="20" viewBox="0 0 20 20" width="20"><path d="M0 4C0 1.79086 1.79086 0 4 0H10V20H4C1.79086 20 0 18.2091 0 16V4Z" fill="rgba(251,67,60,1)" opacity="1"></path><path d="M20 4C20 1.79086 18.2091 0 16 0H10V20H16C18.2091 20 20 18.2091 20 16V4Z" fill="rgba(251,67,60,1)" opacity="1"></path><path clip-rule="evenodd" d="M10 13.3736L12.5949 14.7111C12.7378 14.7848 12.9006 14.8106 13.0593 14.7847C13.4681 14.718 13.7454 14.3325 13.6787 13.9237L13.2085 11.0425L15.2824 8.98796C15.3967 8.8748 15.4715 8.72792 15.4959 8.569C15.5588 8.15958 15.2779 7.77672 14.8685 7.71384L11.983 7.2707L10.6699 4.66338C10.5975 4.51978 10.481 4.40322 10.3374 4.33089C9.96742 4.14458 9.51648 4.29344 9.33017 4.66338L8.01705 7.2707L5.13157 7.71384C4.97265 7.73825 4.82577 7.81309 4.71261 7.92731C4.42109 8.22158 4.42332 8.69645 4.71759 8.98796L6.79152 11.0425L6.32131 13.9237C6.29541 14.0824 6.3212 14.2452 6.3 ...

# %%
parent.contents[1].text
# Out:
# '75'

# %%
rcs = [int((t.parent.parent.parent.parent.parent.parent).contents[1].text) for t in tags]
rcs
# Out:
# [75, 151, 560, 163, 53, 134, 100, 221, 110, 152]

# %%
## Example:  Navigate from the restaurant name to the restaraunt star rating

# %% [markdown]
# #### 2.3 Scraping multiple data fields into a DataFrame

# %%
import pandas

pandas.DataFrame(zip(names, rcs))
# Out:
#                                    0    1
# 0                   Taqueria el Paso   75
# 1              The Blacksburg Tavern  151
# 2                     Cabo Fish Taco  560
# 3            Gaucho Brazilian Grille  163
# 4                Blacksburg Wine Lab   53
# 5                            Spicity  134
# 6                        Joe’s Diner  100
# 7  Our Daily Bread Bakery and Bistro  221
# 8                          Avellinos  110
# 9                    Benny Marzano’s  152

# %% [markdown]
# ### 3. Crawl
#
# * Scrape many pages
# * use parsed hyperlinks on an index page to scrape more pages
# * or use URL query string
# * common patterns:
#     * results list, n rows on 1 page
#     * paginated result lists, k rows per page, n/k pages
#     * index page + n detail pages, 1 row per page

# %%
## Example: crawl to each restaurant's review page
url = "https://www.yelp.com/search?find_desc=Restaurants&find_loc=Blacksburg%2C+VA+24060&ns=1&sortby=rating&start="
urli = url + str(40)
urli
# Out:
# 'https://www.yelp.com/search?find_desc=Restaurants&find_loc=Blacksburg%2C+VA+24060&ns=1&sortby=rating&start=40'

# %%
## Exercise: crawl paginated lists: restaurants 1-10, 11-20, 21,30, ...

pages = [requests.get(url + str(i*10)) for i in range(5)]
pages
# Out:
# [<Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>]

# %%
pages[0].text
# Out:
# '<!DOCTYPE html><html lang="en-US" prefix="og: http://ogp.me/ns#" style="margin: 0;padding: 0; border: 0; font-size: 100%; font: inherit; vertical-align: baseline;"><head><script>document.documentElement.className=document.documentElement.className.replace(/\x08no-js\x08/,"js");</script><meta http-equiv="Content-Type" content="text/html; charset=UTF-8" /><meta http-equiv="Content-Language" content="en-US" /><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"><link rel="mask-icon" sizes="any" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b2bb2fb0ec9c/assets/img/logos/yelp_burst.svg" content="#FF1A1A"><link rel="shortcut icon" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b05852393ae5/assets/img/logos/favicon.ico"><script> window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;window.ygaPageStartTime=new Date().getTime();</script><script>\n            window.yelp = window.yelp || {};\n            window.yelp.cookieTypePreferencesHeader = \'["ANALYTICS","FUNCTIONAL","INTERNAL","STRICTLY_NECESSARY","TARGETING"]\';\n\n            function addCookieManagementScript() {\n                var tag = document.createElement(\'script\');\n                tag.async = true;\n                tag.src = \'https://cdn.cookielaw.org/scripttemplates/otSDKStub.js\';\n                tag.type = \'text/javascript\';\n                tag.charset = \'UTF-8\';\n                tag.setAttribute(\'data-domain-script\', \'5fbcd417-fbc1-4fcc-abad-f622f1bba72d\');\n                tag.setAttribute(\'data-document-language\', \'true\');\n\n                document.head.appendChild(tag);\n            }\n\n            if (\'requestIdleCallback\' in window) {\n                requestIdleCallback(addCookieManagementScript, { timeout: 4000 });\n            } else {\n                setTimeout(addCookieManagementScript, 2000);\n            }\n        </script><script async src="https://www.google-analytics.com/analytics.js"></script><meta id="emotion-container"><style data-emotion-css="0 xl0fej ymzf9m ux5mu6 1fygppl 9vivtc 1sb02f4 19sk4h4 qgunke chan6m fohjg7 k04tcy 4mfze4 gutk1c 8f83st 1m051bw 1nrzw89 oxqmph 11pkcdj 6a0jil 1udg11w 79elbk 8dlaw4 xlzvdl ije6j5 1agk4wl 1egxyvc dzq7l1 epvm6 q7yb35 dc6bdr 11bijt4 1v994a0 16lklrv 1wayfxy 1um3nx 4kbcid lcqz66 1oibaro 1italjr 1enow5j m5kq4v foyide 1lx34my 144i0wq 1kq79li 13zsxt e29med dew2bp 1w0hvwb 1sie4w0 ul2hjm 1lnf5f9 2sacua 1keukgz ralh0w yyr98k 1jac6c2 cv1jz2 ddqa90 aurft1 12i50in sw4sjz fksa8h n65gq3 147xtl9 jb5mb6">html,body,div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,address,big,cite,code,del,dfn,em,img,ins,kbd,q,s,samp,small,strike,strong,sub,sup,tt,var,b,u,i,center,dl,dt,dd,ol,ul,li,fieldset,form,label,legend,table,caption,tbody,tfoot,thead,tr,th,td,article,aside,canvas,details,embed,figure,figcaption,footer,header,hgroup,menu,nav,output,ruby,section,summary,time,mark,audio,video{margin:0;padding:0;border:0;font-size:100%;font:inherit;vertical-align:baseline;}article,aside,details,figcaption,figure,footer,header,hgroup,menu,nav,section{display:block;}body{line-height:1;}ol,ul{list-style:none;}blockquote,q{quotes:none;}blockquote:before,blockquote:after,q:before,q:after{content:\'\';content:none;}table{border-collapse:collapse;border-spacing:0;}.hidden-non-responsive-inline,.hidden-non-responsive-inline-block,.hidden-non-responsive-block,.hidden-non-responsive-table-cell{display:none !important;}@media only screen and (max-width:600px){.responsive .responsive-small-display-inline-block{display:inline-block !important;}.responsive .responsive-small-display-block{display:block !important;}.responsive .responsive-small-display-inline{display:inline !important;}}@media only screen and (max-width:780px){.responsive-biz .responsive-small-display-inline-block{display:inline-block !important;}.responsive-biz .responsive-small-display-block{display:block !important;}.responsive-biz  ...

# %%
soups = [bs4.BeautifulSoup(page.text, 'html5lib') for page in pages]
soups
# Out:
# [<!DOCTYPE html>
# /,"js");</script><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="en-US" http-equiv="Content-Language"/><meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/><link content="#FF1A1A" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b2bb2fb0ec9c/assets/img/logos/yelp_burst.svg" rel="mask-icon" sizes="any"/><link href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b05852393ae5/assets/img/logos/favicon.ico" rel="shortcut icon"/><script> window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;window.ygaPageStartTime=new Date().getTime();</script><script>
#              window.yelp = window.yelp || {};
#              window.yelp.cookieTypePreferencesHeader = '["ANALYTICS","FUNCTIONAL","INTERNAL","STRICTLY_NECESSARY","TARGETING"]';
#
#              function addCookieManagementScript() {
#                  var tag = document.createElement('script');
#                  tag.async = true;
#                  tag.src = 'https://cdn.cookielaw.org/scripttemplates/otSDKStub.js';
#                  tag.type = 'text/javascript';
#                  tag.charset = 'UTF-8';
#                  tag.setAttribute('data-domain-script', '5fbcd417-fbc1-4fcc-abad-f622f1bba72d');
#                  tag.setAttribute('data-document-language', 'true');
#
#                  document.head.appendChild(tag);
#              }
#
#              if ('requestIdleCallback' in window) {
#                  requestIdleCallback(addCookieManagementScript, { timeout: 4000 });
#              } else {
#                  setTimeout(addCookieManagementScript, 2000);
#              }
#          </script><script async="" src="https://www.google-analytics.com/analytics.js"></script><meta id="emotion-container"/><style data-emotion-css="0 xl0fej ymzf9m ux5mu6 1fygppl 9vivtc 1sb02f4 19sk4h4 qgunke chan6m fohjg7 k04tcy 4mfze4 gutk1c 8f83st 1m051bw 1nrzw89 oxqmph 11pkcdj 6a0jil 1udg11w 79elbk 8dlaw4 xlzvdl ije6j5 1agk4wl 1egxyvc dzq7l1 epvm6 q7yb35 dc6bdr 11bijt4 1v994a0 16lklrv 1wayfxy 1um3nx 4kbcid lcqz66 1oibaro 1italjr 1enow5j m5kq4v foyide 1lx34my 144i0wq 1kq79li 13zsxt e29med dew2bp 1w0hvwb 1sie4w0 ul2hjm 1lnf5f9 2sacua 1keukgz ralh0w yyr98k 1jac6c2 cv1jz2 ddqa90 aurft1 12i50in sw4sjz fksa8h n65gq3 147xtl9 jb5mb6">html,body,div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,address,big,cite,code,del,dfn,em,img,ins,kbd,q,s,samp,small,strike,strong,sub,sup,tt,var,b,u,i,center,dl,dt,dd,ol,ul,li,fieldset,form,label,legend,table,caption,tbody,tfoot,thead,tr,th,td,article,aside,canvas,details,embed,figure,figcaption,footer,header,hgroup,menu,nav,output,ruby,section,summary,time,mark,audio,video{margin:0;padding:0;border:0;font-size:100%;font:inherit;vertical-align:baseline;}article,aside,details,figcaption,figure,footer,header,hgroup,menu,nav,section{display:block;}body{line-height:1;}ol,ul{list-style:none;}blockquote,q{quotes:none;}blockquote:before,blockquote:after,q:before,q:after{content:'';content:none;}table{border-collapse:collapse;border-spacing:0;}.hidden-non-responsive-inline,.hidden-non-responsive-inline-block,.hidden-non-responsive-block,.hidden-non-responsive-table-cell{display:none !important;}@media only screen and (max-width:600px){.responsive .responsive-small-display-inline-block{display:inline-block !important;}.responsive .responsive-small-display-block{display:block !important;}.responsive .responsive-small-display-inline{display:inline !important;}}@media only screen and (max-width:780px){.responsive-biz .responsive-small-display-inline-block{display:inline-block !important;}.responsive-biz .responsive-small-display-block{display:block !important;}.responsive-biz .responsive-small-display-inline{display:inline !important;}}@media only screen and (max-width:1024px){.responsive .responsive-medium-display-inline-block{display:inline-block !important;}.responsive .responsive-medium-display-block{display:block !important;}.responsive .responsive-medium-display-inline{display:inline !important;}}@media only screen and (max-width:1240px){.responsive-biz .responsive-medium-display-inline-block{display:inline-block !important;}.responsive-biz .responsive-medium-display-block{display:block !important;}.responsive-biz .responsive-medium-display-inline{display:inline !important;}}@media only screen and (min-width:1025px){.responsive .responsive-desktop-small-display-inline-block{display:inline-block !important;}.responsive .responsive-desktop-small-display-block{display:block !important;}.responsive .responsive-desktop-small-display-inline{display:inline !important;}}@media only screen and (min-width:1241px){.responsive-biz .responsive-desktop-small-display-inline-block{display:inline-block !important;}.responsive-biz .responsive-desktop-small-display-block{display:block !important;}.responsive-biz .responsive-desktop-small-display-inline{display:inline !important;}}@media only screen and (min-width:1144px){.responsive .responsive-desktop-default-display-inline-block{display:inline-block !important;}.responsive .responsive-desktop-default-display-block{display:block !important;}.responsive .responsive-desktop-default-display-inline{display:inline !important;}}@media only screen and (min-width:1241px){.responsive-biz .responsive-desktop-default-display-inline-block{display:inline-block !important;}.responsive-biz .responsive-desktop-default-display-block{display:block !important;}.responsive-biz .responsive-desktop-default-display-inline{display:inline !important;}}.responsive .hidden-non-responsive-inline{display:inline !important;}.responsive .hidden-non-responsive-inline-bl ...
#
#      <script>
#          window.yelp = window.yelp || {};
#          window.yelp.critical_css = window.yelp.critical_css || {};
#          window.yelp.critical_css.css_map = {};
#      </script>
#      <!-- css-middleware: bootstrap placeholder --><script>(function() { window.yelp.critical_css.recordDone=function(c,l){l.onload=null;var i=window.yelp.critical_css.css_map[c];window.yelp.critical_css.css_map[c]=i&&Object.keys(i).length?i:{loaded:!1,linkTag:l}}; })()</script>
#  <meta name="critical_css_middleware"/><link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp-frontend-commons-pkg.yji-26d465377aaaceb8d450.css" rel="stylesheet"/><link as="font" crossorigin="anonymous" data-rh="true" href="https://s3-media0.fl.yelpcdn.com/assets/public/open-sans-regular.yji-aff9b80e384301f2ae0c.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" data-rh="true" href="https://s3-media0.fl.yelpcdn.com/assets/public/open-sans-semibold.yji-d3abae27d3eac73b40a5.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" data-rh="true" href="https://s3-media0.fl.yelpcdn.com/assets/public/open-sans-bold.yji-1145ff0b749fff2d31bb.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" data-rh="true" href="https://s3-media0.fl.yelpcdn.com/assets/public/poppins-bold.yji-9690ce6275ddc5645cfa.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" data-rh="true" href="https://s3-media0.fl.yelpcdn.com/assets/public/poppins-medium.yji-dc16a3592fdb61b620cc.woff2" rel="preload" type="font/woff2"/><link data-rh="true" href="https://www.yelp.com/search?find_desc=Restaurants&amp;find_loc=Blacksburg%2C+VA+24060&amp;sortby=rating&amp;start=10" rel="next"/><link data-rh="true" href="/opensearch" rel="search" title="Yelp" type="application/opensearchdescription+xml"/><link as="image" data-rh="true" href="https://s3-media0.fl.yelpcdn.com/assets/public/gray-spinner.yji-98588e3310fd5dfa96dd.gif" rel="preload"/><link data-rh="true" href="https://maps.gstatic.com" rel="preconnect"/><script data-rh="true" data-testid="gtmScript" type="text/javascript">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-THHF2RF');</script><script data-rh="true" type="application/ld+json">{"@context":"https://schema.org","@type":"Organization","name":"Yelp","url":"http://www.yelp.com","sameAs":["https://www.facebook.com/yelp","https://twitter.com/yelp","https://www.linkedin.com/company/31517","https://instagram.com/yelp"]}</script><script data-rh="true">window.pageSpeedCustomTimestamps = {};</script><script data-rh="true" type="application/ld+json">
#                      {
#                          "@context": "https://schema.org",
#                          "@type": "FAQPage",
#                          "mainEntity": [{"@type": "Question", "name": "What are the best restaurants with outdoor seating?", "acceptedAnswer": {"@type": "Answer", "text": "These are the best restaurants with outdoor seating near Blacksburg, VA:<ul><li><a href='/biz/cabo-fish-taco-blacksburg'>Cabo Fish Taco</a></li><li><a href='/biz/the-blacksburg-tavern-blacksburg'>The Blacksburg Tavern</a></li><li><a href='/biz/cellar-restaurant-blacksburg'>Cellar Restaurant</a></li><li><a href='/biz/the-black-hen-and-bar-blue-blacksburg'>The Black Hen & Bar Blue</a></li><li><a href='/biz/avellinos-blacksburg'>Avellinos</a></li></ul><p>People also liked:  <a href=/search?find_desc=restaurants+for+lunch&find_loc=Blacksburg%2C+VA+24060>restaurants for lunch</a></p>"}}, {"@type": "Question", "name": "What did people search for similar to restaurants near Blacksburg, VA 24060?", "acceptedAnswer": {"@type": "Answer", "text": "People also searched for these near Blacksburg:<ul><li><a href='/search?find_desc=takeout&find_loc=Blacksburg%2C+VA&page_src=q2q_faq_sq'>Takeout</a></li><li><a href='/search?find_desc=food&find_loc=Blacksburg%2C+VA&page_src=q2q_faq_sq'>Food</a></li><li><a href='/search?find_desc=lunch&find_loc=Blacksburg%2C+VA&page_src=q2q_faq_sq'>Lunch</a></li><li><a href='/search?find_desc=breakfast+%26+brunch&find_loc=Blacksburg%2C+VA&page_src=q2q_faq_sq'>Breakfast & Brunch</a></li><li><a href='/search?find_desc=dinner&find_loc=Blacksburg%2C+VA&page_src=q2q_faq_sq'>Dinner</a></li></ul><p><a href=/search?find_desc=restaurants&find_loc=Blacksburg%2C+VA+24060&page_src=q2q_faq_sq>See more restaurants near Blacksburg.</a></p>"}}, {"@type": "Question", "name": "What are the best restaurants for lunch?", "acceptedAnswer": {"@type": "Answer", "text": "These are the best restaurants for lunch near Blacksburg, VA:<ul><li><a href='/biz/cabo-fish-taco-blacksburg'>Cabo Fish Taco</a></li><li><a href='/biz/cellar-restaurant-blacksburg'>Cellar Restaurant</a></li><li><a href='/biz/leftys-main-street-grille-blacksburg-5'>Lefty's Main Street Grille</a></li><li><a href='/biz/due-south-bbq-christiansburg'>Due South BBQ</a></li><li><a href='/biz/himalayan-curry-cafe-blacksburg-2'>Himalayan Curry Cafe</a></li></ul><p>People also liked:  <a href=/search?find_desc=outdoor+dining+restaurants&find_loc=Blacksburg%2C+VA+24060>restaurants with outdoor seating</a></p>"}}]
#                      }
#                  </script><script data-rh="true">
#  window.__googleInit = function() {
#
#      if (window.mapInstance != null) {
#          return;
#      }
#
#      window.mapContainer = document.createElement('div');
#      window.mapContainer.style.height = '100%';
#      window.mapContainer.style.width = '100%';
#      window.mapContainer.style.visibility = 'hidden';
#
#      document.body.appendChild(window.mapContainer);
#
#
#      window.mapInstance = new google.maps.Map(
#          window.mapContainer,
#          {
#              gestureHandling: 'cooperative',
#              backgroundColor: 'rgba(229, 227, 223, 1)',
#              mapTypeId: google.maps.MapTypeId.ROADMAP,
#              controlSize: 28,
#              disableDefaultUI: true,
#              zoomControl: false,
#              zoomControlOptions: {
#                  position: google.maps.ControlPosition.TOP_LEFT,
#              },
#              styles: [
#                  {
#                      featureType: 'poi',
#                      elementType: 'labels',
#                      stylers: [{ visibility: 'off' }],
#                  },
#                  {
#                      featureType: 'administrative.neighborhood',
#                      elementType: 'labels',
#                      stylers: [{ lightness: 50 }],
#                  },
#              ],
#          }
#      );
#
#      var marker = new google.maps.Marker({
#          position: {lat: 0, lng: 0},
#          map: window.mapInstance,
#      });
#      marker.setMap(null);
#      window.mapInstance.setCenter({lat: 0, lng: 0});
#
#
#      if(window.__mapReady) {
#          window.__mapReady();
#      }
#  }
#  </script><script async="true" data-rh="true" src="//maps.googleapis.com/maps/api/js?client=gme-yelp&amp;libraries=places,visualization&amp;language=en&amp;region=US&amp;callback=__googleInit" type="text/javascript"></script><title data-rh="true">Restaurants Blacksburg, VA 24060 - Last Updated November 2022 - Yelp</title><meta content="Best Restaurants in Blacksburg, VA 24060 - Taqueria el Paso, The Blacksburg Tavern, Cabo Fish Taco, Gaucho Brazilian Grille, Blacksburg Wine Lab, Spicity, Joe's Diner, Our Daily Bread Bakery and Bistro, Avellinos, Benny Marzano's" data-rh="true" name="description"/><meta content="noindex" data-rh="true" name="robots"/><meta content="Yelp,recommendation,San Francisco, bay area, local,business,review,friend,restaurant,dentist,doctor,salon,spa,shopping,store,share,community,massage,sushi,pizza,nails,New York,Los Angeles" data-rh="true" name="keywords"/><meta content="Yelp" data-rh="true" property="og:site_name"/><meta content="website" data-rh="true" property="og:type"/><meta content="https://s3-media0.fl.yelpcdn.com/assets/srv0/seo_metadata/f9149736ad8d/assets/img/logos/yelp_og_image.png" data-rh="true" property="og:image"/><meta content="1080" data-rh="true" property="og:image:height"/><meta content="1920" data-rh="true" property="og:image:width"/><meta content="97534753161" data-rh="true" property="fb:app_id"/><meta content="Best Restaurants in Blacksburg, VA 24060 - Taqueria el Paso, The Blacksburg Tavern, Cabo Fish Taco, Gaucho Brazilian Grille, Blacksburg Wine Lab, Spicity, Joe's Diner, Our Daily Bread Bakery and Bistro, Avellinos, Benny Marzano's" data-rh="true" property="og:description"/><meta content="Restaurants Blacksburg, VA 24060 - Last Updated November 2022 - Yelp" data-rh="true" property="og:title"/><meta content="" data-rh="true" property="og:url"/><meta content="app-id=284910350, app-argument=yelp:///search?location=Blacksburg%2C%20VA%2024060&amp;terms=Restaurants&amp;utm_campaign=default&amp;utm_source=www" data-rh="true" name="apple-itunes-app"/>
#
#  <script>document.cookie = "xcj=1|_G53MHOYWJG-NOgtMbWimqE7zdAoMR_BThYe5MO7gb8; Domain=.yelp.com; expires=Wed, 01 Feb 2023 13:09:39 GMT; Max-Age=7776000; Path=/";</script><link href="/opensearch" rel="search" title="Yelp" type="application/opensearchdescription+xml"/></head><body class="" style="margin: 0; padding: 0; border: 0; font-size: 100%; font: inherit; vertical-align: baseline; line-height: 1;"><noscript></noscript><yelp-react-root><div data-hypernova-id="f595ffe5-358b-4ee5-adeb-82761b4bdec4" data-hypernova-key="yelpfrontend__53057__yelpfrontend__GondolaSearch__dynamic"><div class="" id="google_one_tap_parent" style="position:fixed;width:auto;height:auto;z-index:9999;top:20px;left:20px"></div><noscript data-testid="gtmNoscript"><iframe class="" height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-THHF2RF" style="display:none;visibility:hidden" width="0"></iframe></noscript><script>window.pageSpeedCustomTimestamps['body:start'] = (new Date()).getTime();</script><div class="alert-notice__09f24__WKrTt border-color--default__09f24__NPAKY"><iframe class="cookie-iframe-banner__09f24__GnESl" frameborder="0" scrolling="no" src="/eu_cookie_notice?responsive" style="height:0px" tabindex="-1" title="cookie notice"></iframe></div><div class="sticky-wrapper__09f24__hwFNf pageHeader__09f24__e6lW4 v2__09f24__GsUJ_ border-color--default__09f24__NPAKY background-color--white__09f24__ulvSM" data-lcp-target-id="CONSUMER_HEADER"><div class="css-fksa8h padding-t1-5__09f24__VNyRg padding-b1-5__09f24__M_AcV border-color--default__09f24__NPAKY background-color--gray-extra-light__09f24__UbDJH"><div class="a11y-menu-container__09f24__V3Frf border-color--default__09f24__NPAKY"></div></div><header class="consumer-header-container__09f24__ieW2P border--bottom__09f24___mg5X border-color--default__09f24__NPAKY background-color--white__09f24__ulvSM"><div class="consumer-header__09f24__GAvyT border-color--default__09f24__NPAKY"><div class="arrange__09f24__LDfbs vertical-align-middle__09f24__zU9sE border-color--default__09f24__NPAKY"><div class="logo-arrange-unit__09f24__Rbwi3 arrange-unit__09f24__rqHTg border-color--default__09f24__NPAKY"><div class="margin-r4__09f24__mJ91T margin-sm-r0__09f24__WfNsG border-color--default__09f24__NPAKY"><div class="logo__09f24__ip022 logo-image__09f24__SXMH_ logo-container__09f24__jaSQB border-color--default__09f24__NPAKY" data-analytics-label="logo" id="logo" style="background-image:url(https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_design_cdn/7ef71bf77a33/assets/img/brand/logo_desktop.svg)"><a class="logo-link__09f24__fS20h css-1sie4w0" href="/" role="link">Yelp</a></div></div></div><div class="search-suggest-arrange-unit__09f24__zqa_F arrange-unit__09f24__rqHTg arrange-unit-fill__09f24__CUubG border-color--default__09f24__NPAKY"><div class="search-suggest-container-outer__09f24__SUL4j border-color--default__09f24__NPAKY"><div class="search-suggest-container-inner__09f24__WsMGR border-color--default__09f24__NPAKY"><div class="arrange__09f24__LDfbs gutter-2__09f24__CCmUo border-color--default__09f24__NPAKY"><div class="arrange-unit__09f24__rqHTg arrange-unit-fill__09f24__CUubG border-color--default__09f24__NPAKY"><div class="search-suggest__09f24__Yd8a9"><div class=""><form action="/search" class="find-near-form__09f24__qHR1I" id="header_find_form" method="get" role="search"><div class="undefined arrange__09f24__LDfbs border-color--default__09f24__NPAKY"><div class="arrange-unit__09f24__rqHTg arrange-unit-fill__09f24__CUubG border-color--default__09f24__NPAKY"><div class="find-near-arrange__09f24__czL3z find-near-arrange--height__09f24__uFYD6 arrange__09f24__LDfbs layout-equal__09f24__odeM0 border-color--default__09f24__NPAKY"><div class="find-near-arrange-unit__09f24__hvHOu arrange-unit__09f24__rqHTg border-color--default__09f24__NPAKY"><label class="label__09f24__y83zE pseudo-input__09f24__nfxxT pseudo-input--find-near__09f24__o_Lff pseudo-input--find__09f24__dWbac pseudo-input__09f24__bK86t" for="sear ...
#
#  Rasta Pasta was orgasmic!!! lemon shrimp tacos are awesome!!! Just go!”<span class="css-1wayfxy" data-font-weight="semibold"> <a class="css-1um3nx" href="/biz/cabo-fish-taco-blacksburg?hrid=qh7-SBcoDVu52Vk3yLVW8Q&amp;osq=Restaurants" rel="noopener" role="link" target="_blank">more</a></span></p></div></div></div></div></div><div class="border-color--default__09f24__NPAKY"></div><div class="border-color--default__09f24__NPAKY" data-testid="services-actions-component"><div class="css-4kbcid arrange__09f24__LDfbs gutter-1__09f24__yAbCL vertical-align-middle__09f24__zU9sE border-color--default__09f24__NPAKY"><div class="arrange-unit__09f24__rqHTg arrange-unit-fill__09f24__CUubG border-color--default__09f24__NPAKY"><div class="border-color--default__09f24__NPAKY"><div aria-hidden="false" class="display--inline-block__09f24__fEDiJ border-color--default__09f24__NPAKY"><div class="border-color--default__09f24__NPAKY"><ul class="undefined list__09f24__ynIEd"><li class="border-color--default__09f24__NPAKY"><div class="border-color--default__09f24__NPAKY nowrap__09f24__lBkC2" data-testid="TRUSTED_PROPERTY"><div class="tag__09f24__mjBHZ margin-t0-5__09f24__gboxT margin-r2__09f24__XL72f border-color--default__09f24__NPAKY"><div class="icon__09f24__a1_rF margin-r0-25__09f24__zRfIA border-color--default__09f24__NPAKY"><span alt="" aria-hidden="true" class="icon--16-checkmark-v2 css-lcqz66" role="img"><svg class="icon_svg" height="16" width="16"><path d="M6.308 11.763a.748.748 0 01-.53-.22l-2.641-2.64a.75.75 0 011.06-1.061l2.11 2.11 5.496-5.495a.75.75 0 111.06 1.06l-6.025 6.026a.748.748 0 01-.53.22z"></path></svg></span></div><span class="label__09f24__hNq6C display--inline__09f24__c6N_k border-color--default__09f24__NPAKY"><p class="tagText__09f24__ArEfy iaTagText__09f24__Gv1CO css-1oibaro" data-font-weight="semibold"><span class="raw__09f24__T4Ezm">Outdoor seating</span></p></span></div><div class="tag__09f24__mjBHZ margin-t0-5__09f24__gboxT margin-r2__09f24__XL72f border-color--default__09f24__NPAKY"><div class="icon__09f24__a1_rF margin-r0-25__09f24__zRfIA border-color--default__09f24__NPAKY"><span alt="" aria-hidden="true" class="icon--16-checkmark-v2 css-lcqz66" role="img"><svg class="icon_svg" height="16" width="16"><path d="M6.308 11.763a.748.748 0 01-.53-.22l-2.641-2.64a.75.75 0 011.06-1.061l2.11 2.11 5.496-5.495a.75.75 0 111.06 1.06l-6.025 6.026a.748.748 0 01-.53.22z"></path></svg></span></div><span class="label__09f24__hNq6C display--inline__09f24__c6N_k border-color--default__09f24__NPAKY"><p class="tagText__09f24__ArEfy iaTagText__09f24__Gv1CO css-1oibaro" data-font-weight="semibold"><span class="raw__09f24__T4Ezm">Delivery</span></p></span></div><div class="tag__09f24__mjBHZ margin-t0-5__09f24__gboxT margin-r2__09f24__XL72f border-color--default__09f24__NPAKY"><div class="icon__09f24__a1_rF margin-r0-25__09f24__zRfIA border-color--default__09f24__NPAKY"><span alt="" aria-hidden="true" class="icon--16-checkmark-v2 css-lcqz66" role="img"><svg class="icon_svg" height="16" width="16"><path d="M6.308 11.763a.748.748 0 01-.53-.22l-2.641-2.64a.75.75 0 011.06-1.061l2.11 2.11 5.496-5.495a.75.75 0 111.06 1.06l-6.025 6.026a.748.748 0 01-.53.22z"></path></svg></span></div><span class="label__09f24__hNq6C display--inline__09f24__c6N_k border-color--default__09f24__NPAKY"><p class="tagText__09f24__ArEfy iaTagText__09f24__Gv1CO css-1oibaro" data-font-weight="semibold"><span class="raw__09f24__T4Ezm">Takeout</span></p></span></div></div></li></ul></div></div></div></div><div class="arrange-unit__09f24__rqHTg border-color--default__09f24__NPAKY"><div aria-hidden="false" class="dontTriggerCardClick__09f24__nH1kt border-color--default__09f24__NPAKY"><div class="border-color--default__09f24__NPAKY"><div class="border-color--default__09f24__NPAKY"><div class="border-color--default__09f24__NPAKY"><div class="border-color--default__09f24__NPAKY"><div class="border-color--default__09f24__NPAKY nowrap__09f24__lBkC2"><div class="border-color--default__0 ...
#  <script data-hypernova-id="f595ffe5-358b-4ee5-adeb-82761b4bdec4" data-hypernova-key="yelpfrontend__53057__yelpfrontend__GondolaSearch__dynamic" type="application/json"><!--{"locale":"en_US","messages":{},"requestCookies":{"LOCATION":null,"MO_MAP":null},"requestHeaders":{},"requestPath":"/search","requestUrl":"https://www.yelp.com/search?find_desc=Restaurants&amp;find_loc=Blacksburg%2C+VA+24060&amp;ns=1&amp;sortby=rating&amp;start=0","routeParams":{},"userId":null,"bizUserId":null,"uniqueRequestId":"6ba937f0ddd3efdd","site":"www","gaConfig":{"clientID":"87FC317E9EDE7675","dimensions":{"global":{"full_url":[15,"/search?find_desc=Restaurants&amp;find_loc=Blacksburg%2C+VA+24060&amp;ns=1&amp;sortby=rating&amp;start=0"],"internal_ip":[18,false],"referrer":[28,"none"]},"www":{"full_url":[34,"/search?find_desc=Restaurants&amp;find_loc=Blacksburg%2C+VA+24060&amp;ns=1&amp;sortby=rating&amp;start=0"],"internal_ip":[27,false],"referrer":[64,"none"]}},"domain":"yelp.com","enable_high_volume_events":false,"ga_enabled":true,"js_dimensions":{"global":{},"www":{}},"metrics":{"global":{},"www":{}},"trackers":{"www":"UA-30501-24","global":"UA-30501-1"},"user_id":null},"guv":"87FC317E9EDE7675","legacyProps":{"searchAppProps":{"ajaxScrollablePhotosURI":"/biz_photos/scrollable_photos/lMrF5I-apkobh_4keTYkbA%2CHX36A4N4GvA0QTdtmXv8rw%2CaURgpKldq6YKqAleHaFUtA%2CUobpwIha_v2AmnDTJFhzKQ%2CnoHwUDUAV1cnvLcB_cY3Aw%2CM5OPTpzS08HSHIxG_Q50VQ%2Cq4a9_hphM1zrmYZDi6lAcg%2CI5dFvzPt57bb9T7z0Mp-jw%2CkhdcN1oO5yj49LlnWCzMnQ%2CbsqCkCccS5LY1X5Ub75JBQ","autoEnabledAttributes":[],"experimentData":{"ax.mobile.remove_menu_icon_from_search_ads":"enabled","ax.mobile.remove_menu_photos_from_search_for_national_advertisers":"enabled","ax.www.sponsored_business_highlights":"enabled","erised_suggested_filters":"true","hot_and_new_launchpad_internal":"disabled","searchux.ios.snappy_carousels":"automatic_snaps","searchux.www.cta_consistency":"red_left_aligned_button","searchux.www.larger_photos_everywhere":"scrollable_photos","txn.www.food_delivery_or_pickup_flow_fullstory":"status_quo","yelp.search.search_suggest.model_based_delivery_pickup":"disabled","yelp.search.search_suggest.relevance_model_testing_override":"disabled","yelp.search.search_suggest.structured_suggest_filters":"disabled","yelp.search.search_suggest.structured_suggest_internal_testing":"disabled"},"searchPageProps":{"consumerHeaderProps":{"logoutCsrfToken":"6bca6958a1144bfa0c69181c677f62747cae98b257ab9c8dbd68a96b971b37a5","bizSiteURL":null,"initialSearchDisplayVal":"Restaurants","initialLocationDisplayVal":"Blacksburg, VA 24060","initialHiddenLocationInputVal":"Blacksburg, VA 24060","initialIsMapArea":false,"initialHiddenLocationInputName":"find_loc","initialIsCurrentLocation":false},"footerProps":{"localeCode":"en_US","baseUrl":"https://www.yelp.com/","attributionSource":"acxiom","currentUrl":"https://www.yelp.com//search?find_desc=Restaurants&amp;find_loc=Blacksburg%2C+VA+24060&amp;sortby=rating&amp;start=0"},"filterPanelProps":{"filterInfoMap":{"recommended":{"name":"sort","value":"recommended","text":"Recommended"},"rating":{"name":"sort","value":"rating","text":"Highest Rated","isSelected":true},"review_count":{"name":"sort","value":"review_count","text":"Most Reviewed"},"g:-80.53184509277344,37.14827672411747,-80.32722473144531,37.31229085980303":{"name":"l","value":"g:-80.53184509277344,37.14827672411747,-80.32722473144531,37.31229085980303","text":"Bird's-eye View"},"g:-80.4806900024414,37.18931370032807,-80.37837982177734,37.271320777045204":{"name":"l","value":"g:-80.4806900024414,37.18931370032807,-80.37837982177734,37.271320777045204","text":"Driving (5 mi.)"},"g:-80.45511245727539,37.20982383064024,-80.40395736694336,37.250827370108105":{"name":"l","value":"g:-80.45511245727539,37.20982383064024,-80.40395736694336,37.250827370108105","text":"Biking (2 mi.)"},"g:-80.44232368469238,37.22000845730578,-80.41674613952637,37.240510245759914":{"name":"l","value":"g:-80.44232368469238,37.22000845730578,-80.41 ...
#  <script crossorigin="anonymous" integrity="sha384-bm7MnzvK++ykSwVJ2tynSE5TRdN+xL418osEVF2DE/L/gfWHj91J2Sphe582B1Bh" src="https://s3-media0.fl.yelpcdn.com/assets/srv0/cdn_assets/64141792105e/assets/vendor/react-dom/18.2.0/umd/react-dom.production.min.js"></script>
#  <!-- css-middleware: body tag placeholder --><script>(function() { var e=window.yelp.critical_css;function t(e){setTimeout(e,0)}function n(n){for(var o in e.css_map)if(!e.css_map[o].loaded)return;t(n)}function o(t,o){var a=e.css_map[t],i=a.linkTag,r=document.querySelector('style[data-critical-css="'+t+'"]');if(r&&i&&!a.loaded){var c=function(e,t){var n=e.cloneNode();n.rel="stylesheet",n.media="all",n.href=e.href;var o=function(){this.onload=null,this.setAttribute("onload",null),t.parentNode.removeChild(t)};return n.setAttribute("onload",o),n.onload=o,n}(i,r);r.insertAdjacentElement("afterend",c),i.parentNode.removeChild(i),e.css_map[t].loaded=!0,n(o)}else n(o)}function a(n,a){if(!e.css_map||0===Object.keys(e.css_map).length)return void t(n);(a?[a]:Object.keys(e.css_map)).forEach((function(t){e.lowPriorityMode?o(t,n):setTimeout(o,0,t,n)}))}e.criticalCSSReady=function(t){const n=(o=t,function(){return o&&(r=o.apply(i||this,arguments),o=null),r});var o,i,r;a(n);var c=e.recordDone.bind(window);e.recordDone=function(e,t){c.call(this,e,t),a(n,t.dataset.criticalCss)}}; })()</script>
#  <script>
#          window.yelp = window.yelp || {};
#          window.yelp.zipkin_id = 'a70ea8f4eb50c51b';
#          window.yelp.unique_request_id = '6ba937f0ddd3efdd';
#          window.yelp.guv = '87FC317E9EDE7675';
#          window.yelp.yuv_record = 'NPM4SfAZKq3MZI-IOoFQUh0DwqxHIEmhpPQghPWGUCEc7F6tId4yc1TgZccKt1OYHvVb2k7S7UZqtjQpjAEmoN_k7As5O0dU';
#      </script>
#  <script crossorigin="anonymous" integrity="sha384-VWXV8VA+0xZuNh5mksoTGTWM4qM9gdLvcv/y/f3Ps2ZjKN37taVfpJHexdLG2bJI" src="https://s3-media0.fl.yelpcdn.com/assets/srv0/cdn_assets/4dc644e84e0b/assets/vendor/regenerator-runtime/0.13.9/regenerator-runtime.min.js"></script>
#  <script id="yelp-js-error-reporting-init-error-reporting" type="application/json">{"config": {"release": "1454d47a0513b6922dca0d85d72ee1a986cdc50a", "metaData": {"projectName": "gondola-search", "activeVersion": "5.30.57", "deploymentPreviewId": null, "zipkinTraceID": "a70ea8f4eb50c51b"}, "environment": "prod", "blacklist": {"location": ["yl[a-z]-[a-z]*\\.js"], "type": [], "message": ["Blocked a frame with origin"]}, "sampleRate": 1}, "client": "bugsnag", "apiKey": "7a505cfcfc5a2e124a4f37054c4d684d", "enabled": true}</script>
#  <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">[]</script><script id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">{"namedChunks":[]}</script>
#  <script>window.ySitRepParams = {"guv": "87FC317E9EDE7675", "datacenter": "us-east-1", "unique_request_id": "6ba937f0ddd3efdd"};</script>
#
#  <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_runtime.yji-f1229e69a4c370b7b489.js"></script>
#  <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-yelp-react-component-photo-box-14.0.0.yji-4ba552416fa73e74fdcc.js"></script>
#  <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-lodash-4.17.21.yji-ec5090f63d408b938d4f.js"></script>
#  <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-yelp-style-utils-6.1.1.yji-3854c1ff39c49d8fd8a5.js"></script>
#  <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-moment-2.29.4.yji-1a043372db501fbae4ec.js"></script>
#  <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-yelp-react-component-error-boundary-8.0.0.yji-f81cbe8d58d688c75cc2.js"></script>
#  <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-immutable-4.1.0.yji-354bb9a9d2806d17e209.js"></script>
#  <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_commons.yji-38578231b92230e41448.js"></script>
#  <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_gondola-search.yji-a93f68bc382f6f8bc758.js"></script><script type="text/javascript">window.yelp.initReactComponents();</script></body></html>,
#  <!DOCTYPE html>
# /,"js");</script><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="en-US" http-equiv="Content-Language"/><meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/><link content="#FF1A1A" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b2bb2fb0ec9c/assets/img/logos/yelp_burst.svg" rel="mask-icon" sizes="any"/><link href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b05852393ae5/assets/img/logos/favicon.ico" rel="shortcut icon"/><script> window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;window.ygaPageStartTime=new Date().getTime();</script><script>
#              window.yelp = window.yelp || {};
#              window.yelp.cookieTypePreferencesHeader = '["ANALYTICS","FUNCTIONAL","INTERNAL","STRICTLY_NECESSARY","TARGETING"]';
#
#              function addCookieManagementScript() {
#                  var tag = document.createElement('script');
#                  tag.async = true;
#                  tag.src = 'https://cdn.cookielaw.org/scripttemplates/otSDKStub.js';
#                  tag.type = 'text/javascript';
#                  tag.charset = 'UTF-8';
#                  tag.setAttribute('data-domain-script', '5fbcd417-fbc1-4fcc-abad-f622f1bba72d');
#                  tag.setAttribute('data-document-language', 'true');
#
#                  document.head.appendChild(tag);
#              }
#
#              if ('requestIdleCallback' in window) {
#                  requestIdleCallback(addCookieManagementScript, { timeout: 4000 });
#              } else {
#                  setTimeout(addCookieManagementScript, 2000);
#              }
#          </script><script async="" src="https://www.google-analytics.com/analytics.js"></script><meta id="emotion-container"/><style data-emotion-css="0 xl0fej ymzf9m ux5mu6 1fygppl 9vivtc 1sb02f4 19sk4h4 qgunke chan6m fohjg7 k04tcy 4mfze4 gutk1c 8f83st 1m051bw 1nrzw89 oxqmph 11pkcdj 6a0jil 1udg11w 79elbk 8dlaw4 xlzvdl ije6j5 1agk4wl 1egxyvc dzq7l1 epvm6 q7yb35 dc6bdr 11bijt4 1v994a0 16lklrv 1wayfxy 1um3nx 4kbcid lcqz66 1oibaro d1exgw 1italjr 1enow5j foyide 144i0wq 1kq79li 13zsxt e29med dew2bp 1w0hvwb 1sie4w0 ul2hjm 1lnf5f9 2sacua 1keukgz ralh0w yyr98k 1jac6c2 cv1jz2 ddqa90 aurft1 12i50in sw4sjz fksa8h n65gq3 147xtl9 jb5mb6">html,body,div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,address,big,cite,code,del,dfn,em,img,ins,kbd,q,s,samp,small,strike,strong,sub,sup,tt,var,b,u,i,center,dl,dt,dd,ol,ul,li,fieldset,form,label,legend,table,caption,tbody,tfoot,thead,tr,th,td,article,aside,canvas,details,embed,figure,figcaption,footer,header,hgroup,menu,nav,output,ruby,section,summary,time,mark,audio,video{margin:0;padding:0;border:0;font-size:100%;font:inherit;vertical-align:baseline;}article,aside,details,figcaption,figure,footer,header,hgroup,menu,nav,section{display:block;}body{line-height:1;}ol,ul{list-style:none;}blockquote,q{quotes:none;}blockquote:before,blockquote:after,q:before,q:after{content:'';content:none;}table{border-collapse:collapse;border-spacing:0;}.hidden-non-responsive-inline,.hidden-non-responsive-inline-block,.hidden-non-responsive-block,.hidden-non-responsive-table-cell{display:none !important;}@media only screen and (max-width:600px){.responsive .responsive-small-display-inline-block{display:inline-block !important;}.responsive .responsive-small-display-block{display:block !important;}.responsive .responsive-small-display-inline{display:inline !important;}}@media only screen and (max-width:780px){.responsive-biz .responsive-small-display-inline-block{display:inline-block !important;}.responsive-biz .responsive-small-display-block{display:block !important;}.responsive-biz .responsive-small-display-inline{display:inline !important;}}@media only screen and (max-width:1024px){.responsive .responsive-medium-display-inline-block{display:inline-block !important;}.responsive .responsive-medium-display-block{display:block !important;}.responsive .responsive-medium-display-inline{display:inline !important;}}@media only screen and (max-width:1240px){.responsive-biz .responsive-medium-display-inline-block{display:inline-block !important;}.responsive-biz .responsive-medium-display-block{display:block !important;}.responsive-biz .responsive-medium-display-inline{display:inline !important;}}@media only screen and (min-width:1025px){.responsive .responsive-desktop-small-display-inline-block{display:inline-block !important;}.responsive .responsive-desktop-small-display-block{display:block !important;}.responsive .responsive-desktop-small-display-inline{display:inline !important;}}@media only screen and (min-width:1241px){.responsive-biz .responsive-desktop-small-display-inline-block{display:inline-block !important;}.responsive-biz .responsive-desktop-small-display-block{display:block !important;}.responsive-biz .responsive-desktop-small-display-inline{display:inline !important;}}@media only screen and (min-width:1144px){.responsive .responsive-desktop-default-display-inline-block{display:inline-block !important;}.responsive .responsive-desktop-default-display-block{display:block !important;}.responsive .responsive-desktop-default-display-inline{display:inline !important;}}@media only screen and (min-width:1241px){.responsive-biz .responsive-desktop-default-display-inline-block{display:inline-block !important;}.responsive-biz .responsive-desktop-default-display-block{display:block !important;}.responsive-biz .responsive-desktop-default-display-inline{display:inline !important;}}.responsive .hidden-non-responsive-inline{display:inline !important;}.responsive .hidden-non-responsive-inline-block{disp ...
#
#      <script>
#          window.yelp = window.yelp || {};
#          window.yelp.critical_css = window.yelp.critical_css || {};
#          window.yelp.critical_css.css_map = {};
#      </script>
#      <!-- css-middleware: bootstrap placeholder --><script>(function() { window.yelp.critical_css.recordDone=function(c,l){l.onload=null;var i=window.yelp.critical_css.css_map[c];window.yelp.critical_css.css_map[c]=i&&Object.keys(i).length?i:{loaded:!1,linkTag:l}}; })()</script>
#  <meta name="critical_css_middleware"/><link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp-frontend-commons-pkg.yji-26d465377aaaceb8d450.css" rel="stylesheet"/><link as="font" crossorigin="anonymous" data-rh="true" href="https://s3-media0.fl.yelpcdn.com/assets/public/open-sans-regular.yji-aff9b80e384301f2ae0c.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" data-rh="true" href="https://s3-media0.fl.yelpcdn.com/assets/public/open-sans-semibold.yji-d3abae27d3eac73b40a5.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" data-rh="true" href="https://s3-media0.fl.yelpcdn.com/assets/public/open-sans-bold.yji-1145ff0b749fff2d31bb.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" data-rh="true" href="https://s3-media0.fl.yelpcdn.com/assets/public/poppins-bold.yji-9690ce6275ddc5645cfa.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" data-rh="true" href="https://s3-media0.fl.yelpcdn.com/assets/public/poppins-medium.yji-dc16a3592fdb61b620cc.woff2" rel="preload" type="font/woff2"/><link data-rh="true" href="https://www.yelp.com/search?find_desc=Restaurants&amp;find_loc=Blacksburg%2C+VA+24060&amp;sortby=rating" rel="prev"/><link data-rh="true" href="https://www.yelp.com/search?find_desc=Restaurants&amp;find_loc=Blacksburg%2C+VA+24060&amp;sortby=rating&amp;start=20" rel="next"/><link data-rh="true" href="/opensearch" rel="search" title="Yelp" type="application/opensearchdescription+xml"/><link as="image" data-rh="true" href="https://s3-media0.fl.yelpcdn.com/assets/public/gray-spinner.yji-98588e3310fd5dfa96dd.gif" rel="preload"/><link data-rh="true" href="https://maps.gstatic.com" rel="preconnect"/><script data-rh="true" data-testid="gtmScript" type="text/javascript">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-THHF2RF');</script><script data-rh="true" type="application/ld+json">{"@context":"https://schema.org","@type":"Organization","name":"Yelp","url":"http://www.yelp.com","sameAs":["https://www.facebook.com/yelp","https://twitter.com/yelp","https://www.linkedin.com/company/31517","https://instagram.com/yelp"]}</script><script data-rh="true">window.pageSpeedCustomTimestamps = {};</script><script data-rh="true" type="application/ld+json">
#                      {
#                          "@context": "https://schema.org",
#                          "@type": "FAQPage",
#                          "mainEntity": [{"@type": "Question", "name": "What are the best restaurants with outdoor seating?", "acceptedAnswer": {"@type": "Answer", "text": "These are the best restaurants with outdoor seating near Blacksburg, VA:<ul><li><a href='/biz/cabo-fish-taco-blacksburg'>Cabo Fish Taco</a></li><li><a href='/biz/the-blacksburg-tavern-blacksburg'>The Blacksburg Tavern</a></li><li><a href='/biz/cellar-restaurant-blacksburg'>Cellar Restaurant</a></li><li><a href='/biz/the-black-hen-and-bar-blue-blacksburg'>The Black Hen & Bar Blue</a></li><li><a href='/biz/avellinos-blacksburg'>Avellinos</a></li></ul><p>People also liked:  <a href=/search?find_desc=restaurants+for+lunch&find_loc=Blacksburg%2C+VA+24060>restaurants for lunch</a></p>"}}, {"@type": "Question", "name": "What did people search for similar to restaurants near Blacksburg, VA 24060?", "acceptedAnswer": {"@type": "Answer", "text": "People also searched for these near Blacksburg:<ul><li><a href='/search?find_desc=takeout&find_loc=Blacksburg%2C+VA&page_src=q2q_faq_sq'>Takeout</a></li><li><a href='/search?find_desc=food&find_loc=Blacksburg%2C+VA&page_src=q2q_faq_sq'>Food</a></li><li><a href='/search?find_desc=lunch&find_loc=Blacksburg%2C+VA&page_src=q2q_faq_sq'>Lunch</a></li><li><a href='/search?find_desc=breakfast+%26+brunch&find_loc=Blacksburg%2C+VA&page_src=q2q_faq_sq'>Breakfast & Brunch</a></li><li><a href='/search?find_desc=dinner&find_loc=Blacksburg%2C+VA&page_src=q2q_faq_sq'>Dinner</a></li></ul><p><a href=/search?find_desc=restaurants&find_loc=Blacksburg%2C+VA+24060&page_src=q2q_faq_sq>See more restaurants near Blacksburg.</a></p>"}}, {"@type": "Question", "name": "What are people saying about restaurants near Blacksburg, VA 24060?", "acceptedAnswer": {"@type": "Answer", "text": "This is a review for restaurants near Blacksburg, VA 24060:<br/>\"Such a convenient, tasty, and accessible restaurant near campus for dinner with your friends or the occasional date night! They have such a wide variety on their menu, so there's really something for everyone.\n\nI've heard that there's a lower level of the restaurant, but I've only been to the upper part of the Cellar. I can't attest to the alcoholic beverages served here either. \n\nIn the past, I've ordered \"Cajun Shrimp Dip\", \"Greek Gyro\" (make sure you specify that you want this as a pita sandwich because there's also a pizza version!), and \"Pasta Aegean.\" Each time I've come here, I've been really happy with my food!\"<br/><p><a href=/biz/cellar-restaurant-blacksburg>See more reviews for this business.</a></p>"}}, {"@type": "Question", "name": "What are the best restaurants for lunch?", "acceptedAnswer": {"@type": "Answer", "text": "These are the best restaurants for lunch near Blacksburg, VA:<ul><li><a href='/biz/cabo-fish-taco-blacksburg'>Cabo Fish Taco</a></li><li><a href='/biz/cellar-restaurant-blacksburg'>Cellar Restaurant</a></li><li><a href='/biz/leftys-main-street-grille-blacksburg-5'>Lefty's Main Street Grille</a></li><li><a href='/biz/due-south-bbq-christiansburg'>Due South BBQ</a></li><li><a href='/biz/himalayan-curry-cafe-blacksburg-2'>Himalayan Curry Cafe</a></li></ul><p>People also liked:  <a href=/search?find_desc=outdoor+dining+restaurants&find_loc=Blacksburg%2C+VA+24060>restaurants with outdoor seating</a></p>"}}]
#                      }
#                  </script><script data-rh="true">
#  window.__googleInit = function() {
#
#      if (window.mapInstance != null) {
#          return;
#      }
#
#      window.mapContainer = document.createElement('div');
#      window.mapContainer.style.height = '100%';
#      window.mapContainer.style.width = '100%';
#      window.mapContainer.style.visibility = 'hidden';
#
#      document.body.appendChild(window.mapContainer);
#
#
#      window.mapInstance = new google.maps.Map(
#          window.mapContainer,
#          {
#              gestureHandling: 'cooperative',
#              backgroundColor: 'rgba(229, 227, 223, 1)',
#              mapTypeId: google.maps.MapTypeId.ROADMAP,
#              controlSize: 28,
#              disableDefaultUI: true,
#              zoomControl: false,
#              zoomControlOptions: {
#                  position: google.maps.ControlPosition.TOP_LEFT,
#              },
#              styles: [
#                  {
#                      featureType: 'poi',
#                      elementType: 'labels',
#                      stylers: [{ visibility: 'off' }],
#                  },
#                  {
#                      featureType: 'administrative.neighborhood',
#                      elementType: 'labels',
#                      stylers: [{ lightness: 50 }],
#                  },
#              ],
#          }
#      );
#
#      var marker = new google.maps.Marker({
#          position: {lat: 0, lng: 0},
#          map: window.mapInstance,
#      });
#      marker.setMap(null);
#      window.mapInstance.setCenter({lat: 0, lng: 0});
#
#
#      if(window.__mapReady) {
#          window.__mapReady();
#      }
#  }
#  </script><script async="true" data-rh="true" src="//maps.googleapis.com/maps/api/js?client=gme-yelp&amp;libraries=places,visualization&amp;language=en&amp;region=US&amp;callback=__googleInit" type="text/javascript"></script><title data-rh="true">Restaurants Blacksburg, VA 24060 - Last Updated November 2022 - Yelp</title><meta content="Best Restaurants in Blacksburg, VA 24060 - Marco &amp; Luca, Cellar Restaurant, Himalayan Curry Cafe, Gillie's Cuisine, The Black Hen &amp; Bar Blue, Halwa Bakery &amp; Cafe, Souvlaki, Lefty's Main Street Grille, Ninja Cafe, Hello Bagel" data-rh="true" name="description"/><meta content="noindex" data-rh="true" name="robots"/><meta content="Yelp,recommendation,San Francisco, bay area, local,business,review,friend,restaurant,dentist,doctor,salon,spa,shopping,store,share,community,massage,sushi,pizza,nails,New York,Los Angeles" data-rh="true" name="keywords"/><meta content="Yelp" data-rh="true" property="og:site_name"/><meta content="website" data-rh="true" property="og:type"/><meta content="https://s3-media0.fl.yelpcdn.com/assets/srv0/seo_metadata/f9149736ad8d/assets/img/logos/yelp_og_image.png" data-rh="true" property="og:image"/><meta content="1080" data-rh="true" property="og:image:height"/><meta content="1920" data-rh="true" property="og:image:width"/><meta content="97534753161" data-rh="true" property="fb:app_id"/><meta content="Best Restaurants in Blacksburg, VA 24060 - Marco &amp; Luca, Cellar Restaurant, Himalayan Curry Cafe, Gillie's Cuisine, The Black Hen &amp; Bar Blue, Halwa Bakery &amp; Cafe, Souvlaki, Lefty's Main Street Grille, Ninja Cafe, Hello Bagel" data-rh="true" property="og:description"/><meta content="Restaurants Blacksburg, VA 24060 - Last Updated November 2022 - Yelp" data-rh="true" property="og:title"/><meta content="" data-rh="true" property="og:url"/><meta content="app-id=284910350, app-argument=yelp:///search?location=Blacksburg%2C%20VA%2024060&amp;terms=Restaurants&amp;utm_campaign=default&amp;utm_source=www" data-rh="true" name="apple-itunes-app"/>
#
# ...
#
#  For the price, we got a lot of food! And our meals were packaged very well to avoid spillage in the car ride home. Thank you so much!"</p><p class="css-2sacua"><a class="css-1um3nx" href="/biz/italianos-blacksburg">See more reviews for this business.</a></p><p class="css-1lnf5f9" data-font-weight="bold">What are the best restaurants for lunch?</p><p class="css-2sacua">These are the best restaurants for lunch near Blacksburg, VA:</p><div class="margin-b2__09f24__CEMjT border-color--default__09f24__NPAKY"><ul class="list--round__09f24__yv71t list__09f24__ynIEd list-size--default__09f24__fMJ05"><li class="list-item__09f24__n1LHc"><a class="css-1keukgz" href="/biz/cabo-fish-taco-blacksburg"><p class="css-ralh0w">Cabo Fish Taco</p></a></li><li class="list-item__09f24__n1LHc"><a class="css-1keukgz" href="/biz/cellar-restaurant-blacksburg"><p class="css-ralh0w">Cellar Restaurant</p></a></li><li class="list-item__09f24__n1LHc"><a class="css-1keukgz" href="/biz/leftys-main-street-grille-blacksburg-5"><p class="css-ralh0w">Lefty's Main Street Grille</p></a></li><li class="list-item__09f24__n1LHc"><a class="css-1keukgz" href="/biz/due-south-bbq-christiansburg"><p class="css-ralh0w">Due South BBQ</p></a></li><li class="list-item__09f24__n1LHc"><a class="css-1keukgz" href="/biz/himalayan-curry-cafe-blacksburg-2"><p class="css-ralh0w">Himalayan Curry Cafe</p></a></li></ul></div><p class="css-2sacua">People also liked: <a class="css-1um3nx" href="/search?find_desc=outdoor+dining+restaurants&amp;find_loc=Blacksburg%2C+VA+24060">restaurants with outdoor seating </a></p></div></div></div></li></ul><img alt="" class="abpDetectionPixel__09f24__xemfz" src="/px.gif?ch=1&amp;local_ads=1&amp;rn=3&amp;unique_request_id=fed3de37cccab5e3&amp;unique_visitor_id=FB54B04C69743D53"/><img alt="" class="abpDetectionPixel__09f24__xemfz" src="/px.gif?ch=2&amp;local_ads=1&amp;rn=3&amp;unique_request_id=fed3de37cccab5e3&amp;unique_visitor_id=FB54B04C69743D53"/></div></main></div></div><div class="rightRailContainer__09f24__LYdJF border-color--default__09f24__NPAKY"><aside aria-label="Search results map" class="rightRailInnerContainer__09f24__it0cQ border-color--default__09f24__NPAKY"><div class="stickyContainer__09f24__VECdo innerShadow__09f24__m1PJ2 border-color--default__09f24__NPAKY" style="top:131px;margin-top:34px;height:calc(100vh - 131px)"><div class="container__09f24__e_1lI googleMapContainer__09f24__Sz3Zg border-color--default__09f24__NPAKY" data-lcp-target-id="SEARCH_MAP_SPINNER"><div class="outer__09f24__O95Wi border-color--default__09f24__NPAKY"><div class="engine__09f24__spkHV border-color--default__09f24__NPAKY"></div></div></div></div></aside></div></div></div></div><footer class="footer__09f24__NKwLz border-color--default__09f24__NPAKY background-color--silver-light__09f24__u9k0W"><div class="padding-r5__09f24__QRKqb padding-l5__09f24__IQ8Wp border-color--default__09f24__NPAKY"><div class="arrange__09f24__LDfbs gutter-auto__09f24__W9jlL layout-equal__09f24__odeM0 layout-stack-small__09f24__QROpe border-color--default__09f24__NPAKY"><div class="arrange-unit__09f24__rqHTg responsive-hidden-small__09f24__qQFtj border-color--default__09f24__NPAKY"><div class="margin-b2__09f24__CEMjT border-color--default__09f24__NPAKY"><span class="css-ux5mu6" data-font-weight="bold">About</span></div><ul class="undefined list__09f24__ynIEd"><li class="margin-b1__09f24__vaLrm border-color--default__09f24__NPAKY"><a class="css-yyr98k" href="https://www.yelp.com/about">About Yelp</a></li><li class="margin-b1__09f24__vaLrm border-color--default__09f24__NPAKY"><a class="css-yyr98k" href="https://www.yelp.com/careers/home">Careers</a></li><li class="margin-b1__09f24__vaLrm border-color--default__09f24__NPAKY"><a class="css-yyr98k" href="https://www.yelp.com/press">Press</a></li><li class="margin-b1__09f24__vaLrm border-color--default__09f24__NPAKY"><a class="css-yyr98k" href="http://yelp-ir.com/">Investor Relations</a></li><li class="margin-b1__09f24__vaLrm border-color--d ...
#  <script data-hypernova-id="19d1673b-3a4b-42a5-8697-e556542ae083" data-hypernova-key="yelpfrontend__53057__yelpfrontend__GondolaSearch__dynamic" type="application/json"><!--{"locale":"en_US","messages":{},"requestCookies":{"LOCATION":null,"MO_MAP":null},"requestHeaders":{},"requestPath":"/search","requestUrl":"https://www.yelp.com/search?find_desc=Restaurants&amp;find_loc=Blacksburg%2C+VA+24060&amp;ns=1&amp;sortby=rating&amp;start=40","routeParams":{},"userId":null,"bizUserId":null,"uniqueRequestId":"974e4c65c8820529","site":"www","gaConfig":{"clientID":"FB54B04C69743D53","dimensions":{"global":{"full_url":[15,"/search?find_desc=Restaurants&amp;find_loc=Blacksburg%2C+VA+24060&amp;ns=1&amp;sortby=rating&amp;start=40"],"internal_ip":[18,false],"referrer":[28,"none"]},"www":{"full_url":[34,"/search?find_desc=Restaurants&amp;find_loc=Blacksburg%2C+VA+24060&amp;ns=1&amp;sortby=rating&amp;start=40"],"internal_ip":[27,false],"referrer":[64,"none"]}},"domain":"yelp.com","enable_high_volume_events":false,"ga_enabled":true,"js_dimensions":{"global":{},"www":{}},"metrics":{"global":{},"www":{}},"trackers":{"www":"UA-30501-24","global":"UA-30501-1"},"user_id":null},"guv":"FB54B04C69743D53","legacyProps":{"searchAppProps":{"ajaxScrollablePhotosURI":"/biz_photos/scrollable_photos/7zDbcbUkafhkanpTE5TQRQ%2C5zVUSsK-RnjgrQwsiAPMcQ%2C7mA0ZwnvAHjbiiVjcMVsSw%2C1Lky0iMx8_8u9IZV3G14dA%2CBDD69CHkwlISTUW4iJ5Asg%2CkiXcEqIxJJk773AvrgSyQA%2CK4Sq3cz0-73HWS14K6I6Ng%2CKsrMCDF689P4bTBrrbTLjA%2CKeT8chXygi4TzR-3crcr0A%2Cz3m9LqyBlEIFhY3EbUXPHg","autoEnabledAttributes":[],"experimentData":{"ax.mobile.remove_menu_icon_from_search_ads":"enabled","ax.mobile.remove_menu_photos_from_search_for_national_advertisers":"enabled","ax.www.sponsored_business_highlights":"enabled","erised_suggested_filters":"true","hot_and_new_launchpad_internal":"disabled","searchux.ios.snappy_carousels":"automatic_snaps","searchux.www.cta_consistency":"red_left_aligned_button","searchux.www.larger_photos_everywhere":"scrollable_photos","txn.www.food_delivery_or_pickup_flow_fullstory":"status_quo","yelp.search.search_suggest.model_based_delivery_pickup":"disabled","yelp.search.search_suggest.relevance_model_testing_override":"disabled","yelp.search.search_suggest.structured_suggest_filters":"disabled","yelp.search.search_suggest.structured_suggest_internal_testing":"disabled"},"searchPageProps":{"consumerHeaderProps":{"logoutCsrfToken":"3204b7440c21fd821d73bfeb672bd5ec09daec6b26ac9f54ed10123ce0175ed8","bizSiteURL":null,"initialSearchDisplayVal":"Restaurants","initialLocationDisplayVal":"Blacksburg, VA 24060","initialHiddenLocationInputVal":"Blacksburg, VA 24060","initialIsMapArea":false,"initialHiddenLocationInputName":"find_loc","initialIsCurrentLocation":false},"footerProps":{"localeCode":"en_US","baseUrl":"https://www.yelp.com/","attributionSource":"acxiom","currentUrl":"https://www.yelp.com//search?find_desc=Restaurants&amp;find_loc=Blacksburg%2C+VA+24060&amp;sortby=rating&amp;start=40"},"filterPanelProps":{"filterInfoMap":{"recommended":{"name":"sort","value":"recommended","text":"Recommended"},"rating":{"name":"sort","value":"rating","text":"Highest Rated","isSelected":true},"review_count":{"name":"sort","value":"review_count","text":"Most Reviewed"},"g:-80.53184509277344,37.14827672411747,-80.32722473144531,37.31229085980303":{"name":"l","value":"g:-80.53184509277344,37.14827672411747,-80.32722473144531,37.31229085980303","text":"Bird's-eye View"},"g:-80.4806900024414,37.18931370032807,-80.37837982177734,37.271320777045204":{"name":"l","value":"g:-80.4806900024414,37.18931370032807,-80.37837982177734,37.271320777045204","text":"Driving (5 mi.)"},"g:-80.45511245727539,37.20982383064024,-80.40395736694336,37.250827370108105":{"name":"l","value":"g:-80.45511245727539,37.20982383064024,-80.40395736694336,37.250827370108105","text":"Biking (2 mi.)","isSelected":true},"g:-80.44232368469238,37.22000845730578,-80.41674613952637,37.240510245759914":{"name":"l","value":"g:-80.44232368469238,37 ...
#  <script crossorigin="anonymous" integrity="sha384-bm7MnzvK++ykSwVJ2tynSE5TRdN+xL418osEVF2DE/L/gfWHj91J2Sphe582B1Bh" src="https://s3-media0.fl.yelpcdn.com/assets/srv0/cdn_assets/64141792105e/assets/vendor/react-dom/18.2.0/umd/react-dom.production.min.js"></script>
#  <!-- css-middleware: body tag placeholder --><script>(function() { var e=window.yelp.critical_css;function t(e){setTimeout(e,0)}function n(n){for(var o in e.css_map)if(!e.css_map[o].loaded)return;t(n)}function o(t,o){var a=e.css_map[t],i=a.linkTag,r=document.querySelector('style[data-critical-css="'+t+'"]');if(r&&i&&!a.loaded){var c=function(e,t){var n=e.cloneNode();n.rel="stylesheet",n.media="all",n.href=e.href;var o=function(){this.onload=null,this.setAttribute("onload",null),t.parentNode.removeChild(t)};return n.setAttribute("onload",o),n.onload=o,n}(i,r);r.insertAdjacentElement("afterend",c),i.parentNode.removeChild(i),e.css_map[t].loaded=!0,n(o)}else n(o)}function a(n,a){if(!e.css_map||0===Object.keys(e.css_map).length)return void t(n);(a?[a]:Object.keys(e.css_map)).forEach((function(t){e.lowPriorityMode?o(t,n):setTimeout(o,0,t,n)}))}e.criticalCSSReady=function(t){const n=(o=t,function(){return o&&(r=o.apply(i||this,arguments),o=null),r});var o,i,r;a(n);var c=e.recordDone.bind(window);e.recordDone=function(e,t){c.call(this,e,t),a(n,t.dataset.criticalCss)}}; })()</script>
#  <script>
#          window.yelp = window.yelp || {};
#          window.yelp.zipkin_id = '0138d85717e8e7cf';
#          window.yelp.unique_request_id = '974e4c65c8820529';
#          window.yelp.guv = 'FB54B04C69743D53';
#          window.yelp.yuv_record = 'e44A4O9JCQOvmK3VzbRplrGTD98knzj607R2wtpaxC-EOF48Y0hzQenPfwPMsWv76SXp6xCOdyT5wW0aMiDRXw5kuOE3OG4W';
#      </script>
#  <script crossorigin="anonymous" integrity="sha384-VWXV8VA+0xZuNh5mksoTGTWM4qM9gdLvcv/y/f3Ps2ZjKN37taVfpJHexdLG2bJI" src="https://s3-media0.fl.yelpcdn.com/assets/srv0/cdn_assets/4dc644e84e0b/assets/vendor/regenerator-runtime/0.13.9/regenerator-runtime.min.js"></script>
#  <script id="yelp-js-error-reporting-init-error-reporting" type="application/json">{"config": {"release": "1454d47a0513b6922dca0d85d72ee1a986cdc50a", "metaData": {"projectName": "gondola-search", "activeVersion": "5.30.57", "deploymentPreviewId": null, "zipkinTraceID": "0138d85717e8e7cf"}, "environment": "prod", "blacklist": {"location": ["yl[a-z]-[a-z]*\\.js"], "type": [], "message": ["Blocked a frame with origin"]}, "sampleRate": 1}, "client": "bugsnag", "apiKey": "7a505cfcfc5a2e124a4f37054c4d684d", "enabled": true}</script>
#  <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">[]</script><script id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">{"namedChunks":[]}</script>
#  <script>window.ySitRepParams = {"guv": "FB54B04C69743D53", "datacenter": "us-east-1", "unique_request_id": "974e4c65c8820529"};</script>
#
#  <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_runtime.yji-f1229e69a4c370b7b489.js"></script>
#  <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-yelp-react-component-photo-box-14.0.0.yji-4ba552416fa73e74fdcc.js"></script>
#  <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-lodash-4.17.21.yji-ec5090f63d408b938d4f.js"></script>
#  <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-yelp-style-utils-6.1.1.yji-3854c1ff39c49d8fd8a5.js"></script>
#  <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-moment-2.29.4.yji-1a043372db501fbae4ec.js"></script>
#  <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-yelp-react-component-error-boundary-8.0.0.yji-f81cbe8d58d688c75cc2.js"></script>
#  <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-immutable-4.1.0.yji-354bb9a9d2806d17e209.js"></script>
#  <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_commons.yji-38578231b92230e41448.js"></script>
#  <script crossorigin="anonymous" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_gondola-search.yji-a93f68bc382f6f8bc758.js"></script><script type="text/javascript">window.yelp.initReactComponents();</script></body></html>]

# %%
tags = [soup.find_all('a', {"class": "css-1m051bw", "rel": "noopener"}) for soup in soups]
tags
# Out:
# [[<a class="css-1m051bw" href="/biz/taqueria-el-paso-christiansburg?osq=Restaurants" name="Taqueria el Paso" rel="noopener" target="_blank">Taqueria el Paso</a>,
#   <a class="css-1m051bw" href="/biz/the-blacksburg-tavern-blacksburg?osq=Restaurants" name="The Blacksburg Tavern" rel="noopener" target="_blank">The Blacksburg Tavern</a>,
#   <a class="css-1m051bw" href="/biz/cabo-fish-taco-blacksburg?osq=Restaurants" name="Cabo Fish Taco" rel="noopener" target="_blank">Cabo Fish Taco</a>,
#   <a class="css-1m051bw" href="/biz/gaucho-brazilian-grille-blacksburg-2?osq=Restaurants" name="Gaucho Brazilian Grille" rel="noopener" target="_blank">Gaucho Brazilian Grille</a>,
#   <a class="css-1m051bw" href="/biz/blacksburg-wine-lab-blacksburg?osq=Restaurants" name="Blacksburg Wine Lab" rel="noopener" target="_blank">Blacksburg Wine Lab</a>,
#   <a class="css-1m051bw" href="/biz/spicity-blacksburg?osq=Restaurants" name="Spicity" rel="noopener" target="_blank">Spicity</a>,
#   <a class="css-1m051bw" href="/biz/joes-diner-blacksburg?osq=Restaurants" name="Joe’s Diner" rel="noopener" target="_blank">Joe’s Diner</a>,
#   <a class="css-1m051bw" href="/biz/our-daily-bread-bakery-and-bistro-blacksburg-2?osq=Restaurants" name="Our Daily Bread Bakery and Bistro" rel="noopener" target="_blank">Our Daily Bread Bakery and Bistro</a>,
#   <a class="css-1m051bw" href="/biz/avellinos-blacksburg?osq=Restaurants" name="Avellinos" rel="noopener" target="_blank">Avellinos</a>,
#   <a class="css-1m051bw" href="/biz/benny-marzanos-blacksburg?osq=Restaurants" name="Benny Marzano’s" rel="noopener" target="_blank">Benny Marzano’s</a>],
#  [<a class="css-1m051bw" href="/biz/marco-and-luca-blacksburg?osq=Restaurants" name="Marco &amp; Luca" rel="noopener" target="_blank">Marco &amp; Luca</a>,
#   <a class="css-1m051bw" href="/biz/cellar-restaurant-blacksburg?osq=Restaurants" name="Cellar Restaurant" rel="noopener" target="_blank">Cellar Restaurant</a>,
#   <a class="css-1m051bw" href="/biz/himalayan-curry-cafe-blacksburg-2?osq=Restaurants" name="Himalayan Curry Cafe" rel="noopener" target="_blank">Himalayan Curry Cafe</a>,
#   <a class="css-1m051bw" href="/biz/gillies-cuisine-blacksburg?osq=Restaurants" name="Gillie’s Cuisine" rel="noopener" target="_blank">Gillie’s Cuisine</a>,
#   <a class="css-1m051bw" href="/biz/the-black-hen-and-bar-blue-blacksburg?osq=Restaurants" name="The Black Hen &amp; Bar Blue" rel="noopener" target="_blank">The Black Hen &amp; Bar Blue</a>,
#   <a class="css-1m051bw" href="/biz/halwa-bakery-and-cafe-blacksburg?osq=Restaurants" name="Halwa Bakery &amp; Cafe" rel="noopener" target="_blank">Halwa Bakery &amp; Cafe</a>,
#   <a class="css-1m051bw" href="/biz/souvlaki-blacksburg-2?osq=Restaurants" name="Souvlaki" rel="noopener" target="_blank">Souvlaki</a>,
#   <a class="css-1m051bw" href="/biz/leftys-main-street-grille-blacksburg-5?osq=Restaurants" name="Lefty’s Main Street Grille" rel="noopener" target="_blank">Lefty’s Main Street Grille</a>,
#   <a class="css-1m051bw" href="/biz/ninja-cafe-blacksburg?osq=Restaurants" name="Ninja Cafe" rel="noopener" target="_blank">Ninja Cafe</a>,
#   <a class="css-1m051bw" href="/biz/hello-bagel-blacksburg-3?osq=Restaurants" name="Hello Bagel" rel="noopener" target="_blank">Hello Bagel</a>],
#  [<a class="css-1m051bw" href="/biz/abbys-blacksburg?osq=Restaurants" name="Abby’s" rel="noopener" target="_blank">Abby’s</a>,
#   <a class="css-1m051bw" href="/biz/roots-natural-kitchen-blacksburg?osq=Restaurants" name="Roots Natural Kitchen" rel="noopener" target="_blank">Roots Natural Kitchen</a>,
#   <a class="css-1m051bw" href="/biz/next-door-bake-shop-blacksburg?osq=Restaurants" name="Next Door Bake Shop" rel="noopener" target="_blank">Next Door Bake Shop</a>,
#   <a class="css-1m051bw" href="/biz/622-north-blacksburg?osq=Restaurants" name="622 North" rel="noopener" target="_blank">622 North</a>,
#   <a class="css-1m051bw" href="/biz/sushi-factory-blacksburg?osq=Restaurants" name="Sushi Factory" rel="noopener" target="_blank">Sushi Factory</a>,
#   <a class="css-1m051bw" href="/biz/mill-mountain-coffee-and-tea-blacksburg?osq=Restaurants" name="Mill Mountain Coffee And Tea" rel="noopener" target="_blank">Mill Mountain Coffee And Tea</a>,
#   <a class="css-1m051bw" href="/biz/lin-yue-chuan-blacksburg?osq=Restaurants" name="Lin Yue Chuan" rel="noopener" target="_blank">Lin Yue Chuan</a>,
#   <a class="css-1m051bw" href="/biz/mezeh-mediterranean-grill-blacksburg-blacksburg?osq=Restaurants" name="Mezeh Mediterranean Grill - Blacksburg" rel="noopener" target="_blank">Mezeh Mediterranean Grill - Blacksburg</a>,
#   <a class="css-1m051bw" href="/biz/greens-grill-and-sushi-bar-blacksburg?osq=Restaurants" name="Green’s Grill &amp; Sushi Bar" rel="noopener" target="_blank">Green’s Grill &amp; Sushi Bar</a>,
#   <a class="css-1m051bw" href="/biz/centro-taco-bar-blacksburg?osq=Restaurants" name="Centro Taco Bar" rel="noopener" target="_blank">Centro Taco Bar</a>],
#  [<a class="css-1m051bw" href="/biz/benny-marzanos-blacksburg-5?osq=Restaurants" name="Benny Marzano’s" rel="noopener" target="_blank">Benny Marzano’s</a>,
#   <a class="css-1m051bw" href="/biz/orzo-roll-and-bowl-blacksburg?osq=Restaurants" name="Orzo Roll &amp; Bowl" rel="noopener" target="_blank">Orzo Roll &amp; Bowl</a>,
#   <a class="css-1m051bw" href="/biz/deli-mart-blacksburg-2?osq=Restaurants" name="Deli Mart" rel="noopener" target="_blank">Deli Mart</a>,
#   <a class="css-1m051bw" href="/biz/tokyo-grill-blacksburg?osq=Restaurants" name="Tokyo Grill" rel="noopener" target="_blank">Tokyo Grill</a>,
#   <a class="css-1m051bw" href="/biz/variabowl-blacksburg?osq=Restaurants" name="Variabowl" rel="noopener" target="_blank">Variabowl</a>,
#   <a class="css-1m051bw" href="/biz/bottom-of-the-stairs-blacksburg?osq=Restaurants" name="Bottom of the Stairs" rel="noopener" target="_blank">Bottom of the Stairs</a>,
#   <a class="css-1m051bw" href="/biz/souvlaki-blacksburg-2?osq=Restaurants" name="Souvlaki" rel="noopener" target="_blank">Souvlaki</a>,
#   <a class="css-1m051bw" href="/biz/centro-taco-bar-blacksburg?osq=Restaurants" name="Centro Taco Bar" rel="noopener" target="_blank">Centro Taco Bar</a>,
#   <a class="css-1m051bw" href="/biz/mezeh-mediterranean-grill-blacksburg-blacksburg?osq=Restaurants" name="Mezeh Mediterranean Grill - Blacksburg" rel="noopener" target="_blank">Mezeh Mediterranean Grill - Blacksburg</a>,
#   <a class="css-1m051bw" href="/biz/cellar-restaurant-blacksburg?osq=Restaurants" name="Cellar Restaurant" rel="noopener" target="_blank">Cellar Restaurant</a>],
#  [<a class="css-1m051bw" href="/biz/india-garden-restaurant-blacksburg?osq=Restaurants" name="India Garden Restaurant" rel="noopener" target="_blank">India Garden Restaurant</a>,
#   <a class="css-1m051bw" href="/biz/zoes-kitchen-blacksburg-3?osq=Restaurants" name="Zoes Kitchen" rel="noopener" target="_blank">Zoes Kitchen</a>,
#   <a class="css-1m051bw" href="/biz/black-salt-kitchen-blacksburg-2?osq=Restaurants" name="Black Salt Kitchen" rel="noopener" target="_blank">Black Salt Kitchen</a>,
#   <a class="css-1m051bw" href="/biz/the-milk-parlor-blacksburg?osq=Restaurants" name="The Milk Parlor" rel="noopener" target="_blank">The Milk Parlor</a>,
#   <a class="css-1m051bw" href="/biz/the-farmhouse-restaurant-christiansburg-2?osq=Restaurants" name="The Farmhouse Restaurant" rel="noopener" target="_blank">The Farmhouse Restaurant</a>,
#   <a class="css-1m051bw" href="/biz/italianos-blacksburg?osq=Restaurants" name="Italiano’s" rel="noopener" target="_blank">Italiano’s</a>,
#   <a class="css-1m051bw" href="/biz/el-rodeo-blacksburg?osq=Restaurants" name="El Rodeo" rel="noopener" target="_blank">El Rodeo</a>,
#   <a class="css-1m051bw" href="/biz/bull-and-bones-brewhaus-and-grill-blacksburg?osq=Restaurants" name="Bull and Bones Brewhaus and Grill" rel="noopener" target="_blank">Bull and Bones Brewhaus and Grill</a>,
#   <a class="css-1m051bw" href="/biz/tokyo-grill-blacksburg?osq=Restaurants" name="Tokyo Grill" rel="noopener" target="_blank">Tokyo Grill</a>,
#   <a class="css-1m051bw" href="/biz/cafe-mekong-blacksburg?osq=Restaurants" name="Cafe MeKong" rel="noopener" target="_blank">Cafe MeKong</a>]]

# %% [markdown]
# ## Exercise
# Scrape march madness rankings
# https://www.ncaa.com/rankings/basketball-men/d1/ncaa-mens-basketball-net-rankings
#
# see QAC notes...
