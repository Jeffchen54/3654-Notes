# %% [markdown]
# # Data Lists and List Transforms
# by Chris North, Virginia Tech
#
# Also: Computational Notebooks, Jupyter & Python, Processing Data Files
#
# Reminder about learning goals:  Concepts + Coding

# %% [markdown]
# ## Computational Notebooks
# * What?
#     * Notebook encapsulates Code + Results + Narrative
#     * Consists of a series of 2 types of cells:  code+result cell, or markdown cell
#     * Example:  https://nbviewer.org/gist/nealcaren/5105037
# * Why?
#     * Provenance = Sequence of code cells and intermediate results leading up to a solution
#     * Incremental, Interactive, Collaborative, Reproducable science, ...
# * Use cases
#     * Data science process
#     * Reporting and presentation
# * Tools:
#     * Jupyter, colab.research.google.com, deepnote.com, observablehq.com, ...
#
# ### Jupyter:
# * Anaconda Navigator
# * Documentation:  https://jupyter.org
# * WebCAT plug-in:  https://github.com/CSSPLICE/webcatjupyterplugin
#
# ### Python:
# * Anaconda download: https://www.anaconda.com/download/
# * Documentation: https://www.python.org

# %% [markdown]
# ## Getting started with Jupyter and Python
#
# ### Code cell
# * Create a code cell (+)
#     * Code completion (tab)
#     * Code inspector (shift+tab)
#     * Run a cell (shift+return)
# * Command mode vs Edit mode
#     * Delete a cell (d,d)
# * Keyboard Shortcuts:  Jupyter | Help | Keyboard Shortcuts
#     * Tutorial: Jupyter | Help | User Interface Tour

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# **bold**
#
# *Virginia Tech is great*

# %% [markdown]
# ### Markdown cell
# * Create a markdown cell (+, toolbar menu | Markdown)
#     * Markdown syntax: https://www.markdownguide.org/cheat-sheet/ ,  https://help.github.com/articles/basic-writing-and-formatting-syntax/
#     * bullet *italic* **bold** `code`
#     * [VT](http://vt.edu) or http://dude.com/url
#     * [link within a notebook](#Computational-Notebooks)
# * Run a markdown cell
#
# ![VT](https://www.assets.cms.vt.edu/images/logo-maroon-whiteBG.svg)

# %% [markdown]
# ### Computing stuff

# %% [markdown]
# How tall are you in inches?

# %%
print(5*12+7)
5*12+7
# Out:
# 67
# 67

# %% [markdown]
# How tall are you in cm?
# *Write a function*

# %%
def inch_to_cm(inch):
    return inch * 2.54

# %%
inch_to_cm(67)
# Out:
# 170.18

# %% [markdown]
# ## Data Structures and Transforms:  Lists
# Using appropriate data science abstractions
#
# ### List data structure
# * Sequence of elements:  [1, 2, 3]
# * Length:  len(list)
# * Mutable:  list[2]=5
# * List Comprehensions: https://docs.python.org/3.6/tutorial/datastructures.html#list-comprehensions

# %% [markdown]
# Example:  heights of students in the class, in inches

# %%
heights = [67, 68, 74, 63, 69, 65, 82]
heights
# Out:
# [67, 68, 74, 63, 69, 65, 82]

# %% [markdown]
# ## Data Transforms using Lists
#
# Functional transforms for answers to simple data questions.
# (Without writing loop code!)
#
# * Slice
# * Reduce
# * Map
# * Filter
# * Sort
# * Join

# %% [markdown]
# ### Slice
#
# Select data by index.
#
# `list[start:end:step]`
#
# Example: What are some specific heights in the list?

# %%
heights
# Out:
# [67, 68, 74, 63, 69, 65, 82]

# %%
heights[0]
# Out:
# 67

# %%
heights[-1]
# Out:
# 82

# %%
heights[0:6:2]
# Out:
# [67, 74, 69]

# %%
heights[::-1]
# Out:
# [82, 65, 69, 63, 74, 68, 67]

# %%
print(heights)
heights[::-1]
print(heights)
# Out:
# [67, 68, 74, 63, 69, 65, 82]
# [67, 68, 74, 63, 69, 65, 82]

# %%
heights
# Out:
# [67, 68, 74, 63, 69, 65, 82]

# %% [markdown]
# ### Reduce
#
# List &rarr; value
#
# Most common reduce transforms are pre-implemented: `mean(list), sum(list), len(list), ...`
#
# Example:  How many?  Whats the mean?  Shortest or tallest?

# %%
max(heights)
# Out:
# 82

# %%
import numpy 
numpy.median(heights)
# Out:
# 68.0

# %% [markdown]
# ### Map
#
# List &rarr; List
#
# * Long form:  `map(func, list)` where `func(element)` is 1&rarr;1
#     * Inline funcs:  `(lambda vars: expression(vars))`
# * Short form:  `[expr(var) for var in list]`  (Python **List Comprehension**)
#     * List Comprehensions: https://docs.python.org/3.6/tutorial/datastructures.html#list-comprehensions
#
# Example: What are the heights in metric?

# %%
heights
# Out:
# [67, 68, 74, 63, 69, 65, 82]

# %%
## Map, using defined function
list(map(inch_to_cm, heights))
# Out:
# [170.18, 172.72, 187.96, 160.02, 175.26, 165.1, 208.28]

# %%
## Map, using Lambda function
list(map(lambda i: i * 2.54, heights))
# Out:
# [170.18, 172.72, 187.96, 160.02, 175.26, 165.1, 208.28]

# %%
## Map, using Python List Comprehension
[i * 2.54 for i in heights]
# Out:
# [170.18, 172.72, 187.96, 160.02, 175.26, 165.1, 208.28]

# %% [markdown]
# ### Filter
#
# Select by data criteria:  List &rarr; shorter List
#
# * Long form:  `filter(func, list)`  where func(element) -> boolean
# * Short form: `[var for var in list if cond(var)]`  (Python **List Comprehension**)
#
# Example:  Which are tall?

# %%
heights
# Out:
# [67, 68, 74, 63, 69, 65, 82]

# %%
def is_tall(inch):
    return inch >= 6 * 12

# %%
[is_tall(i) for i in heights]
# Out:
# [False, False, True, False, False, False, True]

# %%
## Filter using defined function
list(filter(is_tall, heights))
# Out:
# [74, 82]

# %%
## Filter using lambda function

# %%
## Filter, using Python List Comprehension
[i for i in heights if i >= 6*12]
# Out:
# [74, 82]

# %%
## Combine Map and Filter in one list comprehension
[i * 2.54 for i in heights if i >= 6*12]
# Out:
# [187.96, 208.28]

# %% [markdown]
# ### Sort
#
# `sorted(list)` or  `list.sort()`
#
# Example: What is the order of short to tall?

# %%
sorted(heights, reverse=True)
# Out:
# [82, 74, 69, 68, 67, 65, 63]

# %% [markdown]
# ## Composition of Transforms
#
# Chaining multiple transforms together
#
# Example: How many tall people?
#
# *hint: use data as logic, no counter variable needed*

# %%
len([i for i in heights if i >= 6*12])
# Out:
# 2

# %% [markdown]
# Example: Standard Deviation?
#
# ![](https://wikimedia.org/api/rest_v1/media/math/render/svg/32e3c0f27c2595926963cc5d8df113e6a12cf917)

# %%
## HW2?

# %% [markdown]
# # Exercises
#
# ### Data normalization using Zscore:
#
# $zscore(x) = \frac{(x - mean)}{stdev}$
#
# * normalize data such that: mean=0, stdev=1
# * https://en.wikipedia.org/wiki/Standard_score
#
# Problem 1:  Normalize the Heights using Zscore:

# %%
### some useful reduce operators
import numpy
numpy.mean(heights), numpy.std(heights)
# Out:
# (69.71428571428571, 5.94532915619566)

# %% [markdown]
# Problem 2: Find heights shorter than -1 stdev

# %%
(75 - numpy.mean(heights)) / numpy.std(heights)
# Out:
# 0.8890532629645946

# %%
[(i - numpy.mean(heights)) / numpy.std(heights) for i in heights]
# Out:
# [-0.45654086476560113,
#  -0.28834159879932664,
#  0.7208539969983202,
#  -1.129337928630699,
#  -0.12014233283305217,
#  -0.7929393966981501,
#  2.066448124728516]

# %% [markdown]
# ## Functional vs Loops
#
# Functional transforms (e.g. `map()`, `filter()`, List Comprehensions `[for in if]`)
#
#     vs.
#
# Imperative loops (e.g. `For in:`)?
#
# * Functional programming: https://en.wikipedia.org/wiki/Functional_programming
# * Functional programming in python:  https://docs.python.org/3.6/howto/functional.html
#     * List Comprehensions
#     * Lambda functions

# %%
### functional map
list(map(inch_to_cm, heights))

# or list comprehension
[inch_to_cm(i) for i in heights]
# Out:
# [170.18, 172.72, 187.96, 160.02, 175.26, 165.1, 208.28]

# %%
### imperative loop
cms = []
for i in heights:
    cms.append(i * 2.54)
cms
# Out:
# [170.18, 172.72, 187.96, 160.02, 175.26, 165.1, 208.28]

# %% [markdown]
# Advantages of Functional transforms (e.g. `map()`, `filter()`, List Comprehensions `[for in if]`) over writing loops (e.g. `For in:`)?
# * Abstraction: loops are low level
# * Composable, re-usable:  z = f(g(x))
# * Provenance: maintain copies of lists
# * Usability: focus on math, not data structure maintenance
# * Optimization: native code
# * Efficiency: parallel computing
# * More efficiency: Lazy evaluation

# %%
### Which one is faster?
import time

input = range(1,10000000)  # 10,000,000

# using a for loop with func
start = time.time()
output = []
for i in input:
    output.append(inch_to_cm(i))
end = time.time()
print( "%.3fs = for loop with func" % (end-start) )

# using a for loop
start = time.time()
output = []
for i in input:
    output.append(i * 2.54)
end = time.time()
print( "%.3fs = for loop" % (end-start) )


# using map with func
start = time.time()
output = list(map(inch_to_cm, input))
end = time.time()
print( "%.3fs = map with func" % (end-start) )

# using map
start = time.time()
output = list(map(lambda i: i * 2.54, input))
end = time.time()
print( "%.3fs = map" % (end-start) )


# using list comprehension with func
start = time.time()
output = [inch_to_cm(i) for i in input]
end = time.time()
print( "%.3fs = list comprehension with func" % (end-start) )

# using list comprehension
start = time.time()
output = [i * 2.54 for i in input]
end = time.time()
print( "%.3fs = list comprehension" % (end-start) )
# Out:
# 1.521s = for loop with func
# 1.129s = for loop
# 0.843s = map with func
# 0.842s = map
# 1.054s = list comprehension with func
# 0.629s = list comprehension

# %%
### dict access by key
d['a']
# Out:
# 1

# %% [markdown]
# ## Tuples, Dictionaries, Sets, Strings
#
# Other useful list-like data structures:
# * Tuple:  `(1, 2, 3)`
# * Dictionary:  `{'a':1, 'b':2, 'c':3}`
# * Set: `{1, 2, 3}`

# %%
heights
# Out:
# [67, 68, 74, 63, 69, 65, 82]

# %%
### tuple
t = (1,2,2,3)
t
# Out:
# (1, 2, 2, 3)

# %%
(a,b,c,d) = t
b
# Out:
# 2

# %%
t[2:]
# Out:
# (2, 3)

# %%
### dict key/value pairs
d = {'a':1, 'b':2, 'c':3}
d
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
### set
s= {4, 1, 2, 2, 3}
s
# Out:
# {1, 2, 3, 4}

# %%
### string
x = 'some text'
x[3]
# Out:
# 'e'

# %%
x.capitalize()
# Out:
# 'Some text'

# %% [markdown]
# # Join, Zip
#
# columns -> rows
# * table = zip(column, column)
# * rows = zip(*columns)
# * columns = zip(*rows)

# %%
heights
# Out:
# [67, 68, 74, 63, 69, 65, 82]

# %%
### names
names = ['yalong','chris','mary','jack','e','f','g']
names
# Out:
# ['yalong', 'chris', 'mary', 'jack', 'e', 'f', 'g']

# %%
dt = list(zip(names, heights))
dt
# Out:
# [('yalong', 67),
#  ('chris', 68),
#  ('mary', 74),
#  ('jack', 63),
#  ('e', 69),
#  ('f', 65),
#  ('g', 82)]

# %%
dt[0][0]
# Out:
# 'yalong'

# %% [markdown]
# ## Data Table = List of Tuples
#
# * `[(1,2,3), (4,5,6)]`
# * row-major format = list of rows
# * column-major format = list of columns
# * https://en.wikipedia.org/wiki/Column-oriented_DBMS

# %%
[print(t) for t in dt]
# Out:
# ('yalong', 67)
# ('chris', 68)
# ('mary', 74)
# ('jack', 63)
# ('e', 69)
# ('f', 65)
# ('g', 82)
# [None, None, None, None, None, None, None]

# %%
[t[0] for t in dt if t[1] >= 72]
# Out:
# ['mary', 'g']

# %%
[name for (name, height) in dt if height >= 72]
# Out:
# ['mary', 'g']

# %%
sorted(dt, key=lambda t:t[1])
# Out:
# [('jack', 63),
#  ('f', 65),
#  ('yalong', 67),
#  ('chris', 68),
#  ('e', 69),
#  ('mary', 74),
#  ('g', 82)]

# %%
sorted(dt, key=lambda (name, height):height)
# Out:
#   Input In [67]
#     sorted(dt, key=lambda (name, height):height)
#                           ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Parsing data from text files
#
# Table = List of Tuples
#
# * `open()`, `read()`, `splitlines()`, `split()`
# * tuple assignment:  `(x,y) = (1,2)`

# %%
text = open('data/pop-table.csv').read()
text
# Out:
# "Name,State,Population\nAleutians East,AK,2305\nAleutians West,AK,5259\nAnchorage,AK,251335\nBethel,AK,15525\nBristol Bay,AK,1023\nDillingham,AK,4360\nFairbanks North Star,AK,83374\nHaines,AK,2181\nJuneau,AK,29378\nKenai Peninsula,AK,46151\nKetchikan Gateway,AK,14422\nKodiak Island,AK,14987\nLake and Peninsula,AK,1787\nMatanuska-Susitna,AK,50686\nNome,AK,8754\nNorth Slope,AK,7024\nNorthwest Arctic,AK,6501\nPrince of Wales-Outer Ketchikan,AK,7109\nSitka,AK,8710\nSkagway-Yakutat-Angoon,AK,4655\nSoutheast Fairbanks,AK,6018\nValdez-Cordova,AK,10475\nWade Hampton,AK,6574\nWrangell-Petersburg,AK,7089\nYukon-Koyukuk,AK,6057\nAutauga,AL,39381\nBaldwin,AL,120198\nBarbour,AL,26469\nBibb,AL,17942\nBlount,AL,42721\nBullock,AL,11149\nButler,AL,21798\nCalhoun,AL,117263\nChambers,AL,37262\nCherokee,AL,21038\nChilton,AL,34912\nChoctaw,AL,16079\nClarke,AL,27993\nClay,AL,13551\nCleburne,AL,13272\nCoffee,AL,42359\nColbert,AL,52586\nConecuh,AL,14022\nCoosa,AL,11680\nCovington,AL,37459\nCrenshaw,AL,13624\nCullman,AL,72489\nDale,AL,50001\nDallas,AL,48022\nDe Kalb,AL,57271\nElmore,AL,57071\nEscambia,AL,36541\nEtowah,AL,100259\nFayette,AL,18019\nFranklin,AL,29313\nGeneva,AL,24727\nGreene,AL,10076\nHale,AL,16212\nHenry,AL,15752\nHouston,AL,84367\nJackson,AL,50128\nJefferson,AL,657827\nLamar,AL,15754\nLauderdale,AL,83598\nLawrence,AL,32803\nLee,AL,94029\nLimestone,AL,59344\nLowndes,AL,12946\nMacon,AL,23959\nMadison,AL,258340\nMarengo,AL,23662\nMarion,AL,30382\nMarshall,AL,78195\nMobile,AL,397413\nMonroe,AL,24550\nMontgomery,AL,218880\nMorgan,AL,107034\nPerry,AL,12708\nPickens,AL,20956\nPike,AL,28848\nRandolph,AL,20323\nRussell,AL,51436\nShelby,AL,123500\nSt. Clair,AL,57713\nSumter,AL,16390\nTalladega,AL,76737\nTallapoosa,AL,39737\nTuscaloosa,AL,158732\nWalker,AL,69678\nWashington,AL,17385\nWilcox,AL,13628\nWinston,AL,23489\nArkansas,AR,21032\nAshley,AR,24651\nBaxter,AR,35666\nBenton,AR,120932\nBoone,AR,31364\nBradley,AR,11650\nCalhoun,AR,5801\nCarroll,AR,21933\nChicot,AR,15289\nClark,AR,22101\nClay,AR,17601\nCleburne,AR,21865\nCleveland,AR,8084\nColumbia,AR,25670\nConway,AR,19671\nCraighead,AR,74794\nCrawford,AR,48100\nCrittenden,AR,49889\nCross,AR,19370\nDallas,AR,9493\nDesha,AR,15487\nDrew,AR,17853\nFaulkner,AR,71758\nFranklin,AR,16122\nFulton,AR,10732\nGarland,AR,81049\nGrant,AR,15022\nGreene,AR,34620\nHempstead,AR,22194\nHot Spring,AR,27876\nHoward,AR,13655\nIndependence,AR,32752\nIzard,AR,12619\nJackson,AR,18622\nJefferson,AR,84042\nJohnson,AR,20508\nLafayette,AR,9213\nLawrence,AR,17468\nLee,AR,12962\nLincoln,AR,14119\nLittle River,AR,13413\nLogan,AR,21050\nLonoke,AR,45966\nMadison,AR,12943\nMarion,AR,13855\nMiller,AR,39082\nMississippi,AR,50811\nMonroe,AR,10374\nMontgomery,AR,8356\nNevada,AR,9996\nNewton,AR,7989\nOuachita,AR,28580\nPerry,AR,8823\nPhillips,AR,27386\nPike,AR,10332\nPoinsett,AR,24640\nPolk,AR,18832\nPope,AR,51181\nPrairie,AR,9312\nPulaski,AR,352240\nRandolph,AR,17430\nSaline,AR,73604\nScott,AR,10628\nSearcy,AR,7626\nSebastian,AR,104402\nSevier,AR,14501\nSharp,AR,16172\nSt. Francis,AR,27859\nStone,AR,10784\nUnion,AR,46191\nVan Buren,AR,15198\nWashington,AR,131708\nWhite,AR,61016\nWoodruff,AR,9121\nYell,AR,18739\nApache,AZ,67803\nCochise,AZ,110062\nCoconino,AZ,110498\nGila,AZ,46039\nGraham,AZ,29589\nGreenlee,AZ,9232\nLa Paz,AZ,14310\nMaricopa,AZ,2432372\nMohave,AZ,121602\nNavajo,AZ,89253\nPima,AZ,752428\nPinal,AZ,131210\nSanta Cruz,AZ,36078\nYavapai,AZ,134595\nYuma,AZ,132869\nAlameda,CA,1323312\nAlpine,CA,1229\nAmador,CA,33162\nButte,CA,192880\nCalaveras,CA,37694\nColusa,CA,17596\nContra Costa,CA,872099\nDel Norte,CA,26956\nEl Dorado,CA,148217\nFresno,CA,737289\nGlenn,CA,26028\nHumboldt,CA,122747\nImperial,CA,138072\nInyo,CA,18435\nKern,CA,617528\nKings,CA,113089\nLake,CA,55783\nLassen,CA,28279\nLos Angeles,CA,9138789\nMadera,CA,107004\nMarin,CA,233883\nMariposa,CA,15772\nMendocino,CA,82499\nMerced,CA,194407\nModoc,CA,9559\nMono,CA,10433\nMonterey,CA,348841\nNapa,CA,115751\nNevada,CA,87318\nOrange,CA,2563971\nPlacer,CA,205239\nPlumas, ...

# %%
lines = text.splitlines()
lines
# Out:
# ['Name,State,Population',
#  'Aleutians East,AK,2305',
#  'Aleutians West,AK,5259',
#  'Anchorage,AK,251335',
#  'Bethel,AK,15525',
#  'Bristol Bay,AK,1023',
#  'Dillingham,AK,4360',
#  'Fairbanks North Star,AK,83374',
#  'Haines,AK,2181',
#  'Juneau,AK,29378',
#  'Kenai Peninsula,AK,46151',
#  'Ketchikan Gateway,AK,14422',
#  'Kodiak Island,AK,14987',
#  'Lake and Peninsula,AK,1787',
#  'Matanuska-Susitna,AK,50686',
#  'Nome,AK,8754',
#  'North Slope,AK,7024',
#  'Northwest Arctic,AK,6501',
#  'Prince of Wales-Outer Ketchikan,AK,7109',
#  'Sitka,AK,8710',
#  'Skagway-Yakutat-Angoon,AK,4655',
#  'Southeast Fairbanks,AK,6018',
#  'Valdez-Cordova,AK,10475',
#  'Wade Hampton,AK,6574',
#  'Wrangell-Petersburg,AK,7089',
#  'Yukon-Koyukuk,AK,6057',
#  'Autauga,AL,39381',
#  'Baldwin,AL,120198',
#  'Barbour,AL,26469',
#  'Bibb,AL,17942',
#  'Blount,AL,42721',
#  'Bullock,AL,11149',
#  'Butler,AL,21798',
#  'Calhoun,AL,117263',
#  'Chambers,AL,37262',
#  'Cherokee,AL,21038',
#  'Chilton,AL,34912',
#  'Choctaw,AL,16079',
#  'Clarke,AL,27993',
#  'Clay,AL,13551',
#  'Cleburne,AL,13272',
#  'Coffee,AL,42359',
#  'Colbert,AL,52586',
#  'Conecuh,AL,14022',
#  'Coosa,AL,11680',
#  'Covington,AL,37459',
#  'Crenshaw,AL,13624',
#  'Cullman,AL,72489',
#  'Dale,AL,50001',
#  'Dallas,AL,48022',
#  'De Kalb,AL,57271',
#  'Elmore,AL,57071',
#  'Escambia,AL,36541',
#  'Etowah,AL,100259',
#  'Fayette,AL,18019',
#  'Franklin,AL,29313',
#  'Geneva,AL,24727',
#  'Greene,AL,10076',
#  'Hale,AL,16212',
#  'Henry,AL,15752',
#  'Houston,AL,84367',
#  'Jackson,AL,50128',
#  'Jefferson,AL,657827',
#  'Lamar,AL,15754',
#  'Lauderdale,AL,83598',
#  'Lawrence,AL,32803',
#  'Lee,AL,94029',
#  'Limestone,AL,59344',
#  'Lowndes,AL,12946',
#  'Macon,AL,23959',
#  'Madison,AL,258340',
#  'Marengo,AL,23662',
#  'Marion,AL,30382',
#  'Marshall,AL,78195',
#  'Mobile,AL,397413',
#  'Monroe,AL,24550',
#  'Montgomery,AL,218880',
#  'Morgan,AL,107034',
#  'Perry,AL,12708',
#  'Pickens,AL,20956',
#  'Pike,AL,28848',
#  'Randolph,AL,20323',
#  'Russell,AL,51436',
#  'Shelby,AL,123500',
#  'St. Clair,AL,57713',
#  'Sumter,AL,16390',
#  'Talladega,AL,76737',
#  'Tallapoosa,AL,39737',
#  'Tuscaloosa,AL,158732',
#  'Walker,AL,69678',
#  'Washington,AL,17385',
#  'Wilcox,AL,13628',
#  'Winston,AL,23489',
#  'Arkansas,AR,21032',
#  'Ashley,AR,24651',
#  'Baxter,AR,35666',
#  'Benton,AR,120932',
#  'Boone,AR,31364',
#  'Bradley,AR,11650',
#  'Calhoun,AR,5801',
#  'Carroll,AR,21933',
#  'Chicot,AR,15289',
#  'Clark,AR,22101',
#  'Clay,AR,17601',
#  'Cleburne,AR,21865',
#  'Cleveland,AR,8084',
#  'Columbia,AR,25670',
#  'Conway,AR,19671',
#  'Craighead,AR,74794',
#  'Crawford,AR,48100',
#  'Crittenden,AR,49889',
#  'Cross,AR,19370',
#  'Dallas,AR,9493',
#  'Desha,AR,15487',
#  'Drew,AR,17853',
#  'Faulkner,AR,71758',
#  'Franklin,AR,16122',
#  'Fulton,AR,10732',
#  'Garland,AR,81049',
#  'Grant,AR,15022',
#  'Greene,AR,34620',
#  'Hempstead,AR,22194',
#  'Hot Spring,AR,27876',
#  'Howard,AR,13655',
#  'Independence,AR,32752',
#  'Izard,AR,12619',
#  'Jackson,AR,18622',
#  'Jefferson,AR,84042',
#  'Johnson,AR,20508',
#  'Lafayette,AR,9213',
#  'Lawrence,AR,17468',
#  'Lee,AR,12962',
#  'Lincoln,AR,14119',
#  'Little River,AR,13413',
#  'Logan,AR,21050',
#  'Lonoke,AR,45966',
#  'Madison,AR,12943',
#  'Marion,AR,13855',
#  'Miller,AR,39082',
#  'Mississippi,AR,50811',
#  'Monroe,AR,10374',
#  'Montgomery,AR,8356',
#  'Nevada,AR,9996',
#  'Newton,AR,7989',
#  'Ouachita,AR,28580',
#  'Perry,AR,8823',
#  'Phillips,AR,27386',
#  'Pike,AR,10332',
#  'Poinsett,AR,24640',
#  'Polk,AR,18832',
#  'Pope,AR,51181',
#  'Prairie,AR,9312',
#  'Pulaski,AR,352240',
#  'Randolph,AR,17430',
#  'Saline,AR,73604',
#  'Scott,AR,10628',
#  'Searcy,AR,7626',
#  'Sebastian,AR,104402',
#  'Sevier,AR,14501',
#  'Sharp,AR,16172',
#  'St. Francis,AR,27859',
#  'Stone,AR,10784',
#  'Union,AR,46191',
#  'Van Buren,AR,15198',
#  'Washington,AR,131708',
#  'White,AR,61016',
#  'Woodruff,AR,9121',
#  'Yell,AR,18739',
#  'Apache,AZ,67803',
#  'Cochise,AZ,110062',
#  'Coconino,AZ,110498',
#  'Gila,AZ,46039',
#  'Graham,AZ,29589',
#  'Greenlee,AZ,9232',
#  'La Paz,AZ,14310',
#  'Maricopa,AZ,2432372',
#  'Mohave,AZ,121602',
#  'Navajo,AZ,89253',
#  'Pima,AZ,752428',
#  'Pinal,AZ,131210',
#  'Santa Cruz,AZ,36078',
#  'Yavapai,AZ,134595',
#  'Yuma,AZ,132869',
#  'Alameda,CA,1323312',
#  'Alpine,CA,1229',
#  'Amador,CA,33162',
#  'Butte,CA,192880',
#  'Calaveras,CA,37694',
#  'Colusa,CA,17596',
#  'Contra Costa,CA,872099',
#  'Del Norte,CA,26956',
#  'El Dorado,CA,148217',
#  'Fresno,CA,737289',
#  'Glenn,CA,26028',
#  'Humboldt,CA,122747',
#  'Imperial,CA,138072',
#  'Inyo,CA,18435',
#  'Kern,CA,617528',
#  'Kings,CA,113089',
#  'Lake,CA,55783',
#  'Lassen,CA,28279',
#  'Los Angeles,CA,9138789',
#  'Madera,CA,107004',
#  'Marin,CA,233883',
#  'Mariposa,CA,15772',
#  'Mendocino,CA,82499',
#  'Merced,CA,194407',
#  'Modoc,CA,9559',
#  'Mono,CA,10433',
#  'Monterey,CA,348841',
#  'Napa,CA,115751',
#  'Nevada,CA,87318',
#  'Orange,CA,2563971',
#  'Placer,CA,205239',
#  'Plumas,CA,20451',
#  'Riverside,CA,1379801',
#  'Sacramento,CA,1103499',
#  'San Benito,CA,42625',
#  'San Bernardino,CA,1569586',
#  'San Diego,CA,2644132',
#  'San Francisco,CA,730570',
#  'San Joaquin,CA,523969',
#  'San Luis Obispo,CA,226071',
#  'San Mateo,CA,681362',
#  'Santa Barbara,CA,381401',
#  'Santa Clara,CA,1565253',
#  'Santa Cruz,CA,236669',
#  'Shasta,CA,160940',
#  'Sierra,CA,3399',
#  'Siskiyou,CA,44253',
#  'Solano,CA,366134',
#  'Sonoma,CA,414569',
#  'Stanislaus,CA,410870',
#  'Sutter,CA,74963',
#  'Tehama,CA,53798',
#  'Trinity,CA,13429',
#  'Tulare,CA,346843',
#  'Tuolumne,CA,51777',
#  'Ventura,CA,710018',
#  'Yolo,CA,147769',
#  'Yuba,CA,61141',
#  'Adams,CO,303297',
#  'Alamosa,CO,14215',
#  'Arapahoe,CO,449103',
#  'Archuleta,CO,7100',
#  'Baca,CO,4384',
#  'Bent,CO,5518',
#  'Boulder,CO,253850',
#  'Chaffee,CO,14413',
#  'Cheyenne,CO,2312',
#  'Clear Creek,CO,8745',
#  'Conejos,CO,7807',
#  'Costilla,CO,3384',
#  'Crowley,CO,4303',
#  'Custer,CO,2702',
#  'Delta,CO,25077',
#  'Denver,CO,494462',
#  'Dolores,CO,1588',
#  'Douglas,CO,99577',
#  'Eagle,CO,28844',
#  'El Paso,CO,465800',
#  'Elbert,CO,14565',
#  'Fremont,CO,39794',
#  'Garfield,CO,35338',
#  'Gilpin,CO,3576',
#  'Grand,CO,9188',
#  'Gunnison,CO,11931',
#  'Hinsdale,CO,648',
#  'Huerfano,CO,6356',
#  'Jackson,CO,1537',
#  'Jefferson,CO,484869',
#  'Kiowa,CO,1627',
#  'Kit Carson,CO,7301',
#  'La Plata,CO,38314',
#  'Lake,CO,6296',
#  'Larimer,CO,217215',
#  'Las Animas,CO,14268',
#  'Lincoln,CO,5602',
#  'Logan,CO,17869',
#  'Mesa,CO,106548',
#  'Mineral,CO,634',
#  'Moffat,CO,12136',
#  'Montezuma,CO,21591',
#  'Montrose,CO,28829',
#  'Morgan,CO,23729',
#  'Otero,CO,20788',
#  'Ouray,CO,3033',
#  'Park,CO,10589',
#  'Phillips,CO,4309',
#  'Pitkin,CO,13589',
#  'Prowers,CO,13591',
#  'Pueblo,CO,129759',
#  'Rio Blanco,CO,6472',
#  'Rio Grande,CO,11262',
#  'Routt,CO,16709',
#  'Saguache,CO,5514',
#  'San Juan,CO,546',
#  'San Miguel,CO,4929',
#  'Sedgwick,CO,2606',
#  'Summit,CO,17204',
#  'Teller,CO,17478',
#  'Washington,CO,4687',
#  'Weld,CO,148014',
#  'Yuma,CO,9264',
#  'Fairfield,CT,830728',
#  'Hartford,CT,835589',
#  'Litchfield,CT,179316',
#  'Middlesex,CT,148030',
#  'New Haven,CT,794785',
#  'New London,CT,250404',
#  'Tolland,CT,131604',
#  'Windham,CT,104206',
#  'Washington,DC,554256',
#  'Kent,DE,121725',
#  'New Castle,DE,467889',
#  'Sussex,DE,127583',
#  'Alachua,FL,196106',
#  'Baker,FL,20153',
#  'Bay,FL,142690',
#  'Bradford,FL,24182',
#  'Brevard,FL,450646',
#  'Broward,FL,1412165',
#  'Calhoun,FL,11858',
#  'Charlotte,FL,129381',
#  'Citrus,FL,107333',
#  'Clay,FL,124431',
#  'Collier,FL,181381',
#  'Columbia,FL,48376',
#  'Dade,FL,2031336',
#  'De Soto,FL,25048',
#  'Dixie,FL,12159',
#  'Duval,FL,701673',
#  'Escambia,FL,273804',
#  'Flagler,FL,40643',
#  'Franklin,FL,10301',
#  'Gadsden,FL,43378',
#  'Gilchrist,FL,12332',
#  'Glades,FL,7665',
#  'Gulf,FL,13390',
#  'Hamilton,FL,11773',
#  'Hardee,FL,19952',
#  'Hendry,FL,28114',
#  'Hernando,FL,120054',
#  'Highlands,FL,74507',
#  'Hillsborough,FL,884608',
#  'Holmes,FL,17520',
#  'Indian River,FL,97144',
#  'Jackson,FL,43891',
#  'Jefferson,FL,12950',
#  'Lafayette,FL,6043',
#  'Lake,FL,180160',
#  'Lee,FL,375381',
#  'Leon,FL,213917',
#  'Levy,FL,29738',
#  'Liberty,FL,6400',
#  'Madison,FL,17231',
#  'Manatee,FL,229864',
#  'Marion,FL,226678',
#  'Martin,FL,111069',
#  'Monroe,FL,81850',
#  'Nassau,FL,50767',
#  'Okaloosa,FL,163707',
#  'Okeechobee,FL,30222',
#  'Orange,FL,749631',
#  'Osceola,FL,130771',
#  'Palm Beach,FL,972093',
#  'Pasco,FL,304938',
#  'Pinellas,FL,870884',
#  'Polk,FL,436701',
#  'Putnam,FL,69481',
#  'Santa Rosa,FL,104110',
#  'Sarasota,FL,295942',
#  'Seminole,FL,330012',
#  'St. Johns,FL,102174',
#  'St. Lucie,FL,172483',
#  'Sumter,FL,34788',
#  'Suwannee,FL,30103',
#  'Taylor,FL,17445',
#  'Union,FL,12433',
#  'Volusia,FL,408261',
#  'Wakulla,FL,17111',
#  'Walton,FL,33615',
#  'Washington,FL,18623',
#  'Appling,GA,16359',
#  'Atkinson,GA,6749',
#  'Bacon,GA,10438',
#  'Baker,GA,3766',
#  'Baldwin,GA,41854',
#  'Banks,GA,11616',
#  'Barrow,GA,35699',
#  'Bartow,GA,63732',
#  'Ben Hill,GA,17258',
#  'Berrien,GA,15466',
#  'Bibb,GA,155066',
#  'Bleckley,GA,10958',
#  'Brantley,GA,12698',
#  'Brooks,GA,15837',
#  'Bryan,GA,21190',
#  'Bulloch,GA,48642',
#  'Burke,GA,21742',
#  'Butts,GA,16025',
#  'Calhoun,GA,4851',
#  'Camden,GA,40714',
#  'Candler,GA,8637',
#  'Carroll,GA,77977',
#  'Catoosa,GA,48008',
#  'Charlton,GA,9296',
#  'Chatham,GA,226160',
#  'Chattahoochee,GA,15871',
#  'Chattooga,GA,22884',
#  'Cherokee,GA,114751',
#  'Clarke,GA,90207',
#  'Clay,GA,3473',
#  'Clayton,GA,198551',
#  'Clinch,GA,6438',
#  'Cobb,GA,525453',
#  'Coffee,GA,32697',
#  'Colquitt,GA,38072',
#  'Columbia,GA,83674',
#  'Cook,GA,13950',
#  'Coweta,GA,72021',
#  'Crawford,GA,10166',
#  'Crisp,GA,20716',
#  'Dade,GA,14158',
#  'Dawson,GA,12237',
#  'De Kalb,GA,582095',
#  'Decatur,GA,26390',
#  'Dodge,GA,17956',
#  'Dooly,GA,10314',
#  'Dougherty,GA,97511',
#  'Douglas,GA,82297',
#  'Early,GA,12198',
#  'Echols,GA,2325',
#  'Effingham,GA,32118',
#  'Elbert,GA,19173',
#  'Emanuel,GA,20954',
#  'Evans,GA,9438',
#  'Fannin,GA,17480',
#  'Fayette,GA,78879',
#  'Floyd,GA,83935',
#  'Forsyth,GA,62335',
#  'Franklin,GA,17701',
#  'Fulton,GA,700689',
#  'Gilmer,GA,15916',
#  'Glascock,GA,2456',
#  'Glynn,GA,65565',
#  'Gordon,GA,38442',
#  'Grady,GA,21312',
#  'Greene,GA,12781',
#  'Gwinnett,GA,457058',
#  'Habersham,GA,30146',
#  'Hall,GA,108238',
#  'Hancock,GA,9100',
#  'Haralson,GA,23378',
#  'Harris,GA,20479',
#  'Hart,GA,20848',
#  'Heard,GA,9573',
#  'Henry,GA,84553',
#  'Houston,GA,99647',
#  'Irwin,GA,8725',
#  'Jackson,GA,33921',
#  'Jasper,GA,9168',
#  'Jeff Davis,GA,12366',
#  'Jefferson,GA,17872',
#  'Jenkins,GA,8658',
#  'Johnson,GA,8436',
#  'Jones,GA,22077',
#  'Lamar,GA,13797',
#  'Lanier,GA,6312',
#  'Laurens,GA,42852',
#  'Lee,GA,19922',
#  'Liberty,GA,58749',
#  'Lincoln,GA,8055',
#  'Long,GA,7885',
#  'Lowndes,GA,82952',
#  'Lumpkin,GA,16822',
#  'Macon,GA,13249',
#  'Madison,GA,23396',
#  'Marion,GA,6370',
#  'McDuffie,GA,21627',
#  'McIntosh,GA,9456',
#  'Meriwether,GA,23041',
#  'Miller,GA,6161',
#  'Mitchell,GA,20859',
#  'Monroe,GA,18950',
#  'Montgomery,GA,7635',
#  'Morgan,GA,14006',
#  'Murray,GA,30032',
#  'Muscogee,GA,184594',
#  'Newton,GA,50644',
#  'Oconee,GA,21190',
#  'Oglethorpe,GA,10911',
#  'Paulding,GA,59920',
#  'Peach,GA,22906',
#  'Pickens,GA,16881',
#  'Pierce,GA,14821',
#  'Pike,GA,11441',
#  'Polk,GA,34771',
#  'Pulaski,GA,8245',
#  'Putnam,GA,15991',
#  'Quitman,GA,2420',
#  'Rabun,GA,12738',
#  'Randolph,GA,8092',
#  'Richmond,GA,195508',
#  'Rockdale,GA,64448',
#  'Schley,GA,3783',
#  'Screven,GA,14336',
#  'Seminole,GA,9097',
#  'Spalding,GA,57306',
#  'Stephens,GA,25000',
#  'Stewart,GA,5438',
#  'Sumter,GA,31245',
#  'Talbot,GA,6741',
#  'Taliaferro,GA,1883',
#  'Tattnall,GA,18588',
#  'Taylor,GA,8048',
#  'Telfair,GA,11623',
#  'Terrell,GA,11007',
#  'Thomas,GA,41419',
#  'Tift,GA,35932',
#  'Toombs,GA,25276',
#  'Towns,GA,7559',
#  'Treutlen,GA,5943',
#  'Troup,GA,57882',
#  'Turner,GA,8916',
#  'Twiggs,GA,10060',
#  'Union,GA,14427',
#  'Upson,GA,26961',
#  'Walker,GA,60654',
#  'Walton,GA,46694',
#  'Ware,GA,35589',
#  'Warren,GA,6057',
#  'Washington,GA,19953',
#  'Wayne,GA,24818',
#  'Webster,GA,2260',
#  'Wheeler,GA,4830',
#  'White,GA,15330',
#  'Whitfield,GA,78033',
#  'Wilcox,GA,7100',
#  'Wilkes,GA,10615',
#  'Wilkinson,GA,10627',
#  'Worth,GA,21643',
#  'Hawaii,HI,137531',
#  'Honolulu,HI,877198',
#  'Kauai,HI,56131',
#  'Maui,HI,115864',
#  'Adair,IA,8286',
#  'Adams,IA,4500',
#  'Allamakee,IA,14079',
#  'Appanoose,IA,13674',
#  'Audubon,IA,6875',
#  'Benton,IA,24137',
#  'Black Hawk,IA,123077',
#  'Boone,IA,25502',
#  'Bremer,IA,23218',
#  'Buchanan,IA,21294',
#  'Buena Vista,IA,20065',
#  'Butler,IA,15745',
#  'Calhoun,IA,11430',
#  'Carroll,IA,21603',
#  'Cass,IA,15047',
#  'Cedar,IA,17682',
#  'Cerro Gordo,IA,46633',
#  'Cherokee,IA,13591',
#  'Chickasaw,IA,13429',
#  'Clarke,IA,8136',
#  'Clay,IA,17412',
#  'Clayton,IA,18833',
#  'Clinton,IA,50889',
#  'Crawford,IA,16461',
#  'Dallas,IA,32947',
#  'Davis,IA,8539',
#  'Decatur,IA,8177',
#  'Delaware,IA,18394',
#  'Des Moines,IA,42679',
#  'Dickinson,IA,15664',
#  'Dubuque,IA,88566',
#  'Emmet,IA,11153',
#  'Fayette,IA,21799',
#  'Floyd,IA,16603',
#  'Franklin,IA,11106',
#  'Fremont,IA,8097',
#  'Greene,IA,10080',
#  'Grundy,IA,12303',
#  'Guthrie,IA,11406',
#  'Hamilton,IA,16193',
#  'Hancock,IA,12184',
#  'Hardin,IA,18685',
#  'Harrison,IA,15115',
#  'Henry,IA,19826',
#  'Howard,IA,9887',
#  'Humboldt,IA,10284',
#  'Ida,IA,8193',
#  'Iowa,IA,15193',
#  'Jackson,IA,20120',
#  'Jasper,IA,35163',
#  'Jefferson,IA,16829',
#  'Johnson,IA,101291',
#  'Jones,IA,20273',
#  'Keokuk,IA,11564',
#  'Kossuth,IA,18147',
#  'Lee,IA,39130',
#  'Linn,IA,178559',
#  'Louisa,IA,11793',
#  'Lucas,IA,9015',
#  'Lyon,IA,11890',
#  'Madison,IA,13490',
#  'Mahaska,IA,21927',
#  'Marion,IA,31102',
#  'Marshall,IA,38627',
#  'Mills,IA,13802',
#  'Mitchell,IA,11129',
#  'Monona,IA,9968',
#  'Monroe,IA,8177',
#  'Montgomery,IA,11939',
#  'Muscatine,IA,41435',
#  "O'Brien,IA,15349",
#  'Osceola,IA,7077',
#  'Page,IA,16676',
#  'Palo Alto,IA,10200',
#  'Plymouth,IA,24220',
#  'Pocahontas,IA,9119',
#  'Polk,IA,349560',
#  'Pottawattamie,IA,83701',
#  'Poweshiek,IA,19014',
#  'Ringgold,IA,5373',
#  'Sac,IA,12087',
#  'Scott,IA,156694',
#  'Shelby,IA,13089',
#  'Sioux,IA,31398',
#  'Story,IA,74638',
#  'Tama,IA,17878',
#  'Taylor,IA,7152',
#  'Union,IA,12416',
#  'Van Buren,IA,7767',
#  'Wapello,IA,35770',
#  'Warren,IA,38940',
#  'Washington,IA,20508',
#  'Wayne,IA,6866',
#  'Webster,IA,39206',
#  'Winnebago,IA,11900',
#  'Winneshiek,IA,21058',
#  'Woodbury,IA,101827',
#  'Worth,IA,7926',
#  'Wright,IA,14314',
#  'Ada,ID,251831',
#  'Adams,ID,3877',
#  'Bannock,ID,72115',
#  'Bear Lake,ID,6600',
#  'Benewah,ID,8780',
#  'Bingham,ID,41188',
#  'Blaine,ID,16471',
#  'Boise,ID,4768',
#  'Bonner,ID,33080',
#  'Bonneville,ID,79531',
#  'Boundary,ID,9548',
#  'Butte,ID,3008',
#  'Camas,ID,848',
#  'Canyon,ID,108510',
#  'Caribou,ID,7280',
#  'Cassia,ID,21095',
#  'Clark,ID,822',
#  'Clearwater,ID,9115',
#  'Custer,ID,4316',
#  'Elmore,ID,23181',
#  'Franklin,ID,10286',
#  'Fremont,ID,11532',
#  'Gem,ID,13856',
#  'Gooding,ID,12980',
#  'Idaho,ID,14789',
#  'Jefferson,ID,18786',
#  'Jerome,ID,17017',
#  'Kootenai,ID,91678',
#  'Latah,ID,32860',
#  'Lemhi,ID,7973',
#  'Lewis,ID,3937',
#  'Lincoln,ID,3729',
#  'Madison,ID,23811',
#  'Minidoka,ID,21065',
#  'Nez Perce,ID,36549',
#  'Oneida,ID,3843',
#  'Owyhee,ID,9520',
#  'Payette,ID,19532',
#  'Power,ID,7986',
#  'Shoshone,ID,14042',
#  'Teton,ID,4706',
#  'Twin Falls,ID,59480',
#  'Valley,ID,7877',
#  'Washington,ID,9463',
#  'Adams,IL,68043',
#  'Alexander,IL,10180',
#  'Bond,IL,15738',
#  'Boone,IL,36180',
#  'Brown,IL,6247',
#  'Bureau,IL,36049',
#  'Calhoun,IL,4948',
#  'Carroll,IL,16872',
#  'Cass,IL,13330',
#  'Champaign,IL,169096',
#  'Christian,IL,34920',
#  'Clark,IL,16284',
#  'Clay,IL,14435',
#  'Clinton,IL,35285',
#  'Coles,IL,52357',
#  'Cook,IL,5136877',
#  'Crawford,IL,19911',
#  'Cumberland,IL,11110',
#  'De Kalb,IL,83441',
#  'De Witt,IL,16824',
#  'Douglas,IL,19799',
#  'Du Page,IL,853458',
#  'Edgar,IL,19984',
#  'Edwards,IL,7262',
#  'Effingham,IL,33009',
#  'Fayette,IL,21235',
#  'Ford,IL,14127',
#  'Franklin,IL,40809',
#  'Fulton,IL,38788',
#  'Gallatin,IL,6779',
#  'Greene,IL,15643',
#  'Grundy,IL,35159',
#  'Hamilton,IL,8525',
#  'Hancock,IL,21292',
#  'Hardin,IL,5184',
#  'Henderson,IL,8432',
#  'Henry,IL,51719',
#  'Iroquois,IL,31411',
#  'Jackson,IL,61502',
#  'Jasper,IL,10591',
#  'Jefferson,IL,38998',
#  'Jersey,IL,21188',
#  'Jo Daviess,IL,21931',
#  'Johnson,IL,12426',
#  'Kane,IL,359950',
#  'Kankakee,IL,102046',
#  'Kendall,IL,45398',
#  'Knox,IL,56070',
#  'La Salle,IL,109955',
#  'Lake,IL,572431',
#  'Lawrence,IL,15918',
#  'Lee,IL,35798',
#  'Livingston,IL,40404',
#  'Logan,IL,31267',
#  'Macon,IL,116414',
#  'Macoupin,IL,48729',
#  'Madison,IL,256458',
#  'Marion,IL,41997',
#  'Marshall,IL,12791',
#  'Mason,IL,16691',
#  'Massac,IL,15370',
#  'McDonough,IL,35519',
#  'McHenry,IL,224677',
#  'McLean,IL,139274',
#  'Menard,IL,12284',
#  'Mercer,IL,17444',
#  'Monroe,IL,24719',
#  'Montgomery,IL,30994',
#  'Morgan,IL,36171',
#  'Moultrie,IL,14168',
#  'Ogle,IL,49406',
#  'Peoria,IL,183377',
#  'Perry,IL,21295',
#  'Piatt,IL,16158',
#  'Pike,IL,17338',
#  'Pope,IL,4691',
#  'Pulaski,IL,7464',
#  'Putnam,IL,5718',
#  'Randolph,IL,34296',
#  'Richland,IL,16788',
#  'Rock Island,IL,149830',
#  'Saline,IL,26521',
#  'Sangamon,IL,184731',
#  'Schuyler,IL,7798',
#  'Scott,IL,5629',
#  'Shelby,IL,22561',
#  'St. Clair,IL,265424',
#  'Stark,IL,6396',
#  'Stephenson,IL,48844',
#  'Tazewell,IL,127602',
#  'Union,IL,18114',
#  'Vermilion,IL,86541',
#  'Wabash,IL,12929',
#  'Warren,IL,18816',
#  'Washington,IL,15238',
#  'Wayne,IL,17208',
#  'White,IL,15903',
#  'Whiteside,IL,60352',
#  'Will,IL,413379',
#  'Williamson,IL,59750',
#  'Winnebago,IL,264952',
#  'Woodford,IL,34576',
#  'Adams,IN,32311',
#  'Allen,IN,308503',
#  'Bartholomew,IN,68065',
#  'Benton,IN,9703',
#  'Blackford,IN,14162',
#  'Boone,IN,41813',
#  'Brown,IN,15098',
#  'Carroll,IN,19505',
#  'Cass,IN,38584',
#  'Clark,IN,91826',
#  'Clay,IN,26306',
#  'Clinton,IN,32594',
#  'Crawford,IN,10442',
#  'Daviess,IN,28603',
#  'De Kalb,IN,37955',
#  'Dearborn,IN,44367',
#  'Decatur,IN,24998',
#  'Delaware,IN,118577',
#  'Dubois,IN,38732',
#  'Elkhart,IN,166994',
#  'Fayette,IN,26430',
#  'Floyd,IN,70058',
#  'Fountain,IN,18060',
#  'Franklin,IN,20957',
#  'Fulton,IN,19922',
#  'Gibson,IN,32165',
#  'Grant,IN,73720',
#  'Greene,IN,32696',
#  'Hamilton,IN,140650',
#  'Hancock,IN,50768',
#  'Harrison,IN,32594',
#  'Hendricks,IN,86620',
#  'Henry,IN,49275',
#  'Howard,IN,83763',
#  'Huntington,IN,36807',
#  'Jackson,IN,40403',
#  'Jasper,IN,27895',
#  'Jay,IN,21901',
#  'Jefferson,IN,30813',
#  'Jennings,IN,26168',
#  'Johnson,IN,101690',
#  'Knox,IN,40194',
#  'Kosciusko,IN,69210',
#  'La Porte,IN,110384',
#  'Lagrange,IN,31653',
#  'Lake,IN,482672',
#  'Lawrence,IN,45097',
#  'Madison,IN,132796',
#  'Marion,IN,817604',
#  'Marshall,IN,44879',
#  'Martin,IN,10545',
#  'Miami,IN,32611',
#  'Monroe,IN,115208',
#  'Montgomery,IN,36090',
#  'Morgan,IN,62115',
#  'Newton,IN,14413',
#  'Noble,IN,40884',
#  'Ohio,IN,5395',
#  'Orange,IN,19011',
#  'Owen,IN,19663',
#  'Parke,IN,16094',
#  'Perry,IN,19129',
#  'Pike,IN,12610',
#  'Porter,IN,140487',
#  'Posey,IN,26493',
#  'Pulaski,IN,12960',
#  'Putnam,IN,32939',
#  'Randolph,IN,27377',
#  'Ripley,IN,26829',
#  'Rush,IN,18456',
#  'Scott,IN,22568',
#  'Shelby,IN,42809',
#  'Spencer,IN,20374',
#  'St. Joseph,IN,258083',
#  'Starke,IN,22620',
#  'Steuben,IN,30060',
#  'Sullivan,IN,19879',
#  'Switzerland,IN,8222',
#  'Tippecanoe,IN,135285',
#  'Tipton,IN,16463',
#  'Union,IN,7292',
#  'Vanderburgh,IN,168065',
#  'Vermillion,IN,16841',
#  'Vigo,IN,106622',
#  'Wabash,IN,34896',
#  'Warren,IN,8394',
#  'Warrick,IN,49380',
#  'Washington,IN,26088',
#  'Wayne,IN,72802',
#  'Wells,IN,26506',
#  'White,IN,24505',
#  'Whitley,IN,29426',
#  'Allen,KS,14739',
#  'Anderson,KS,8000',
#  'Atchison,KS,16258',
#  'Barber,KS,5603',
#  'Barton,KS,28614',
#  'Bourbon,KS,15013',
#  'Brown,KS,11075',
#  'Butler,KS,57746',
#  'Chase,KS,2885',
#  'Chautauqua,KS,4439',
#  'Cherokee,KS,22437',
#  'Cheyenne,KS,3230',
#  'Clark,KS,2379',
#  'Clay,KS,9317',
#  'Cloud,KS,10488',
#  'Coffey,KS,8691',
#  'Comanche,KS,2099',
#  'Cowley,KS,37107',
#  'Crawford,KS,36488',
#  'Decatur,KS,3547',
#  'Dickinson,KS,19911',
#  'Doniphan,KS,7608',
#  'Douglas,KS,88206',
#  'Edwards,KS,3564',
#  'Elk,KS,3356',
#  'Ellis,KS,26145',
#  'Ellsworth,KS,6445',
#  'Finney,KS,34913',
#  'Ford,KS,28909',
#  'Franklin,KS,23164',
#  'Geary,KS,29638',
#  'Gove,KS,3091',
#  'Graham,KS,3336',
#  'Grant,KS,7837',
#  'Gray,KS,5367',
#  'Greeley,KS,1834',
#  'Greenwood,KS,8032',
#  'Hamilton,KS,2343',
#  'Harper,KS,6651',
#  'Harvey,KS,31145',
#  'Haskell,KS,4027',
#  'Hodgeman,KS,2268',
#  'Jackson,KS,11809',
#  'Jefferson,KS,17133',
#  'Jewell,KS,3952',
#  'Johnson,KS,401054',
#  'Kearny,KS,4182',
#  'Kingman,KS,8566',
#  'Kiowa,KS,3605',
#  'Labette,KS,22862',
#  'Lane,KS,2275',
#  'Leavenworth,KS,69323',
#  'Lincoln,KS,3431',
#  'Linn,KS,8698',
#  'Logan,KS,3178',
#  'Lyon,KS,34650',
#  'Marion,KS,12961',
#  'Marshall,KS,11261',
#  'McPherson,KS,27267',
#  'Meade,KS,4355',
#  'Miami,KS,25187',
#  'Mitchell,KS,7092',
#  'Montgomery,KS,37694',
#  'Morris,KS,6327',
#  'Morton,KS,3303',
#  'Nemaha,KS,10443',
#  'Neosho,KS,16994',
#  'Ness,KS,3752',
#  'Norton,KS,5735',
#  'Osage,KS,16729',
#  'Osborne,KS,4696',
#  'Ottawa,KS,5749',
#  'Pawnee,KS,7615',
#  'Phillips,KS,6270',
#  'Pottawatomie,KS,17548',
#  'Pratt,KS,9696',
#  'Rawlins,KS,3234',
#  'Reno,KS,63263',
#  'Republic,KS,6215',
#  'Rice,KS,10086',
#  'Riley,KS,69784',
#  'Rooks,KS,5884',
#  'Rush,KS,3541',
#  'Russell,KS,7701',
#  'Saline,KS,51831',
#  'Scott,KS,5074',
#  'Sedgwick,KS,419333',
#  'Seward,KS,19370',
#  'Shawnee,KS,165062',
#  'Sheridan,KS,2824',
#  'Sherman,KS,6706',
#  'Smith,KS,4782',
#  'Stafford,KS,5193',
#  'Stanton,KS,2331',
#  'Stevens,KS,5257',
#  'Sumner,KS,26519',
#  'Thomas,KS,8331',
#  'Trego,KS,3449',
#  'Wabaunsee,KS,6603',
#  'Wallace,KS,1798',
#  'Washington,KS,6833',
#  'Wichita,KS,2841',
#  'Wilson,KS,10321',
#  'Woodson,KS,3999',
#  'Wyandotte,KS,153826',
#  'Adair,KY,16292',
#  'Allen,KY,15706',
#  'Anderson,KY,17152',
#  'Ballard,KY,8232',
#  'Barren,KY,35768',
#  'Bath,KY,10159',
#  'Bell,KY,30490',
#  'Boone,KY,70097',
#  'Bourbon,KY,19257',
#  'Boyd,KY,50613',
#  'Boyle,KY,26699',
#  'Bracken,KY,8209',
#  ...]

# %%
dt2 = [tuple(l.split(',')) for l in lines[1:]]
dt2
# Out:
# [('Aleutians East', 'AK', '2305'),
#  ('Aleutians West', 'AK', '5259'),
#  ('Anchorage', 'AK', '251335'),
#  ('Bethel', 'AK', '15525'),
#  ('Bristol Bay', 'AK', '1023'),
#  ('Dillingham', 'AK', '4360'),
#  ('Fairbanks North Star', 'AK', '83374'),
#  ('Haines', 'AK', '2181'),
#  ('Juneau', 'AK', '29378'),
#  ('Kenai Peninsula', 'AK', '46151'),
#  ('Ketchikan Gateway', 'AK', '14422'),
#  ('Kodiak Island', 'AK', '14987'),
#  ('Lake and Peninsula', 'AK', '1787'),
#  ('Matanuska-Susitna', 'AK', '50686'),
#  ('Nome', 'AK', '8754'),
#  ('North Slope', 'AK', '7024'),
#  ('Northwest Arctic', 'AK', '6501'),
#  ('Prince of Wales-Outer Ketchikan', 'AK', '7109'),
#  ('Sitka', 'AK', '8710'),
#  ('Skagway-Yakutat-Angoon', 'AK', '4655'),
#  ('Southeast Fairbanks', 'AK', '6018'),
#  ('Valdez-Cordova', 'AK', '10475'),
#  ('Wade Hampton', 'AK', '6574'),
#  ('Wrangell-Petersburg', 'AK', '7089'),
#  ('Yukon-Koyukuk', 'AK', '6057'),
#  ('Autauga', 'AL', '39381'),
#  ('Baldwin', 'AL', '120198'),
#  ('Barbour', 'AL', '26469'),
#  ('Bibb', 'AL', '17942'),
#  ('Blount', 'AL', '42721'),
#  ('Bullock', 'AL', '11149'),
#  ('Butler', 'AL', '21798'),
#  ('Calhoun', 'AL', '117263'),
#  ('Chambers', 'AL', '37262'),
#  ('Cherokee', 'AL', '21038'),
#  ('Chilton', 'AL', '34912'),
#  ('Choctaw', 'AL', '16079'),
#  ('Clarke', 'AL', '27993'),
#  ('Clay', 'AL', '13551'),
#  ('Cleburne', 'AL', '13272'),
#  ('Coffee', 'AL', '42359'),
#  ('Colbert', 'AL', '52586'),
#  ('Conecuh', 'AL', '14022'),
#  ('Coosa', 'AL', '11680'),
#  ('Covington', 'AL', '37459'),
#  ('Crenshaw', 'AL', '13624'),
#  ('Cullman', 'AL', '72489'),
#  ('Dale', 'AL', '50001'),
#  ('Dallas', 'AL', '48022'),
#  ('De Kalb', 'AL', '57271'),
#  ('Elmore', 'AL', '57071'),
#  ('Escambia', 'AL', '36541'),
#  ('Etowah', 'AL', '100259'),
#  ('Fayette', 'AL', '18019'),
#  ('Franklin', 'AL', '29313'),
#  ('Geneva', 'AL', '24727'),
#  ('Greene', 'AL', '10076'),
#  ('Hale', 'AL', '16212'),
#  ('Henry', 'AL', '15752'),
#  ('Houston', 'AL', '84367'),
#  ('Jackson', 'AL', '50128'),
#  ('Jefferson', 'AL', '657827'),
#  ('Lamar', 'AL', '15754'),
#  ('Lauderdale', 'AL', '83598'),
#  ('Lawrence', 'AL', '32803'),
#  ('Lee', 'AL', '94029'),
#  ('Limestone', 'AL', '59344'),
#  ('Lowndes', 'AL', '12946'),
#  ('Macon', 'AL', '23959'),
#  ('Madison', 'AL', '258340'),
#  ('Marengo', 'AL', '23662'),
#  ('Marion', 'AL', '30382'),
#  ('Marshall', 'AL', '78195'),
#  ('Mobile', 'AL', '397413'),
#  ('Monroe', 'AL', '24550'),
#  ('Montgomery', 'AL', '218880'),
#  ('Morgan', 'AL', '107034'),
#  ('Perry', 'AL', '12708'),
#  ('Pickens', 'AL', '20956'),
#  ('Pike', 'AL', '28848'),
#  ('Randolph', 'AL', '20323'),
#  ('Russell', 'AL', '51436'),
#  ('Shelby', 'AL', '123500'),
#  ('St. Clair', 'AL', '57713'),
#  ('Sumter', 'AL', '16390'),
#  ('Talladega', 'AL', '76737'),
#  ('Tallapoosa', 'AL', '39737'),
#  ('Tuscaloosa', 'AL', '158732'),
#  ('Walker', 'AL', '69678'),
#  ('Washington', 'AL', '17385'),
#  ('Wilcox', 'AL', '13628'),
#  ('Winston', 'AL', '23489'),
#  ('Arkansas', 'AR', '21032'),
#  ('Ashley', 'AR', '24651'),
#  ('Baxter', 'AR', '35666'),
#  ('Benton', 'AR', '120932'),
#  ('Boone', 'AR', '31364'),
#  ('Bradley', 'AR', '11650'),
#  ('Calhoun', 'AR', '5801'),
#  ('Carroll', 'AR', '21933'),
#  ('Chicot', 'AR', '15289'),
#  ('Clark', 'AR', '22101'),
#  ('Clay', 'AR', '17601'),
#  ('Cleburne', 'AR', '21865'),
#  ('Cleveland', 'AR', '8084'),
#  ('Columbia', 'AR', '25670'),
#  ('Conway', 'AR', '19671'),
#  ('Craighead', 'AR', '74794'),
#  ('Crawford', 'AR', '48100'),
#  ('Crittenden', 'AR', '49889'),
#  ('Cross', 'AR', '19370'),
#  ('Dallas', 'AR', '9493'),
#  ('Desha', 'AR', '15487'),
#  ('Drew', 'AR', '17853'),
#  ('Faulkner', 'AR', '71758'),
#  ('Franklin', 'AR', '16122'),
#  ('Fulton', 'AR', '10732'),
#  ('Garland', 'AR', '81049'),
#  ('Grant', 'AR', '15022'),
#  ('Greene', 'AR', '34620'),
#  ('Hempstead', 'AR', '22194'),
#  ('Hot Spring', 'AR', '27876'),
#  ('Howard', 'AR', '13655'),
#  ('Independence', 'AR', '32752'),
#  ('Izard', 'AR', '12619'),
#  ('Jackson', 'AR', '18622'),
#  ('Jefferson', 'AR', '84042'),
#  ('Johnson', 'AR', '20508'),
#  ('Lafayette', 'AR', '9213'),
#  ('Lawrence', 'AR', '17468'),
#  ('Lee', 'AR', '12962'),
#  ('Lincoln', 'AR', '14119'),
#  ('Little River', 'AR', '13413'),
#  ('Logan', 'AR', '21050'),
#  ('Lonoke', 'AR', '45966'),
#  ('Madison', 'AR', '12943'),
#  ('Marion', 'AR', '13855'),
#  ('Miller', 'AR', '39082'),
#  ('Mississippi', 'AR', '50811'),
#  ('Monroe', 'AR', '10374'),
#  ('Montgomery', 'AR', '8356'),
#  ('Nevada', 'AR', '9996'),
#  ('Newton', 'AR', '7989'),
#  ('Ouachita', 'AR', '28580'),
#  ('Perry', 'AR', '8823'),
#  ('Phillips', 'AR', '27386'),
#  ('Pike', 'AR', '10332'),
#  ('Poinsett', 'AR', '24640'),
#  ('Polk', 'AR', '18832'),
#  ('Pope', 'AR', '51181'),
#  ('Prairie', 'AR', '9312'),
#  ('Pulaski', 'AR', '352240'),
#  ('Randolph', 'AR', '17430'),
#  ('Saline', 'AR', '73604'),
#  ('Scott', 'AR', '10628'),
#  ('Searcy', 'AR', '7626'),
#  ('Sebastian', 'AR', '104402'),
#  ('Sevier', 'AR', '14501'),
#  ('Sharp', 'AR', '16172'),
#  ('St. Francis', 'AR', '27859'),
#  ('Stone', 'AR', '10784'),
#  ('Union', 'AR', '46191'),
#  ('Van Buren', 'AR', '15198'),
#  ('Washington', 'AR', '131708'),
#  ('White', 'AR', '61016'),
#  ('Woodruff', 'AR', '9121'),
#  ('Yell', 'AR', '18739'),
#  ('Apache', 'AZ', '67803'),
#  ('Cochise', 'AZ', '110062'),
#  ('Coconino', 'AZ', '110498'),
#  ('Gila', 'AZ', '46039'),
#  ('Graham', 'AZ', '29589'),
#  ('Greenlee', 'AZ', '9232'),
#  ('La Paz', 'AZ', '14310'),
#  ('Maricopa', 'AZ', '2432372'),
#  ('Mohave', 'AZ', '121602'),
#  ('Navajo', 'AZ', '89253'),
#  ('Pima', 'AZ', '752428'),
#  ('Pinal', 'AZ', '131210'),
#  ('Santa Cruz', 'AZ', '36078'),
#  ('Yavapai', 'AZ', '134595'),
#  ('Yuma', 'AZ', '132869'),
#  ('Alameda', 'CA', '1323312'),
#  ('Alpine', 'CA', '1229'),
#  ('Amador', 'CA', '33162'),
#  ('Butte', 'CA', '192880'),
#  ('Calaveras', 'CA', '37694'),
#  ('Colusa', 'CA', '17596'),
#  ('Contra Costa', 'CA', '872099'),
#  ('Del Norte', 'CA', '26956'),
#  ('El Dorado', 'CA', '148217'),
#  ('Fresno', 'CA', '737289'),
#  ('Glenn', 'CA', '26028'),
#  ('Humboldt', 'CA', '122747'),
#  ('Imperial', 'CA', '138072'),
#  ('Inyo', 'CA', '18435'),
#  ('Kern', 'CA', '617528'),
#  ('Kings', 'CA', '113089'),
#  ('Lake', 'CA', '55783'),
#  ('Lassen', 'CA', '28279'),
#  ('Los Angeles', 'CA', '9138789'),
#  ('Madera', 'CA', '107004'),
#  ('Marin', 'CA', '233883'),
#  ('Mariposa', 'CA', '15772'),
#  ('Mendocino', 'CA', '82499'),
#  ('Merced', 'CA', '194407'),
#  ('Modoc', 'CA', '9559'),
#  ('Mono', 'CA', '10433'),
#  ('Monterey', 'CA', '348841'),
#  ('Napa', 'CA', '115751'),
#  ('Nevada', 'CA', '87318'),
#  ('Orange', 'CA', '2563971'),
#  ('Placer', 'CA', '205239'),
#  ('Plumas', 'CA', '20451'),
#  ('Riverside', 'CA', '1379801'),
#  ('Sacramento', 'CA', '1103499'),
#  ('San Benito', 'CA', '42625'),
#  ('San Bernardino', 'CA', '1569586'),
#  ('San Diego', 'CA', '2644132'),
#  ('San Francisco', 'CA', '730570'),
#  ('San Joaquin', 'CA', '523969'),
#  ('San Luis Obispo', 'CA', '226071'),
#  ('San Mateo', 'CA', '681362'),
#  ('Santa Barbara', 'CA', '381401'),
#  ('Santa Clara', 'CA', '1565253'),
#  ('Santa Cruz', 'CA', '236669'),
#  ('Shasta', 'CA', '160940'),
#  ('Sierra', 'CA', '3399'),
#  ('Siskiyou', 'CA', '44253'),
#  ('Solano', 'CA', '366134'),
#  ('Sonoma', 'CA', '414569'),
#  ('Stanislaus', 'CA', '410870'),
#  ('Sutter', 'CA', '74963'),
#  ('Tehama', 'CA', '53798'),
#  ('Trinity', 'CA', '13429'),
#  ('Tulare', 'CA', '346843'),
#  ('Tuolumne', 'CA', '51777'),
#  ('Ventura', 'CA', '710018'),
#  ('Yolo', 'CA', '147769'),
#  ('Yuba', 'CA', '61141'),
#  ('Adams', 'CO', '303297'),
#  ('Alamosa', 'CO', '14215'),
#  ('Arapahoe', 'CO', '449103'),
#  ('Archuleta', 'CO', '7100'),
#  ('Baca', 'CO', '4384'),
#  ('Bent', 'CO', '5518'),
#  ('Boulder', 'CO', '253850'),
#  ('Chaffee', 'CO', '14413'),
#  ('Cheyenne', 'CO', '2312'),
#  ('Clear Creek', 'CO', '8745'),
#  ('Conejos', 'CO', '7807'),
#  ('Costilla', 'CO', '3384'),
#  ('Crowley', 'CO', '4303'),
#  ('Custer', 'CO', '2702'),
#  ('Delta', 'CO', '25077'),
#  ('Denver', 'CO', '494462'),
#  ('Dolores', 'CO', '1588'),
#  ('Douglas', 'CO', '99577'),
#  ('Eagle', 'CO', '28844'),
#  ('El Paso', 'CO', '465800'),
#  ('Elbert', 'CO', '14565'),
#  ('Fremont', 'CO', '39794'),
#  ('Garfield', 'CO', '35338'),
#  ('Gilpin', 'CO', '3576'),
#  ('Grand', 'CO', '9188'),
#  ('Gunnison', 'CO', '11931'),
#  ('Hinsdale', 'CO', '648'),
#  ('Huerfano', 'CO', '6356'),
#  ('Jackson', 'CO', '1537'),
#  ('Jefferson', 'CO', '484869'),
#  ('Kiowa', 'CO', '1627'),
#  ('Kit Carson', 'CO', '7301'),
#  ('La Plata', 'CO', '38314'),
#  ('Lake', 'CO', '6296'),
#  ('Larimer', 'CO', '217215'),
#  ('Las Animas', 'CO', '14268'),
#  ('Lincoln', 'CO', '5602'),
#  ('Logan', 'CO', '17869'),
#  ('Mesa', 'CO', '106548'),
#  ('Mineral', 'CO', '634'),
#  ('Moffat', 'CO', '12136'),
#  ('Montezuma', 'CO', '21591'),
#  ('Montrose', 'CO', '28829'),
#  ('Morgan', 'CO', '23729'),
#  ('Otero', 'CO', '20788'),
#  ('Ouray', 'CO', '3033'),
#  ('Park', 'CO', '10589'),
#  ('Phillips', 'CO', '4309'),
#  ('Pitkin', 'CO', '13589'),
#  ('Prowers', 'CO', '13591'),
#  ('Pueblo', 'CO', '129759'),
#  ('Rio Blanco', 'CO', '6472'),
#  ('Rio Grande', 'CO', '11262'),
#  ('Routt', 'CO', '16709'),
#  ('Saguache', 'CO', '5514'),
#  ('San Juan', 'CO', '546'),
#  ('San Miguel', 'CO', '4929'),
#  ('Sedgwick', 'CO', '2606'),
#  ('Summit', 'CO', '17204'),
#  ('Teller', 'CO', '17478'),
#  ('Washington', 'CO', '4687'),
#  ('Weld', 'CO', '148014'),
#  ('Yuma', 'CO', '9264'),
#  ('Fairfield', 'CT', '830728'),
#  ('Hartford', 'CT', '835589'),
#  ('Litchfield', 'CT', '179316'),
#  ('Middlesex', 'CT', '148030'),
#  ('New Haven', 'CT', '794785'),
#  ('New London', 'CT', '250404'),
#  ('Tolland', 'CT', '131604'),
#  ('Windham', 'CT', '104206'),
#  ('Washington', 'DC', '554256'),
#  ('Kent', 'DE', '121725'),
#  ('New Castle', 'DE', '467889'),
#  ('Sussex', 'DE', '127583'),
#  ('Alachua', 'FL', '196106'),
#  ('Baker', 'FL', '20153'),
#  ('Bay', 'FL', '142690'),
#  ('Bradford', 'FL', '24182'),
#  ('Brevard', 'FL', '450646'),
#  ('Broward', 'FL', '1412165'),
#  ('Calhoun', 'FL', '11858'),
#  ('Charlotte', 'FL', '129381'),
#  ('Citrus', 'FL', '107333'),
#  ('Clay', 'FL', '124431'),
#  ('Collier', 'FL', '181381'),
#  ('Columbia', 'FL', '48376'),
#  ('Dade', 'FL', '2031336'),
#  ('De Soto', 'FL', '25048'),
#  ('Dixie', 'FL', '12159'),
#  ('Duval', 'FL', '701673'),
#  ('Escambia', 'FL', '273804'),
#  ('Flagler', 'FL', '40643'),
#  ('Franklin', 'FL', '10301'),
#  ('Gadsden', 'FL', '43378'),
#  ('Gilchrist', 'FL', '12332'),
#  ('Glades', 'FL', '7665'),
#  ('Gulf', 'FL', '13390'),
#  ('Hamilton', 'FL', '11773'),
#  ('Hardee', 'FL', '19952'),
#  ('Hendry', 'FL', '28114'),
#  ('Hernando', 'FL', '120054'),
#  ('Highlands', 'FL', '74507'),
#  ('Hillsborough', 'FL', '884608'),
#  ('Holmes', 'FL', '17520'),
#  ('Indian River', 'FL', '97144'),
#  ('Jackson', 'FL', '43891'),
#  ('Jefferson', 'FL', '12950'),
#  ('Lafayette', 'FL', '6043'),
#  ('Lake', 'FL', '180160'),
#  ('Lee', 'FL', '375381'),
#  ('Leon', 'FL', '213917'),
#  ('Levy', 'FL', '29738'),
#  ('Liberty', 'FL', '6400'),
#  ('Madison', 'FL', '17231'),
#  ('Manatee', 'FL', '229864'),
#  ('Marion', 'FL', '226678'),
#  ('Martin', 'FL', '111069'),
#  ('Monroe', 'FL', '81850'),
#  ('Nassau', 'FL', '50767'),
#  ('Okaloosa', 'FL', '163707'),
#  ('Okeechobee', 'FL', '30222'),
#  ('Orange', 'FL', '749631'),
#  ('Osceola', 'FL', '130771'),
#  ('Palm Beach', 'FL', '972093'),
#  ('Pasco', 'FL', '304938'),
#  ('Pinellas', 'FL', '870884'),
#  ('Polk', 'FL', '436701'),
#  ('Putnam', 'FL', '69481'),
#  ('Santa Rosa', 'FL', '104110'),
#  ('Sarasota', 'FL', '295942'),
#  ('Seminole', 'FL', '330012'),
#  ('St. Johns', 'FL', '102174'),
#  ('St. Lucie', 'FL', '172483'),
#  ('Sumter', 'FL', '34788'),
#  ('Suwannee', 'FL', '30103'),
#  ('Taylor', 'FL', '17445'),
#  ('Union', 'FL', '12433'),
#  ('Volusia', 'FL', '408261'),
#  ('Wakulla', 'FL', '17111'),
#  ('Walton', 'FL', '33615'),
#  ('Washington', 'FL', '18623'),
#  ('Appling', 'GA', '16359'),
#  ('Atkinson', 'GA', '6749'),
#  ('Bacon', 'GA', '10438'),
#  ('Baker', 'GA', '3766'),
#  ('Baldwin', 'GA', '41854'),
#  ('Banks', 'GA', '11616'),
#  ('Barrow', 'GA', '35699'),
#  ('Bartow', 'GA', '63732'),
#  ('Ben Hill', 'GA', '17258'),
#  ('Berrien', 'GA', '15466'),
#  ('Bibb', 'GA', '155066'),
#  ('Bleckley', 'GA', '10958'),
#  ('Brantley', 'GA', '12698'),
#  ('Brooks', 'GA', '15837'),
#  ('Bryan', 'GA', '21190'),
#  ('Bulloch', 'GA', '48642'),
#  ('Burke', 'GA', '21742'),
#  ('Butts', 'GA', '16025'),
#  ('Calhoun', 'GA', '4851'),
#  ('Camden', 'GA', '40714'),
#  ('Candler', 'GA', '8637'),
#  ('Carroll', 'GA', '77977'),
#  ('Catoosa', 'GA', '48008'),
#  ('Charlton', 'GA', '9296'),
#  ('Chatham', 'GA', '226160'),
#  ('Chattahoochee', 'GA', '15871'),
#  ('Chattooga', 'GA', '22884'),
#  ('Cherokee', 'GA', '114751'),
#  ('Clarke', 'GA', '90207'),
#  ('Clay', 'GA', '3473'),
#  ('Clayton', 'GA', '198551'),
#  ('Clinch', 'GA', '6438'),
#  ('Cobb', 'GA', '525453'),
#  ('Coffee', 'GA', '32697'),
#  ('Colquitt', 'GA', '38072'),
#  ('Columbia', 'GA', '83674'),
#  ('Cook', 'GA', '13950'),
#  ('Coweta', 'GA', '72021'),
#  ('Crawford', 'GA', '10166'),
#  ('Crisp', 'GA', '20716'),
#  ('Dade', 'GA', '14158'),
#  ('Dawson', 'GA', '12237'),
#  ('De Kalb', 'GA', '582095'),
#  ('Decatur', 'GA', '26390'),
#  ('Dodge', 'GA', '17956'),
#  ('Dooly', 'GA', '10314'),
#  ('Dougherty', 'GA', '97511'),
#  ('Douglas', 'GA', '82297'),
#  ('Early', 'GA', '12198'),
#  ('Echols', 'GA', '2325'),
#  ('Effingham', 'GA', '32118'),
#  ('Elbert', 'GA', '19173'),
#  ('Emanuel', 'GA', '20954'),
#  ('Evans', 'GA', '9438'),
#  ('Fannin', 'GA', '17480'),
#  ('Fayette', 'GA', '78879'),
#  ('Floyd', 'GA', '83935'),
#  ('Forsyth', 'GA', '62335'),
#  ('Franklin', 'GA', '17701'),
#  ('Fulton', 'GA', '700689'),
#  ('Gilmer', 'GA', '15916'),
#  ('Glascock', 'GA', '2456'),
#  ('Glynn', 'GA', '65565'),
#  ('Gordon', 'GA', '38442'),
#  ('Grady', 'GA', '21312'),
#  ('Greene', 'GA', '12781'),
#  ('Gwinnett', 'GA', '457058'),
#  ('Habersham', 'GA', '30146'),
#  ('Hall', 'GA', '108238'),
#  ('Hancock', 'GA', '9100'),
#  ('Haralson', 'GA', '23378'),
#  ('Harris', 'GA', '20479'),
#  ('Hart', 'GA', '20848'),
#  ('Heard', 'GA', '9573'),
#  ('Henry', 'GA', '84553'),
#  ('Houston', 'GA', '99647'),
#  ('Irwin', 'GA', '8725'),
#  ('Jackson', 'GA', '33921'),
#  ('Jasper', 'GA', '9168'),
#  ('Jeff Davis', 'GA', '12366'),
#  ('Jefferson', 'GA', '17872'),
#  ('Jenkins', 'GA', '8658'),
#  ('Johnson', 'GA', '8436'),
#  ('Jones', 'GA', '22077'),
#  ('Lamar', 'GA', '13797'),
#  ('Lanier', 'GA', '6312'),
#  ('Laurens', 'GA', '42852'),
#  ('Lee', 'GA', '19922'),
#  ('Liberty', 'GA', '58749'),
#  ('Lincoln', 'GA', '8055'),
#  ('Long', 'GA', '7885'),
#  ('Lowndes', 'GA', '82952'),
#  ('Lumpkin', 'GA', '16822'),
#  ('Macon', 'GA', '13249'),
#  ('Madison', 'GA', '23396'),
#  ('Marion', 'GA', '6370'),
#  ('McDuffie', 'GA', '21627'),
#  ('McIntosh', 'GA', '9456'),
#  ('Meriwether', 'GA', '23041'),
#  ('Miller', 'GA', '6161'),
#  ('Mitchell', 'GA', '20859'),
#  ('Monroe', 'GA', '18950'),
#  ('Montgomery', 'GA', '7635'),
#  ('Morgan', 'GA', '14006'),
#  ('Murray', 'GA', '30032'),
#  ('Muscogee', 'GA', '184594'),
#  ('Newton', 'GA', '50644'),
#  ('Oconee', 'GA', '21190'),
#  ('Oglethorpe', 'GA', '10911'),
#  ('Paulding', 'GA', '59920'),
#  ('Peach', 'GA', '22906'),
#  ('Pickens', 'GA', '16881'),
#  ('Pierce', 'GA', '14821'),
#  ('Pike', 'GA', '11441'),
#  ('Polk', 'GA', '34771'),
#  ('Pulaski', 'GA', '8245'),
#  ('Putnam', 'GA', '15991'),
#  ('Quitman', 'GA', '2420'),
#  ('Rabun', 'GA', '12738'),
#  ('Randolph', 'GA', '8092'),
#  ('Richmond', 'GA', '195508'),
#  ('Rockdale', 'GA', '64448'),
#  ('Schley', 'GA', '3783'),
#  ('Screven', 'GA', '14336'),
#  ('Seminole', 'GA', '9097'),
#  ('Spalding', 'GA', '57306'),
#  ('Stephens', 'GA', '25000'),
#  ('Stewart', 'GA', '5438'),
#  ('Sumter', 'GA', '31245'),
#  ('Talbot', 'GA', '6741'),
#  ('Taliaferro', 'GA', '1883'),
#  ('Tattnall', 'GA', '18588'),
#  ('Taylor', 'GA', '8048'),
#  ('Telfair', 'GA', '11623'),
#  ('Terrell', 'GA', '11007'),
#  ('Thomas', 'GA', '41419'),
#  ('Tift', 'GA', '35932'),
#  ('Toombs', 'GA', '25276'),
#  ('Towns', 'GA', '7559'),
#  ('Treutlen', 'GA', '5943'),
#  ('Troup', 'GA', '57882'),
#  ('Turner', 'GA', '8916'),
#  ('Twiggs', 'GA', '10060'),
#  ('Union', 'GA', '14427'),
#  ('Upson', 'GA', '26961'),
#  ('Walker', 'GA', '60654'),
#  ('Walton', 'GA', '46694'),
#  ('Ware', 'GA', '35589'),
#  ('Warren', 'GA', '6057'),
#  ('Washington', 'GA', '19953'),
#  ('Wayne', 'GA', '24818'),
#  ('Webster', 'GA', '2260'),
#  ('Wheeler', 'GA', '4830'),
#  ('White', 'GA', '15330'),
#  ('Whitfield', 'GA', '78033'),
#  ('Wilcox', 'GA', '7100'),
#  ('Wilkes', 'GA', '10615'),
#  ('Wilkinson', 'GA', '10627'),
#  ('Worth', 'GA', '21643'),
#  ('Hawaii', 'HI', '137531'),
#  ('Honolulu', 'HI', '877198'),
#  ('Kauai', 'HI', '56131'),
#  ('Maui', 'HI', '115864'),
#  ('Adair', 'IA', '8286'),
#  ('Adams', 'IA', '4500'),
#  ('Allamakee', 'IA', '14079'),
#  ('Appanoose', 'IA', '13674'),
#  ('Audubon', 'IA', '6875'),
#  ('Benton', 'IA', '24137'),
#  ('Black Hawk', 'IA', '123077'),
#  ('Boone', 'IA', '25502'),
#  ('Bremer', 'IA', '23218'),
#  ('Buchanan', 'IA', '21294'),
#  ('Buena Vista', 'IA', '20065'),
#  ('Butler', 'IA', '15745'),
#  ('Calhoun', 'IA', '11430'),
#  ('Carroll', 'IA', '21603'),
#  ('Cass', 'IA', '15047'),
#  ('Cedar', 'IA', '17682'),
#  ('Cerro Gordo', 'IA', '46633'),
#  ('Cherokee', 'IA', '13591'),
#  ('Chickasaw', 'IA', '13429'),
#  ('Clarke', 'IA', '8136'),
#  ('Clay', 'IA', '17412'),
#  ('Clayton', 'IA', '18833'),
#  ('Clinton', 'IA', '50889'),
#  ('Crawford', 'IA', '16461'),
#  ('Dallas', 'IA', '32947'),
#  ('Davis', 'IA', '8539'),
#  ('Decatur', 'IA', '8177'),
#  ('Delaware', 'IA', '18394'),
#  ('Des Moines', 'IA', '42679'),
#  ('Dickinson', 'IA', '15664'),
#  ('Dubuque', 'IA', '88566'),
#  ('Emmet', 'IA', '11153'),
#  ('Fayette', 'IA', '21799'),
#  ('Floyd', 'IA', '16603'),
#  ('Franklin', 'IA', '11106'),
#  ('Fremont', 'IA', '8097'),
#  ('Greene', 'IA', '10080'),
#  ('Grundy', 'IA', '12303'),
#  ('Guthrie', 'IA', '11406'),
#  ('Hamilton', 'IA', '16193'),
#  ('Hancock', 'IA', '12184'),
#  ('Hardin', 'IA', '18685'),
#  ('Harrison', 'IA', '15115'),
#  ('Henry', 'IA', '19826'),
#  ('Howard', 'IA', '9887'),
#  ('Humboldt', 'IA', '10284'),
#  ('Ida', 'IA', '8193'),
#  ('Iowa', 'IA', '15193'),
#  ('Jackson', 'IA', '20120'),
#  ('Jasper', 'IA', '35163'),
#  ('Jefferson', 'IA', '16829'),
#  ('Johnson', 'IA', '101291'),
#  ('Jones', 'IA', '20273'),
#  ('Keokuk', 'IA', '11564'),
#  ('Kossuth', 'IA', '18147'),
#  ('Lee', 'IA', '39130'),
#  ('Linn', 'IA', '178559'),
#  ('Louisa', 'IA', '11793'),
#  ('Lucas', 'IA', '9015'),
#  ('Lyon', 'IA', '11890'),
#  ('Madison', 'IA', '13490'),
#  ('Mahaska', 'IA', '21927'),
#  ('Marion', 'IA', '31102'),
#  ('Marshall', 'IA', '38627'),
#  ('Mills', 'IA', '13802'),
#  ('Mitchell', 'IA', '11129'),
#  ('Monona', 'IA', '9968'),
#  ('Monroe', 'IA', '8177'),
#  ('Montgomery', 'IA', '11939'),
#  ('Muscatine', 'IA', '41435'),
#  ("O'Brien", 'IA', '15349'),
#  ('Osceola', 'IA', '7077'),
#  ('Page', 'IA', '16676'),
#  ('Palo Alto', 'IA', '10200'),
#  ('Plymouth', 'IA', '24220'),
#  ('Pocahontas', 'IA', '9119'),
#  ('Polk', 'IA', '349560'),
#  ('Pottawattamie', 'IA', '83701'),
#  ('Poweshiek', 'IA', '19014'),
#  ('Ringgold', 'IA', '5373'),
#  ('Sac', 'IA', '12087'),
#  ('Scott', 'IA', '156694'),
#  ('Shelby', 'IA', '13089'),
#  ('Sioux', 'IA', '31398'),
#  ('Story', 'IA', '74638'),
#  ('Tama', 'IA', '17878'),
#  ('Taylor', 'IA', '7152'),
#  ('Union', 'IA', '12416'),
#  ('Van Buren', 'IA', '7767'),
#  ('Wapello', 'IA', '35770'),
#  ('Warren', 'IA', '38940'),
#  ('Washington', 'IA', '20508'),
#  ('Wayne', 'IA', '6866'),
#  ('Webster', 'IA', '39206'),
#  ('Winnebago', 'IA', '11900'),
#  ('Winneshiek', 'IA', '21058'),
#  ('Woodbury', 'IA', '101827'),
#  ('Worth', 'IA', '7926'),
#  ('Wright', 'IA', '14314'),
#  ('Ada', 'ID', '251831'),
#  ('Adams', 'ID', '3877'),
#  ('Bannock', 'ID', '72115'),
#  ('Bear Lake', 'ID', '6600'),
#  ('Benewah', 'ID', '8780'),
#  ('Bingham', 'ID', '41188'),
#  ('Blaine', 'ID', '16471'),
#  ('Boise', 'ID', '4768'),
#  ('Bonner', 'ID', '33080'),
#  ('Bonneville', 'ID', '79531'),
#  ('Boundary', 'ID', '9548'),
#  ('Butte', 'ID', '3008'),
#  ('Camas', 'ID', '848'),
#  ('Canyon', 'ID', '108510'),
#  ('Caribou', 'ID', '7280'),
#  ('Cassia', 'ID', '21095'),
#  ('Clark', 'ID', '822'),
#  ('Clearwater', 'ID', '9115'),
#  ('Custer', 'ID', '4316'),
#  ('Elmore', 'ID', '23181'),
#  ('Franklin', 'ID', '10286'),
#  ('Fremont', 'ID', '11532'),
#  ('Gem', 'ID', '13856'),
#  ('Gooding', 'ID', '12980'),
#  ('Idaho', 'ID', '14789'),
#  ('Jefferson', 'ID', '18786'),
#  ('Jerome', 'ID', '17017'),
#  ('Kootenai', 'ID', '91678'),
#  ('Latah', 'ID', '32860'),
#  ('Lemhi', 'ID', '7973'),
#  ('Lewis', 'ID', '3937'),
#  ('Lincoln', 'ID', '3729'),
#  ('Madison', 'ID', '23811'),
#  ('Minidoka', 'ID', '21065'),
#  ('Nez Perce', 'ID', '36549'),
#  ('Oneida', 'ID', '3843'),
#  ('Owyhee', 'ID', '9520'),
#  ('Payette', 'ID', '19532'),
#  ('Power', 'ID', '7986'),
#  ('Shoshone', 'ID', '14042'),
#  ('Teton', 'ID', '4706'),
#  ('Twin Falls', 'ID', '59480'),
#  ('Valley', 'ID', '7877'),
#  ('Washington', 'ID', '9463'),
#  ('Adams', 'IL', '68043'),
#  ('Alexander', 'IL', '10180'),
#  ('Bond', 'IL', '15738'),
#  ('Boone', 'IL', '36180'),
#  ('Brown', 'IL', '6247'),
#  ('Bureau', 'IL', '36049'),
#  ('Calhoun', 'IL', '4948'),
#  ('Carroll', 'IL', '16872'),
#  ('Cass', 'IL', '13330'),
#  ('Champaign', 'IL', '169096'),
#  ('Christian', 'IL', '34920'),
#  ('Clark', 'IL', '16284'),
#  ('Clay', 'IL', '14435'),
#  ('Clinton', 'IL', '35285'),
#  ('Coles', 'IL', '52357'),
#  ('Cook', 'IL', '5136877'),
#  ('Crawford', 'IL', '19911'),
#  ('Cumberland', 'IL', '11110'),
#  ('De Kalb', 'IL', '83441'),
#  ('De Witt', 'IL', '16824'),
#  ('Douglas', 'IL', '19799'),
#  ('Du Page', 'IL', '853458'),
#  ('Edgar', 'IL', '19984'),
#  ('Edwards', 'IL', '7262'),
#  ('Effingham', 'IL', '33009'),
#  ('Fayette', 'IL', '21235'),
#  ('Ford', 'IL', '14127'),
#  ('Franklin', 'IL', '40809'),
#  ('Fulton', 'IL', '38788'),
#  ('Gallatin', 'IL', '6779'),
#  ('Greene', 'IL', '15643'),
#  ('Grundy', 'IL', '35159'),
#  ('Hamilton', 'IL', '8525'),
#  ('Hancock', 'IL', '21292'),
#  ('Hardin', 'IL', '5184'),
#  ('Henderson', 'IL', '8432'),
#  ('Henry', 'IL', '51719'),
#  ('Iroquois', 'IL', '31411'),
#  ('Jackson', 'IL', '61502'),
#  ('Jasper', 'IL', '10591'),
#  ('Jefferson', 'IL', '38998'),
#  ('Jersey', 'IL', '21188'),
#  ('Jo Daviess', 'IL', '21931'),
#  ('Johnson', 'IL', '12426'),
#  ('Kane', 'IL', '359950'),
#  ('Kankakee', 'IL', '102046'),
#  ('Kendall', 'IL', '45398'),
#  ('Knox', 'IL', '56070'),
#  ('La Salle', 'IL', '109955'),
#  ('Lake', 'IL', '572431'),
#  ('Lawrence', 'IL', '15918'),
#  ('Lee', 'IL', '35798'),
#  ('Livingston', 'IL', '40404'),
#  ('Logan', 'IL', '31267'),
#  ('Macon', 'IL', '116414'),
#  ('Macoupin', 'IL', '48729'),
#  ('Madison', 'IL', '256458'),
#  ('Marion', 'IL', '41997'),
#  ('Marshall', 'IL', '12791'),
#  ('Mason', 'IL', '16691'),
#  ('Massac', 'IL', '15370'),
#  ('McDonough', 'IL', '35519'),
#  ('McHenry', 'IL', '224677'),
#  ('McLean', 'IL', '139274'),
#  ('Menard', 'IL', '12284'),
#  ('Mercer', 'IL', '17444'),
#  ('Monroe', 'IL', '24719'),
#  ('Montgomery', 'IL', '30994'),
#  ('Morgan', 'IL', '36171'),
#  ('Moultrie', 'IL', '14168'),
#  ('Ogle', 'IL', '49406'),
#  ('Peoria', 'IL', '183377'),
#  ('Perry', 'IL', '21295'),
#  ('Piatt', 'IL', '16158'),
#  ('Pike', 'IL', '17338'),
#  ('Pope', 'IL', '4691'),
#  ('Pulaski', 'IL', '7464'),
#  ('Putnam', 'IL', '5718'),
#  ('Randolph', 'IL', '34296'),
#  ('Richland', 'IL', '16788'),
#  ('Rock Island', 'IL', '149830'),
#  ('Saline', 'IL', '26521'),
#  ('Sangamon', 'IL', '184731'),
#  ('Schuyler', 'IL', '7798'),
#  ('Scott', 'IL', '5629'),
#  ('Shelby', 'IL', '22561'),
#  ('St. Clair', 'IL', '265424'),
#  ('Stark', 'IL', '6396'),
#  ('Stephenson', 'IL', '48844'),
#  ('Tazewell', 'IL', '127602'),
#  ('Union', 'IL', '18114'),
#  ('Vermilion', 'IL', '86541'),
#  ('Wabash', 'IL', '12929'),
#  ('Warren', 'IL', '18816'),
#  ('Washington', 'IL', '15238'),
#  ('Wayne', 'IL', '17208'),
#  ('White', 'IL', '15903'),
#  ('Whiteside', 'IL', '60352'),
#  ('Will', 'IL', '413379'),
#  ('Williamson', 'IL', '59750'),
#  ('Winnebago', 'IL', '264952'),
#  ('Woodford', 'IL', '34576'),
#  ('Adams', 'IN', '32311'),
#  ('Allen', 'IN', '308503'),
#  ('Bartholomew', 'IN', '68065'),
#  ('Benton', 'IN', '9703'),
#  ('Blackford', 'IN', '14162'),
#  ('Boone', 'IN', '41813'),
#  ('Brown', 'IN', '15098'),
#  ('Carroll', 'IN', '19505'),
#  ('Cass', 'IN', '38584'),
#  ('Clark', 'IN', '91826'),
#  ('Clay', 'IN', '26306'),
#  ('Clinton', 'IN', '32594'),
#  ('Crawford', 'IN', '10442'),
#  ('Daviess', 'IN', '28603'),
#  ('De Kalb', 'IN', '37955'),
#  ('Dearborn', 'IN', '44367'),
#  ('Decatur', 'IN', '24998'),
#  ('Delaware', 'IN', '118577'),
#  ('Dubois', 'IN', '38732'),
#  ('Elkhart', 'IN', '166994'),
#  ('Fayette', 'IN', '26430'),
#  ('Floyd', 'IN', '70058'),
#  ('Fountain', 'IN', '18060'),
#  ('Franklin', 'IN', '20957'),
#  ('Fulton', 'IN', '19922'),
#  ('Gibson', 'IN', '32165'),
#  ('Grant', 'IN', '73720'),
#  ('Greene', 'IN', '32696'),
#  ('Hamilton', 'IN', '140650'),
#  ('Hancock', 'IN', '50768'),
#  ('Harrison', 'IN', '32594'),
#  ('Hendricks', 'IN', '86620'),
#  ('Henry', 'IN', '49275'),
#  ('Howard', 'IN', '83763'),
#  ('Huntington', 'IN', '36807'),
#  ('Jackson', 'IN', '40403'),
#  ('Jasper', 'IN', '27895'),
#  ('Jay', 'IN', '21901'),
#  ('Jefferson', 'IN', '30813'),
#  ('Jennings', 'IN', '26168'),
#  ('Johnson', 'IN', '101690'),
#  ('Knox', 'IN', '40194'),
#  ('Kosciusko', 'IN', '69210'),
#  ('La Porte', 'IN', '110384'),
#  ('Lagrange', 'IN', '31653'),
#  ('Lake', 'IN', '482672'),
#  ('Lawrence', 'IN', '45097'),
#  ('Madison', 'IN', '132796'),
#  ('Marion', 'IN', '817604'),
#  ('Marshall', 'IN', '44879'),
#  ('Martin', 'IN', '10545'),
#  ('Miami', 'IN', '32611'),
#  ('Monroe', 'IN', '115208'),
#  ('Montgomery', 'IN', '36090'),
#  ('Morgan', 'IN', '62115'),
#  ('Newton', 'IN', '14413'),
#  ('Noble', 'IN', '40884'),
#  ('Ohio', 'IN', '5395'),
#  ('Orange', 'IN', '19011'),
#  ('Owen', 'IN', '19663'),
#  ('Parke', 'IN', '16094'),
#  ('Perry', 'IN', '19129'),
#  ('Pike', 'IN', '12610'),
#  ('Porter', 'IN', '140487'),
#  ('Posey', 'IN', '26493'),
#  ('Pulaski', 'IN', '12960'),
#  ('Putnam', 'IN', '32939'),
#  ('Randolph', 'IN', '27377'),
#  ('Ripley', 'IN', '26829'),
#  ('Rush', 'IN', '18456'),
#  ('Scott', 'IN', '22568'),
#  ('Shelby', 'IN', '42809'),
#  ('Spencer', 'IN', '20374'),
#  ('St. Joseph', 'IN', '258083'),
#  ('Starke', 'IN', '22620'),
#  ('Steuben', 'IN', '30060'),
#  ('Sullivan', 'IN', '19879'),
#  ('Switzerland', 'IN', '8222'),
#  ('Tippecanoe', 'IN', '135285'),
#  ('Tipton', 'IN', '16463'),
#  ('Union', 'IN', '7292'),
#  ('Vanderburgh', 'IN', '168065'),
#  ('Vermillion', 'IN', '16841'),
#  ('Vigo', 'IN', '106622'),
#  ('Wabash', 'IN', '34896'),
#  ('Warren', 'IN', '8394'),
#  ('Warrick', 'IN', '49380'),
#  ('Washington', 'IN', '26088'),
#  ('Wayne', 'IN', '72802'),
#  ('Wells', 'IN', '26506'),
#  ('White', 'IN', '24505'),
#  ('Whitley', 'IN', '29426'),
#  ('Allen', 'KS', '14739'),
#  ('Anderson', 'KS', '8000'),
#  ('Atchison', 'KS', '16258'),
#  ('Barber', 'KS', '5603'),
#  ('Barton', 'KS', '28614'),
#  ('Bourbon', 'KS', '15013'),
#  ('Brown', 'KS', '11075'),
#  ('Butler', 'KS', '57746'),
#  ('Chase', 'KS', '2885'),
#  ('Chautauqua', 'KS', '4439'),
#  ('Cherokee', 'KS', '22437'),
#  ('Cheyenne', 'KS', '3230'),
#  ('Clark', 'KS', '2379'),
#  ('Clay', 'KS', '9317'),
#  ('Cloud', 'KS', '10488'),
#  ('Coffey', 'KS', '8691'),
#  ('Comanche', 'KS', '2099'),
#  ('Cowley', 'KS', '37107'),
#  ('Crawford', 'KS', '36488'),
#  ('Decatur', 'KS', '3547'),
#  ('Dickinson', 'KS', '19911'),
#  ('Doniphan', 'KS', '7608'),
#  ('Douglas', 'KS', '88206'),
#  ('Edwards', 'KS', '3564'),
#  ('Elk', 'KS', '3356'),
#  ('Ellis', 'KS', '26145'),
#  ('Ellsworth', 'KS', '6445'),
#  ('Finney', 'KS', '34913'),
#  ('Ford', 'KS', '28909'),
#  ('Franklin', 'KS', '23164'),
#  ('Geary', 'KS', '29638'),
#  ('Gove', 'KS', '3091'),
#  ('Graham', 'KS', '3336'),
#  ('Grant', 'KS', '7837'),
#  ('Gray', 'KS', '5367'),
#  ('Greeley', 'KS', '1834'),
#  ('Greenwood', 'KS', '8032'),
#  ('Hamilton', 'KS', '2343'),
#  ('Harper', 'KS', '6651'),
#  ('Harvey', 'KS', '31145'),
#  ('Haskell', 'KS', '4027'),
#  ('Hodgeman', 'KS', '2268'),
#  ('Jackson', 'KS', '11809'),
#  ('Jefferson', 'KS', '17133'),
#  ('Jewell', 'KS', '3952'),
#  ('Johnson', 'KS', '401054'),
#  ('Kearny', 'KS', '4182'),
#  ('Kingman', 'KS', '8566'),
#  ('Kiowa', 'KS', '3605'),
#  ('Labette', 'KS', '22862'),
#  ('Lane', 'KS', '2275'),
#  ('Leavenworth', 'KS', '69323'),
#  ('Lincoln', 'KS', '3431'),
#  ('Linn', 'KS', '8698'),
#  ('Logan', 'KS', '3178'),
#  ('Lyon', 'KS', '34650'),
#  ('Marion', 'KS', '12961'),
#  ('Marshall', 'KS', '11261'),
#  ('McPherson', 'KS', '27267'),
#  ('Meade', 'KS', '4355'),
#  ('Miami', 'KS', '25187'),
#  ('Mitchell', 'KS', '7092'),
#  ('Montgomery', 'KS', '37694'),
#  ('Morris', 'KS', '6327'),
#  ('Morton', 'KS', '3303'),
#  ('Nemaha', 'KS', '10443'),
#  ('Neosho', 'KS', '16994'),
#  ('Ness', 'KS', '3752'),
#  ('Norton', 'KS', '5735'),
#  ('Osage', 'KS', '16729'),
#  ('Osborne', 'KS', '4696'),
#  ('Ottawa', 'KS', '5749'),
#  ('Pawnee', 'KS', '7615'),
#  ('Phillips', 'KS', '6270'),
#  ('Pottawatomie', 'KS', '17548'),
#  ('Pratt', 'KS', '9696'),
#  ('Rawlins', 'KS', '3234'),
#  ('Reno', 'KS', '63263'),
#  ('Republic', 'KS', '6215'),
#  ('Rice', 'KS', '10086'),
#  ('Riley', 'KS', '69784'),
#  ('Rooks', 'KS', '5884'),
#  ('Rush', 'KS', '3541'),
#  ('Russell', 'KS', '7701'),
#  ('Saline', 'KS', '51831'),
#  ('Scott', 'KS', '5074'),
#  ('Sedgwick', 'KS', '419333'),
#  ('Seward', 'KS', '19370'),
#  ('Shawnee', 'KS', '165062'),
#  ('Sheridan', 'KS', '2824'),
#  ('Sherman', 'KS', '6706'),
#  ('Smith', 'KS', '4782'),
#  ('Stafford', 'KS', '5193'),
#  ('Stanton', 'KS', '2331'),
#  ('Stevens', 'KS', '5257'),
#  ('Sumner', 'KS', '26519'),
#  ('Thomas', 'KS', '8331'),
#  ('Trego', 'KS', '3449'),
#  ('Wabaunsee', 'KS', '6603'),
#  ('Wallace', 'KS', '1798'),
#  ('Washington', 'KS', '6833'),
#  ('Wichita', 'KS', '2841'),
#  ('Wilson', 'KS', '10321'),
#  ('Woodson', 'KS', '3999'),
#  ('Wyandotte', 'KS', '153826'),
#  ('Adair', 'KY', '16292'),
#  ('Allen', 'KY', '15706'),
#  ('Anderson', 'KY', '17152'),
#  ('Ballard', 'KY', '8232'),
#  ('Barren', 'KY', '35768'),
#  ('Bath', 'KY', '10159'),
#  ('Bell', 'KY', '30490'),
#  ('Boone', 'KY', '70097'),
#  ('Bourbon', 'KY', '19257'),
#  ('Boyd', 'KY', '50613'),
#  ('Boyle', 'KY', '26699'),
#  ('Bracken', 'KY', '8209'),
#  ('Breathitt', 'KY', '15539'),
#  ...]

# %%
[(r[0], r[1], int(r[2])) for r in dt2]
# Out:
# [('Aleutians East', 'AK', 2305),
#  ('Aleutians West', 'AK', 5259),
#  ('Anchorage', 'AK', 251335),
#  ('Bethel', 'AK', 15525),
#  ('Bristol Bay', 'AK', 1023),
#  ('Dillingham', 'AK', 4360),
#  ('Fairbanks North Star', 'AK', 83374),
#  ('Haines', 'AK', 2181),
#  ('Juneau', 'AK', 29378),
#  ('Kenai Peninsula', 'AK', 46151),
#  ('Ketchikan Gateway', 'AK', 14422),
#  ('Kodiak Island', 'AK', 14987),
#  ('Lake and Peninsula', 'AK', 1787),
#  ('Matanuska-Susitna', 'AK', 50686),
#  ('Nome', 'AK', 8754),
#  ('North Slope', 'AK', 7024),
#  ('Northwest Arctic', 'AK', 6501),
#  ('Prince of Wales-Outer Ketchikan', 'AK', 7109),
#  ('Sitka', 'AK', 8710),
#  ('Skagway-Yakutat-Angoon', 'AK', 4655),
#  ('Southeast Fairbanks', 'AK', 6018),
#  ('Valdez-Cordova', 'AK', 10475),
#  ('Wade Hampton', 'AK', 6574),
#  ('Wrangell-Petersburg', 'AK', 7089),
#  ('Yukon-Koyukuk', 'AK', 6057),
#  ('Autauga', 'AL', 39381),
#  ('Baldwin', 'AL', 120198),
#  ('Barbour', 'AL', 26469),
#  ('Bibb', 'AL', 17942),
#  ('Blount', 'AL', 42721),
#  ('Bullock', 'AL', 11149),
#  ('Butler', 'AL', 21798),
#  ('Calhoun', 'AL', 117263),
#  ('Chambers', 'AL', 37262),
#  ('Cherokee', 'AL', 21038),
#  ('Chilton', 'AL', 34912),
#  ('Choctaw', 'AL', 16079),
#  ('Clarke', 'AL', 27993),
#  ('Clay', 'AL', 13551),
#  ('Cleburne', 'AL', 13272),
#  ('Coffee', 'AL', 42359),
#  ('Colbert', 'AL', 52586),
#  ('Conecuh', 'AL', 14022),
#  ('Coosa', 'AL', 11680),
#  ('Covington', 'AL', 37459),
#  ('Crenshaw', 'AL', 13624),
#  ('Cullman', 'AL', 72489),
#  ('Dale', 'AL', 50001),
#  ('Dallas', 'AL', 48022),
#  ('De Kalb', 'AL', 57271),
#  ('Elmore', 'AL', 57071),
#  ('Escambia', 'AL', 36541),
#  ('Etowah', 'AL', 100259),
#  ('Fayette', 'AL', 18019),
#  ('Franklin', 'AL', 29313),
#  ('Geneva', 'AL', 24727),
#  ('Greene', 'AL', 10076),
#  ('Hale', 'AL', 16212),
#  ('Henry', 'AL', 15752),
#  ('Houston', 'AL', 84367),
#  ('Jackson', 'AL', 50128),
#  ('Jefferson', 'AL', 657827),
#  ('Lamar', 'AL', 15754),
#  ('Lauderdale', 'AL', 83598),
#  ('Lawrence', 'AL', 32803),
#  ('Lee', 'AL', 94029),
#  ('Limestone', 'AL', 59344),
#  ('Lowndes', 'AL', 12946),
#  ('Macon', 'AL', 23959),
#  ('Madison', 'AL', 258340),
#  ('Marengo', 'AL', 23662),
#  ('Marion', 'AL', 30382),
#  ('Marshall', 'AL', 78195),
#  ('Mobile', 'AL', 397413),
#  ('Monroe', 'AL', 24550),
#  ('Montgomery', 'AL', 218880),
#  ('Morgan', 'AL', 107034),
#  ('Perry', 'AL', 12708),
#  ('Pickens', 'AL', 20956),
#  ('Pike', 'AL', 28848),
#  ('Randolph', 'AL', 20323),
#  ('Russell', 'AL', 51436),
#  ('Shelby', 'AL', 123500),
#  ('St. Clair', 'AL', 57713),
#  ('Sumter', 'AL', 16390),
#  ('Talladega', 'AL', 76737),
#  ('Tallapoosa', 'AL', 39737),
#  ('Tuscaloosa', 'AL', 158732),
#  ('Walker', 'AL', 69678),
#  ('Washington', 'AL', 17385),
#  ('Wilcox', 'AL', 13628),
#  ('Winston', 'AL', 23489),
#  ('Arkansas', 'AR', 21032),
#  ('Ashley', 'AR', 24651),
#  ('Baxter', 'AR', 35666),
#  ('Benton', 'AR', 120932),
#  ('Boone', 'AR', 31364),
#  ('Bradley', 'AR', 11650),
#  ('Calhoun', 'AR', 5801),
#  ('Carroll', 'AR', 21933),
#  ('Chicot', 'AR', 15289),
#  ('Clark', 'AR', 22101),
#  ('Clay', 'AR', 17601),
#  ('Cleburne', 'AR', 21865),
#  ('Cleveland', 'AR', 8084),
#  ('Columbia', 'AR', 25670),
#  ('Conway', 'AR', 19671),
#  ('Craighead', 'AR', 74794),
#  ('Crawford', 'AR', 48100),
#  ('Crittenden', 'AR', 49889),
#  ('Cross', 'AR', 19370),
#  ('Dallas', 'AR', 9493),
#  ('Desha', 'AR', 15487),
#  ('Drew', 'AR', 17853),
#  ('Faulkner', 'AR', 71758),
#  ('Franklin', 'AR', 16122),
#  ('Fulton', 'AR', 10732),
#  ('Garland', 'AR', 81049),
#  ('Grant', 'AR', 15022),
#  ('Greene', 'AR', 34620),
#  ('Hempstead', 'AR', 22194),
#  ('Hot Spring', 'AR', 27876),
#  ('Howard', 'AR', 13655),
#  ('Independence', 'AR', 32752),
#  ('Izard', 'AR', 12619),
#  ('Jackson', 'AR', 18622),
#  ('Jefferson', 'AR', 84042),
#  ('Johnson', 'AR', 20508),
#  ('Lafayette', 'AR', 9213),
#  ('Lawrence', 'AR', 17468),
#  ('Lee', 'AR', 12962),
#  ('Lincoln', 'AR', 14119),
#  ('Little River', 'AR', 13413),
#  ('Logan', 'AR', 21050),
#  ('Lonoke', 'AR', 45966),
#  ('Madison', 'AR', 12943),
#  ('Marion', 'AR', 13855),
#  ('Miller', 'AR', 39082),
#  ('Mississippi', 'AR', 50811),
#  ('Monroe', 'AR', 10374),
#  ('Montgomery', 'AR', 8356),
#  ('Nevada', 'AR', 9996),
#  ('Newton', 'AR', 7989),
#  ('Ouachita', 'AR', 28580),
#  ('Perry', 'AR', 8823),
#  ('Phillips', 'AR', 27386),
#  ('Pike', 'AR', 10332),
#  ('Poinsett', 'AR', 24640),
#  ('Polk', 'AR', 18832),
#  ('Pope', 'AR', 51181),
#  ('Prairie', 'AR', 9312),
#  ('Pulaski', 'AR', 352240),
#  ('Randolph', 'AR', 17430),
#  ('Saline', 'AR', 73604),
#  ('Scott', 'AR', 10628),
#  ('Searcy', 'AR', 7626),
#  ('Sebastian', 'AR', 104402),
#  ('Sevier', 'AR', 14501),
#  ('Sharp', 'AR', 16172),
#  ('St. Francis', 'AR', 27859),
#  ('Stone', 'AR', 10784),
#  ('Union', 'AR', 46191),
#  ('Van Buren', 'AR', 15198),
#  ('Washington', 'AR', 131708),
#  ('White', 'AR', 61016),
#  ('Woodruff', 'AR', 9121),
#  ('Yell', 'AR', 18739),
#  ('Apache', 'AZ', 67803),
#  ('Cochise', 'AZ', 110062),
#  ('Coconino', 'AZ', 110498),
#  ('Gila', 'AZ', 46039),
#  ('Graham', 'AZ', 29589),
#  ('Greenlee', 'AZ', 9232),
#  ('La Paz', 'AZ', 14310),
#  ('Maricopa', 'AZ', 2432372),
#  ('Mohave', 'AZ', 121602),
#  ('Navajo', 'AZ', 89253),
#  ('Pima', 'AZ', 752428),
#  ('Pinal', 'AZ', 131210),
#  ('Santa Cruz', 'AZ', 36078),
#  ('Yavapai', 'AZ', 134595),
#  ('Yuma', 'AZ', 132869),
#  ('Alameda', 'CA', 1323312),
#  ('Alpine', 'CA', 1229),
#  ('Amador', 'CA', 33162),
#  ('Butte', 'CA', 192880),
#  ('Calaveras', 'CA', 37694),
#  ('Colusa', 'CA', 17596),
#  ('Contra Costa', 'CA', 872099),
#  ('Del Norte', 'CA', 26956),
#  ('El Dorado', 'CA', 148217),
#  ('Fresno', 'CA', 737289),
#  ('Glenn', 'CA', 26028),
#  ('Humboldt', 'CA', 122747),
#  ('Imperial', 'CA', 138072),
#  ('Inyo', 'CA', 18435),
#  ('Kern', 'CA', 617528),
#  ('Kings', 'CA', 113089),
#  ('Lake', 'CA', 55783),
#  ('Lassen', 'CA', 28279),
#  ('Los Angeles', 'CA', 9138789),
#  ('Madera', 'CA', 107004),
#  ('Marin', 'CA', 233883),
#  ('Mariposa', 'CA', 15772),
#  ('Mendocino', 'CA', 82499),
#  ('Merced', 'CA', 194407),
#  ('Modoc', 'CA', 9559),
#  ('Mono', 'CA', 10433),
#  ('Monterey', 'CA', 348841),
#  ('Napa', 'CA', 115751),
#  ('Nevada', 'CA', 87318),
#  ('Orange', 'CA', 2563971),
#  ('Placer', 'CA', 205239),
#  ('Plumas', 'CA', 20451),
#  ('Riverside', 'CA', 1379801),
#  ('Sacramento', 'CA', 1103499),
#  ('San Benito', 'CA', 42625),
#  ('San Bernardino', 'CA', 1569586),
#  ('San Diego', 'CA', 2644132),
#  ('San Francisco', 'CA', 730570),
#  ('San Joaquin', 'CA', 523969),
#  ('San Luis Obispo', 'CA', 226071),
#  ('San Mateo', 'CA', 681362),
#  ('Santa Barbara', 'CA', 381401),
#  ('Santa Clara', 'CA', 1565253),
#  ('Santa Cruz', 'CA', 236669),
#  ('Shasta', 'CA', 160940),
#  ('Sierra', 'CA', 3399),
#  ('Siskiyou', 'CA', 44253),
#  ('Solano', 'CA', 366134),
#  ('Sonoma', 'CA', 414569),
#  ('Stanislaus', 'CA', 410870),
#  ('Sutter', 'CA', 74963),
#  ('Tehama', 'CA', 53798),
#  ('Trinity', 'CA', 13429),
#  ('Tulare', 'CA', 346843),
#  ('Tuolumne', 'CA', 51777),
#  ('Ventura', 'CA', 710018),
#  ('Yolo', 'CA', 147769),
#  ('Yuba', 'CA', 61141),
#  ('Adams', 'CO', 303297),
#  ('Alamosa', 'CO', 14215),
#  ('Arapahoe', 'CO', 449103),
#  ('Archuleta', 'CO', 7100),
#  ('Baca', 'CO', 4384),
#  ('Bent', 'CO', 5518),
#  ('Boulder', 'CO', 253850),
#  ('Chaffee', 'CO', 14413),
#  ('Cheyenne', 'CO', 2312),
#  ('Clear Creek', 'CO', 8745),
#  ('Conejos', 'CO', 7807),
#  ('Costilla', 'CO', 3384),
#  ('Crowley', 'CO', 4303),
#  ('Custer', 'CO', 2702),
#  ('Delta', 'CO', 25077),
#  ('Denver', 'CO', 494462),
#  ('Dolores', 'CO', 1588),
#  ('Douglas', 'CO', 99577),
#  ('Eagle', 'CO', 28844),
#  ('El Paso', 'CO', 465800),
#  ('Elbert', 'CO', 14565),
#  ('Fremont', 'CO', 39794),
#  ('Garfield', 'CO', 35338),
#  ('Gilpin', 'CO', 3576),
#  ('Grand', 'CO', 9188),
#  ('Gunnison', 'CO', 11931),
#  ('Hinsdale', 'CO', 648),
#  ('Huerfano', 'CO', 6356),
#  ('Jackson', 'CO', 1537),
#  ('Jefferson', 'CO', 484869),
#  ('Kiowa', 'CO', 1627),
#  ('Kit Carson', 'CO', 7301),
#  ('La Plata', 'CO', 38314),
#  ('Lake', 'CO', 6296),
#  ('Larimer', 'CO', 217215),
#  ('Las Animas', 'CO', 14268),
#  ('Lincoln', 'CO', 5602),
#  ('Logan', 'CO', 17869),
#  ('Mesa', 'CO', 106548),
#  ('Mineral', 'CO', 634),
#  ('Moffat', 'CO', 12136),
#  ('Montezuma', 'CO', 21591),
#  ('Montrose', 'CO', 28829),
#  ('Morgan', 'CO', 23729),
#  ('Otero', 'CO', 20788),
#  ('Ouray', 'CO', 3033),
#  ('Park', 'CO', 10589),
#  ('Phillips', 'CO', 4309),
#  ('Pitkin', 'CO', 13589),
#  ('Prowers', 'CO', 13591),
#  ('Pueblo', 'CO', 129759),
#  ('Rio Blanco', 'CO', 6472),
#  ('Rio Grande', 'CO', 11262),
#  ('Routt', 'CO', 16709),
#  ('Saguache', 'CO', 5514),
#  ('San Juan', 'CO', 546),
#  ('San Miguel', 'CO', 4929),
#  ('Sedgwick', 'CO', 2606),
#  ('Summit', 'CO', 17204),
#  ('Teller', 'CO', 17478),
#  ('Washington', 'CO', 4687),
#  ('Weld', 'CO', 148014),
#  ('Yuma', 'CO', 9264),
#  ('Fairfield', 'CT', 830728),
#  ('Hartford', 'CT', 835589),
#  ('Litchfield', 'CT', 179316),
#  ('Middlesex', 'CT', 148030),
#  ('New Haven', 'CT', 794785),
#  ('New London', 'CT', 250404),
#  ('Tolland', 'CT', 131604),
#  ('Windham', 'CT', 104206),
#  ('Washington', 'DC', 554256),
#  ('Kent', 'DE', 121725),
#  ('New Castle', 'DE', 467889),
#  ('Sussex', 'DE', 127583),
#  ('Alachua', 'FL', 196106),
#  ('Baker', 'FL', 20153),
#  ('Bay', 'FL', 142690),
#  ('Bradford', 'FL', 24182),
#  ('Brevard', 'FL', 450646),
#  ('Broward', 'FL', 1412165),
#  ('Calhoun', 'FL', 11858),
#  ('Charlotte', 'FL', 129381),
#  ('Citrus', 'FL', 107333),
#  ('Clay', 'FL', 124431),
#  ('Collier', 'FL', 181381),
#  ('Columbia', 'FL', 48376),
#  ('Dade', 'FL', 2031336),
#  ('De Soto', 'FL', 25048),
#  ('Dixie', 'FL', 12159),
#  ('Duval', 'FL', 701673),
#  ('Escambia', 'FL', 273804),
#  ('Flagler', 'FL', 40643),
#  ('Franklin', 'FL', 10301),
#  ('Gadsden', 'FL', 43378),
#  ('Gilchrist', 'FL', 12332),
#  ('Glades', 'FL', 7665),
#  ('Gulf', 'FL', 13390),
#  ('Hamilton', 'FL', 11773),
#  ('Hardee', 'FL', 19952),
#  ('Hendry', 'FL', 28114),
#  ('Hernando', 'FL', 120054),
#  ('Highlands', 'FL', 74507),
#  ('Hillsborough', 'FL', 884608),
#  ('Holmes', 'FL', 17520),
#  ('Indian River', 'FL', 97144),
#  ('Jackson', 'FL', 43891),
#  ('Jefferson', 'FL', 12950),
#  ('Lafayette', 'FL', 6043),
#  ('Lake', 'FL', 180160),
#  ('Lee', 'FL', 375381),
#  ('Leon', 'FL', 213917),
#  ('Levy', 'FL', 29738),
#  ('Liberty', 'FL', 6400),
#  ('Madison', 'FL', 17231),
#  ('Manatee', 'FL', 229864),
#  ('Marion', 'FL', 226678),
#  ('Martin', 'FL', 111069),
#  ('Monroe', 'FL', 81850),
#  ('Nassau', 'FL', 50767),
#  ('Okaloosa', 'FL', 163707),
#  ('Okeechobee', 'FL', 30222),
#  ('Orange', 'FL', 749631),
#  ('Osceola', 'FL', 130771),
#  ('Palm Beach', 'FL', 972093),
#  ('Pasco', 'FL', 304938),
#  ('Pinellas', 'FL', 870884),
#  ('Polk', 'FL', 436701),
#  ('Putnam', 'FL', 69481),
#  ('Santa Rosa', 'FL', 104110),
#  ('Sarasota', 'FL', 295942),
#  ('Seminole', 'FL', 330012),
#  ('St. Johns', 'FL', 102174),
#  ('St. Lucie', 'FL', 172483),
#  ('Sumter', 'FL', 34788),
#  ('Suwannee', 'FL', 30103),
#  ('Taylor', 'FL', 17445),
#  ('Union', 'FL', 12433),
#  ('Volusia', 'FL', 408261),
#  ('Wakulla', 'FL', 17111),
#  ('Walton', 'FL', 33615),
#  ('Washington', 'FL', 18623),
#  ('Appling', 'GA', 16359),
#  ('Atkinson', 'GA', 6749),
#  ('Bacon', 'GA', 10438),
#  ('Baker', 'GA', 3766),
#  ('Baldwin', 'GA', 41854),
#  ('Banks', 'GA', 11616),
#  ('Barrow', 'GA', 35699),
#  ('Bartow', 'GA', 63732),
#  ('Ben Hill', 'GA', 17258),
#  ('Berrien', 'GA', 15466),
#  ('Bibb', 'GA', 155066),
#  ('Bleckley', 'GA', 10958),
#  ('Brantley', 'GA', 12698),
#  ('Brooks', 'GA', 15837),
#  ('Bryan', 'GA', 21190),
#  ('Bulloch', 'GA', 48642),
#  ('Burke', 'GA', 21742),
#  ('Butts', 'GA', 16025),
#  ('Calhoun', 'GA', 4851),
#  ('Camden', 'GA', 40714),
#  ('Candler', 'GA', 8637),
#  ('Carroll', 'GA', 77977),
#  ('Catoosa', 'GA', 48008),
#  ('Charlton', 'GA', 9296),
#  ('Chatham', 'GA', 226160),
#  ('Chattahoochee', 'GA', 15871),
#  ('Chattooga', 'GA', 22884),
#  ('Cherokee', 'GA', 114751),
#  ('Clarke', 'GA', 90207),
#  ('Clay', 'GA', 3473),
#  ('Clayton', 'GA', 198551),
#  ('Clinch', 'GA', 6438),
#  ('Cobb', 'GA', 525453),
#  ('Coffee', 'GA', 32697),
#  ('Colquitt', 'GA', 38072),
#  ('Columbia', 'GA', 83674),
#  ('Cook', 'GA', 13950),
#  ('Coweta', 'GA', 72021),
#  ('Crawford', 'GA', 10166),
#  ('Crisp', 'GA', 20716),
#  ('Dade', 'GA', 14158),
#  ('Dawson', 'GA', 12237),
#  ('De Kalb', 'GA', 582095),
#  ('Decatur', 'GA', 26390),
#  ('Dodge', 'GA', 17956),
#  ('Dooly', 'GA', 10314),
#  ('Dougherty', 'GA', 97511),
#  ('Douglas', 'GA', 82297),
#  ('Early', 'GA', 12198),
#  ('Echols', 'GA', 2325),
#  ('Effingham', 'GA', 32118),
#  ('Elbert', 'GA', 19173),
#  ('Emanuel', 'GA', 20954),
#  ('Evans', 'GA', 9438),
#  ('Fannin', 'GA', 17480),
#  ('Fayette', 'GA', 78879),
#  ('Floyd', 'GA', 83935),
#  ('Forsyth', 'GA', 62335),
#  ('Franklin', 'GA', 17701),
#  ('Fulton', 'GA', 700689),
#  ('Gilmer', 'GA', 15916),
#  ('Glascock', 'GA', 2456),
#  ('Glynn', 'GA', 65565),
#  ('Gordon', 'GA', 38442),
#  ('Grady', 'GA', 21312),
#  ('Greene', 'GA', 12781),
#  ('Gwinnett', 'GA', 457058),
#  ('Habersham', 'GA', 30146),
#  ('Hall', 'GA', 108238),
#  ('Hancock', 'GA', 9100),
#  ('Haralson', 'GA', 23378),
#  ('Harris', 'GA', 20479),
#  ('Hart', 'GA', 20848),
#  ('Heard', 'GA', 9573),
#  ('Henry', 'GA', 84553),
#  ('Houston', 'GA', 99647),
#  ('Irwin', 'GA', 8725),
#  ('Jackson', 'GA', 33921),
#  ('Jasper', 'GA', 9168),
#  ('Jeff Davis', 'GA', 12366),
#  ('Jefferson', 'GA', 17872),
#  ('Jenkins', 'GA', 8658),
#  ('Johnson', 'GA', 8436),
#  ('Jones', 'GA', 22077),
#  ('Lamar', 'GA', 13797),
#  ('Lanier', 'GA', 6312),
#  ('Laurens', 'GA', 42852),
#  ('Lee', 'GA', 19922),
#  ('Liberty', 'GA', 58749),
#  ('Lincoln', 'GA', 8055),
#  ('Long', 'GA', 7885),
#  ('Lowndes', 'GA', 82952),
#  ('Lumpkin', 'GA', 16822),
#  ('Macon', 'GA', 13249),
#  ('Madison', 'GA', 23396),
#  ('Marion', 'GA', 6370),
#  ('McDuffie', 'GA', 21627),
#  ('McIntosh', 'GA', 9456),
#  ('Meriwether', 'GA', 23041),
#  ('Miller', 'GA', 6161),
#  ('Mitchell', 'GA', 20859),
#  ('Monroe', 'GA', 18950),
#  ('Montgomery', 'GA', 7635),
#  ('Morgan', 'GA', 14006),
#  ('Murray', 'GA', 30032),
#  ('Muscogee', 'GA', 184594),
#  ('Newton', 'GA', 50644),
#  ('Oconee', 'GA', 21190),
#  ('Oglethorpe', 'GA', 10911),
#  ('Paulding', 'GA', 59920),
#  ('Peach', 'GA', 22906),
#  ('Pickens', 'GA', 16881),
#  ('Pierce', 'GA', 14821),
#  ('Pike', 'GA', 11441),
#  ('Polk', 'GA', 34771),
#  ('Pulaski', 'GA', 8245),
#  ('Putnam', 'GA', 15991),
#  ('Quitman', 'GA', 2420),
#  ('Rabun', 'GA', 12738),
#  ('Randolph', 'GA', 8092),
#  ('Richmond', 'GA', 195508),
#  ('Rockdale', 'GA', 64448),
#  ('Schley', 'GA', 3783),
#  ('Screven', 'GA', 14336),
#  ('Seminole', 'GA', 9097),
#  ('Spalding', 'GA', 57306),
#  ('Stephens', 'GA', 25000),
#  ('Stewart', 'GA', 5438),
#  ('Sumter', 'GA', 31245),
#  ('Talbot', 'GA', 6741),
#  ('Taliaferro', 'GA', 1883),
#  ('Tattnall', 'GA', 18588),
#  ('Taylor', 'GA', 8048),
#  ('Telfair', 'GA', 11623),
#  ('Terrell', 'GA', 11007),
#  ('Thomas', 'GA', 41419),
#  ('Tift', 'GA', 35932),
#  ('Toombs', 'GA', 25276),
#  ('Towns', 'GA', 7559),
#  ('Treutlen', 'GA', 5943),
#  ('Troup', 'GA', 57882),
#  ('Turner', 'GA', 8916),
#  ('Twiggs', 'GA', 10060),
#  ('Union', 'GA', 14427),
#  ('Upson', 'GA', 26961),
#  ('Walker', 'GA', 60654),
#  ('Walton', 'GA', 46694),
#  ('Ware', 'GA', 35589),
#  ('Warren', 'GA', 6057),
#  ('Washington', 'GA', 19953),
#  ('Wayne', 'GA', 24818),
#  ('Webster', 'GA', 2260),
#  ('Wheeler', 'GA', 4830),
#  ('White', 'GA', 15330),
#  ('Whitfield', 'GA', 78033),
#  ('Wilcox', 'GA', 7100),
#  ('Wilkes', 'GA', 10615),
#  ('Wilkinson', 'GA', 10627),
#  ('Worth', 'GA', 21643),
#  ('Hawaii', 'HI', 137531),
#  ('Honolulu', 'HI', 877198),
#  ('Kauai', 'HI', 56131),
#  ('Maui', 'HI', 115864),
#  ('Adair', 'IA', 8286),
#  ('Adams', 'IA', 4500),
#  ('Allamakee', 'IA', 14079),
#  ('Appanoose', 'IA', 13674),
#  ('Audubon', 'IA', 6875),
#  ('Benton', 'IA', 24137),
#  ('Black Hawk', 'IA', 123077),
#  ('Boone', 'IA', 25502),
#  ('Bremer', 'IA', 23218),
#  ('Buchanan', 'IA', 21294),
#  ('Buena Vista', 'IA', 20065),
#  ('Butler', 'IA', 15745),
#  ('Calhoun', 'IA', 11430),
#  ('Carroll', 'IA', 21603),
#  ('Cass', 'IA', 15047),
#  ('Cedar', 'IA', 17682),
#  ('Cerro Gordo', 'IA', 46633),
#  ('Cherokee', 'IA', 13591),
#  ('Chickasaw', 'IA', 13429),
#  ('Clarke', 'IA', 8136),
#  ('Clay', 'IA', 17412),
#  ('Clayton', 'IA', 18833),
#  ('Clinton', 'IA', 50889),
#  ('Crawford', 'IA', 16461),
#  ('Dallas', 'IA', 32947),
#  ('Davis', 'IA', 8539),
#  ('Decatur', 'IA', 8177),
#  ('Delaware', 'IA', 18394),
#  ('Des Moines', 'IA', 42679),
#  ('Dickinson', 'IA', 15664),
#  ('Dubuque', 'IA', 88566),
#  ('Emmet', 'IA', 11153),
#  ('Fayette', 'IA', 21799),
#  ('Floyd', 'IA', 16603),
#  ('Franklin', 'IA', 11106),
#  ('Fremont', 'IA', 8097),
#  ('Greene', 'IA', 10080),
#  ('Grundy', 'IA', 12303),
#  ('Guthrie', 'IA', 11406),
#  ('Hamilton', 'IA', 16193),
#  ('Hancock', 'IA', 12184),
#  ('Hardin', 'IA', 18685),
#  ('Harrison', 'IA', 15115),
#  ('Henry', 'IA', 19826),
#  ('Howard', 'IA', 9887),
#  ('Humboldt', 'IA', 10284),
#  ('Ida', 'IA', 8193),
#  ('Iowa', 'IA', 15193),
#  ('Jackson', 'IA', 20120),
#  ('Jasper', 'IA', 35163),
#  ('Jefferson', 'IA', 16829),
#  ('Johnson', 'IA', 101291),
#  ('Jones', 'IA', 20273),
#  ('Keokuk', 'IA', 11564),
#  ('Kossuth', 'IA', 18147),
#  ('Lee', 'IA', 39130),
#  ('Linn', 'IA', 178559),
#  ('Louisa', 'IA', 11793),
#  ('Lucas', 'IA', 9015),
#  ('Lyon', 'IA', 11890),
#  ('Madison', 'IA', 13490),
#  ('Mahaska', 'IA', 21927),
#  ('Marion', 'IA', 31102),
#  ('Marshall', 'IA', 38627),
#  ('Mills', 'IA', 13802),
#  ('Mitchell', 'IA', 11129),
#  ('Monona', 'IA', 9968),
#  ('Monroe', 'IA', 8177),
#  ('Montgomery', 'IA', 11939),
#  ('Muscatine', 'IA', 41435),
#  ("O'Brien", 'IA', 15349),
#  ('Osceola', 'IA', 7077),
#  ('Page', 'IA', 16676),
#  ('Palo Alto', 'IA', 10200),
#  ('Plymouth', 'IA', 24220),
#  ('Pocahontas', 'IA', 9119),
#  ('Polk', 'IA', 349560),
#  ('Pottawattamie', 'IA', 83701),
#  ('Poweshiek', 'IA', 19014),
#  ('Ringgold', 'IA', 5373),
#  ('Sac', 'IA', 12087),
#  ('Scott', 'IA', 156694),
#  ('Shelby', 'IA', 13089),
#  ('Sioux', 'IA', 31398),
#  ('Story', 'IA', 74638),
#  ('Tama', 'IA', 17878),
#  ('Taylor', 'IA', 7152),
#  ('Union', 'IA', 12416),
#  ('Van Buren', 'IA', 7767),
#  ('Wapello', 'IA', 35770),
#  ('Warren', 'IA', 38940),
#  ('Washington', 'IA', 20508),
#  ('Wayne', 'IA', 6866),
#  ('Webster', 'IA', 39206),
#  ('Winnebago', 'IA', 11900),
#  ('Winneshiek', 'IA', 21058),
#  ('Woodbury', 'IA', 101827),
#  ('Worth', 'IA', 7926),
#  ('Wright', 'IA', 14314),
#  ('Ada', 'ID', 251831),
#  ('Adams', 'ID', 3877),
#  ('Bannock', 'ID', 72115),
#  ('Bear Lake', 'ID', 6600),
#  ('Benewah', 'ID', 8780),
#  ('Bingham', 'ID', 41188),
#  ('Blaine', 'ID', 16471),
#  ('Boise', 'ID', 4768),
#  ('Bonner', 'ID', 33080),
#  ('Bonneville', 'ID', 79531),
#  ('Boundary', 'ID', 9548),
#  ('Butte', 'ID', 3008),
#  ('Camas', 'ID', 848),
#  ('Canyon', 'ID', 108510),
#  ('Caribou', 'ID', 7280),
#  ('Cassia', 'ID', 21095),
#  ('Clark', 'ID', 822),
#  ('Clearwater', 'ID', 9115),
#  ('Custer', 'ID', 4316),
#  ('Elmore', 'ID', 23181),
#  ('Franklin', 'ID', 10286),
#  ('Fremont', 'ID', 11532),
#  ('Gem', 'ID', 13856),
#  ('Gooding', 'ID', 12980),
#  ('Idaho', 'ID', 14789),
#  ('Jefferson', 'ID', 18786),
#  ('Jerome', 'ID', 17017),
#  ('Kootenai', 'ID', 91678),
#  ('Latah', 'ID', 32860),
#  ('Lemhi', 'ID', 7973),
#  ('Lewis', 'ID', 3937),
#  ('Lincoln', 'ID', 3729),
#  ('Madison', 'ID', 23811),
#  ('Minidoka', 'ID', 21065),
#  ('Nez Perce', 'ID', 36549),
#  ('Oneida', 'ID', 3843),
#  ('Owyhee', 'ID', 9520),
#  ('Payette', 'ID', 19532),
#  ('Power', 'ID', 7986),
#  ('Shoshone', 'ID', 14042),
#  ('Teton', 'ID', 4706),
#  ('Twin Falls', 'ID', 59480),
#  ('Valley', 'ID', 7877),
#  ('Washington', 'ID', 9463),
#  ('Adams', 'IL', 68043),
#  ('Alexander', 'IL', 10180),
#  ('Bond', 'IL', 15738),
#  ('Boone', 'IL', 36180),
#  ('Brown', 'IL', 6247),
#  ('Bureau', 'IL', 36049),
#  ('Calhoun', 'IL', 4948),
#  ('Carroll', 'IL', 16872),
#  ('Cass', 'IL', 13330),
#  ('Champaign', 'IL', 169096),
#  ('Christian', 'IL', 34920),
#  ('Clark', 'IL', 16284),
#  ('Clay', 'IL', 14435),
#  ('Clinton', 'IL', 35285),
#  ('Coles', 'IL', 52357),
#  ('Cook', 'IL', 5136877),
#  ('Crawford', 'IL', 19911),
#  ('Cumberland', 'IL', 11110),
#  ('De Kalb', 'IL', 83441),
#  ('De Witt', 'IL', 16824),
#  ('Douglas', 'IL', 19799),
#  ('Du Page', 'IL', 853458),
#  ('Edgar', 'IL', 19984),
#  ('Edwards', 'IL', 7262),
#  ('Effingham', 'IL', 33009),
#  ('Fayette', 'IL', 21235),
#  ('Ford', 'IL', 14127),
#  ('Franklin', 'IL', 40809),
#  ('Fulton', 'IL', 38788),
#  ('Gallatin', 'IL', 6779),
#  ('Greene', 'IL', 15643),
#  ('Grundy', 'IL', 35159),
#  ('Hamilton', 'IL', 8525),
#  ('Hancock', 'IL', 21292),
#  ('Hardin', 'IL', 5184),
#  ('Henderson', 'IL', 8432),
#  ('Henry', 'IL', 51719),
#  ('Iroquois', 'IL', 31411),
#  ('Jackson', 'IL', 61502),
#  ('Jasper', 'IL', 10591),
#  ('Jefferson', 'IL', 38998),
#  ('Jersey', 'IL', 21188),
#  ('Jo Daviess', 'IL', 21931),
#  ('Johnson', 'IL', 12426),
#  ('Kane', 'IL', 359950),
#  ('Kankakee', 'IL', 102046),
#  ('Kendall', 'IL', 45398),
#  ('Knox', 'IL', 56070),
#  ('La Salle', 'IL', 109955),
#  ('Lake', 'IL', 572431),
#  ('Lawrence', 'IL', 15918),
#  ('Lee', 'IL', 35798),
#  ('Livingston', 'IL', 40404),
#  ('Logan', 'IL', 31267),
#  ('Macon', 'IL', 116414),
#  ('Macoupin', 'IL', 48729),
#  ('Madison', 'IL', 256458),
#  ('Marion', 'IL', 41997),
#  ('Marshall', 'IL', 12791),
#  ('Mason', 'IL', 16691),
#  ('Massac', 'IL', 15370),
#  ('McDonough', 'IL', 35519),
#  ('McHenry', 'IL', 224677),
#  ('McLean', 'IL', 139274),
#  ('Menard', 'IL', 12284),
#  ('Mercer', 'IL', 17444),
#  ('Monroe', 'IL', 24719),
#  ('Montgomery', 'IL', 30994),
#  ('Morgan', 'IL', 36171),
#  ('Moultrie', 'IL', 14168),
#  ('Ogle', 'IL', 49406),
#  ('Peoria', 'IL', 183377),
#  ('Perry', 'IL', 21295),
#  ('Piatt', 'IL', 16158),
#  ('Pike', 'IL', 17338),
#  ('Pope', 'IL', 4691),
#  ('Pulaski', 'IL', 7464),
#  ('Putnam', 'IL', 5718),
#  ('Randolph', 'IL', 34296),
#  ('Richland', 'IL', 16788),
#  ('Rock Island', 'IL', 149830),
#  ('Saline', 'IL', 26521),
#  ('Sangamon', 'IL', 184731),
#  ('Schuyler', 'IL', 7798),
#  ('Scott', 'IL', 5629),
#  ('Shelby', 'IL', 22561),
#  ('St. Clair', 'IL', 265424),
#  ('Stark', 'IL', 6396),
#  ('Stephenson', 'IL', 48844),
#  ('Tazewell', 'IL', 127602),
#  ('Union', 'IL', 18114),
#  ('Vermilion', 'IL', 86541),
#  ('Wabash', 'IL', 12929),
#  ('Warren', 'IL', 18816),
#  ('Washington', 'IL', 15238),
#  ('Wayne', 'IL', 17208),
#  ('White', 'IL', 15903),
#  ('Whiteside', 'IL', 60352),
#  ('Will', 'IL', 413379),
#  ('Williamson', 'IL', 59750),
#  ('Winnebago', 'IL', 264952),
#  ('Woodford', 'IL', 34576),
#  ('Adams', 'IN', 32311),
#  ('Allen', 'IN', 308503),
#  ('Bartholomew', 'IN', 68065),
#  ('Benton', 'IN', 9703),
#  ('Blackford', 'IN', 14162),
#  ('Boone', 'IN', 41813),
#  ('Brown', 'IN', 15098),
#  ('Carroll', 'IN', 19505),
#  ('Cass', 'IN', 38584),
#  ('Clark', 'IN', 91826),
#  ('Clay', 'IN', 26306),
#  ('Clinton', 'IN', 32594),
#  ('Crawford', 'IN', 10442),
#  ('Daviess', 'IN', 28603),
#  ('De Kalb', 'IN', 37955),
#  ('Dearborn', 'IN', 44367),
#  ('Decatur', 'IN', 24998),
#  ('Delaware', 'IN', 118577),
#  ('Dubois', 'IN', 38732),
#  ('Elkhart', 'IN', 166994),
#  ('Fayette', 'IN', 26430),
#  ('Floyd', 'IN', 70058),
#  ('Fountain', 'IN', 18060),
#  ('Franklin', 'IN', 20957),
#  ('Fulton', 'IN', 19922),
#  ('Gibson', 'IN', 32165),
#  ('Grant', 'IN', 73720),
#  ('Greene', 'IN', 32696),
#  ('Hamilton', 'IN', 140650),
#  ('Hancock', 'IN', 50768),
#  ('Harrison', 'IN', 32594),
#  ('Hendricks', 'IN', 86620),
#  ('Henry', 'IN', 49275),
#  ('Howard', 'IN', 83763),
#  ('Huntington', 'IN', 36807),
#  ('Jackson', 'IN', 40403),
#  ('Jasper', 'IN', 27895),
#  ('Jay', 'IN', 21901),
#  ('Jefferson', 'IN', 30813),
#  ('Jennings', 'IN', 26168),
#  ('Johnson', 'IN', 101690),
#  ('Knox', 'IN', 40194),
#  ('Kosciusko', 'IN', 69210),
#  ('La Porte', 'IN', 110384),
#  ('Lagrange', 'IN', 31653),
#  ('Lake', 'IN', 482672),
#  ('Lawrence', 'IN', 45097),
#  ('Madison', 'IN', 132796),
#  ('Marion', 'IN', 817604),
#  ('Marshall', 'IN', 44879),
#  ('Martin', 'IN', 10545),
#  ('Miami', 'IN', 32611),
#  ('Monroe', 'IN', 115208),
#  ('Montgomery', 'IN', 36090),
#  ('Morgan', 'IN', 62115),
#  ('Newton', 'IN', 14413),
#  ('Noble', 'IN', 40884),
#  ('Ohio', 'IN', 5395),
#  ('Orange', 'IN', 19011),
#  ('Owen', 'IN', 19663),
#  ('Parke', 'IN', 16094),
#  ('Perry', 'IN', 19129),
#  ('Pike', 'IN', 12610),
#  ('Porter', 'IN', 140487),
#  ('Posey', 'IN', 26493),
#  ('Pulaski', 'IN', 12960),
#  ('Putnam', 'IN', 32939),
#  ('Randolph', 'IN', 27377),
#  ('Ripley', 'IN', 26829),
#  ('Rush', 'IN', 18456),
#  ('Scott', 'IN', 22568),
#  ('Shelby', 'IN', 42809),
#  ('Spencer', 'IN', 20374),
#  ('St. Joseph', 'IN', 258083),
#  ('Starke', 'IN', 22620),
#  ('Steuben', 'IN', 30060),
#  ('Sullivan', 'IN', 19879),
#  ('Switzerland', 'IN', 8222),
#  ('Tippecanoe', 'IN', 135285),
#  ('Tipton', 'IN', 16463),
#  ('Union', 'IN', 7292),
#  ('Vanderburgh', 'IN', 168065),
#  ('Vermillion', 'IN', 16841),
#  ('Vigo', 'IN', 106622),
#  ('Wabash', 'IN', 34896),
#  ('Warren', 'IN', 8394),
#  ('Warrick', 'IN', 49380),
#  ('Washington', 'IN', 26088),
#  ('Wayne', 'IN', 72802),
#  ('Wells', 'IN', 26506),
#  ('White', 'IN', 24505),
#  ('Whitley', 'IN', 29426),
#  ('Allen', 'KS', 14739),
#  ('Anderson', 'KS', 8000),
#  ('Atchison', 'KS', 16258),
#  ('Barber', 'KS', 5603),
#  ('Barton', 'KS', 28614),
#  ('Bourbon', 'KS', 15013),
#  ('Brown', 'KS', 11075),
#  ('Butler', 'KS', 57746),
#  ('Chase', 'KS', 2885),
#  ('Chautauqua', 'KS', 4439),
#  ('Cherokee', 'KS', 22437),
#  ('Cheyenne', 'KS', 3230),
#  ('Clark', 'KS', 2379),
#  ('Clay', 'KS', 9317),
#  ('Cloud', 'KS', 10488),
#  ('Coffey', 'KS', 8691),
#  ('Comanche', 'KS', 2099),
#  ('Cowley', 'KS', 37107),
#  ('Crawford', 'KS', 36488),
#  ('Decatur', 'KS', 3547),
#  ('Dickinson', 'KS', 19911),
#  ('Doniphan', 'KS', 7608),
#  ('Douglas', 'KS', 88206),
#  ('Edwards', 'KS', 3564),
#  ('Elk', 'KS', 3356),
#  ('Ellis', 'KS', 26145),
#  ('Ellsworth', 'KS', 6445),
#  ('Finney', 'KS', 34913),
#  ('Ford', 'KS', 28909),
#  ('Franklin', 'KS', 23164),
#  ('Geary', 'KS', 29638),
#  ('Gove', 'KS', 3091),
#  ('Graham', 'KS', 3336),
#  ('Grant', 'KS', 7837),
#  ('Gray', 'KS', 5367),
#  ('Greeley', 'KS', 1834),
#  ('Greenwood', 'KS', 8032),
#  ('Hamilton', 'KS', 2343),
#  ('Harper', 'KS', 6651),
#  ('Harvey', 'KS', 31145),
#  ('Haskell', 'KS', 4027),
#  ('Hodgeman', 'KS', 2268),
#  ('Jackson', 'KS', 11809),
#  ('Jefferson', 'KS', 17133),
#  ('Jewell', 'KS', 3952),
#  ('Johnson', 'KS', 401054),
#  ('Kearny', 'KS', 4182),
#  ('Kingman', 'KS', 8566),
#  ('Kiowa', 'KS', 3605),
#  ('Labette', 'KS', 22862),
#  ('Lane', 'KS', 2275),
#  ('Leavenworth', 'KS', 69323),
#  ('Lincoln', 'KS', 3431),
#  ('Linn', 'KS', 8698),
#  ('Logan', 'KS', 3178),
#  ('Lyon', 'KS', 34650),
#  ('Marion', 'KS', 12961),
#  ('Marshall', 'KS', 11261),
#  ('McPherson', 'KS', 27267),
#  ('Meade', 'KS', 4355),
#  ('Miami', 'KS', 25187),
#  ('Mitchell', 'KS', 7092),
#  ('Montgomery', 'KS', 37694),
#  ('Morris', 'KS', 6327),
#  ('Morton', 'KS', 3303),
#  ('Nemaha', 'KS', 10443),
#  ('Neosho', 'KS', 16994),
#  ('Ness', 'KS', 3752),
#  ('Norton', 'KS', 5735),
#  ('Osage', 'KS', 16729),
#  ('Osborne', 'KS', 4696),
#  ('Ottawa', 'KS', 5749),
#  ('Pawnee', 'KS', 7615),
#  ('Phillips', 'KS', 6270),
#  ('Pottawatomie', 'KS', 17548),
#  ('Pratt', 'KS', 9696),
#  ('Rawlins', 'KS', 3234),
#  ('Reno', 'KS', 63263),
#  ('Republic', 'KS', 6215),
#  ('Rice', 'KS', 10086),
#  ('Riley', 'KS', 69784),
#  ('Rooks', 'KS', 5884),
#  ('Rush', 'KS', 3541),
#  ('Russell', 'KS', 7701),
#  ('Saline', 'KS', 51831),
#  ('Scott', 'KS', 5074),
#  ('Sedgwick', 'KS', 419333),
#  ('Seward', 'KS', 19370),
#  ('Shawnee', 'KS', 165062),
#  ('Sheridan', 'KS', 2824),
#  ('Sherman', 'KS', 6706),
#  ('Smith', 'KS', 4782),
#  ('Stafford', 'KS', 5193),
#  ('Stanton', 'KS', 2331),
#  ('Stevens', 'KS', 5257),
#  ('Sumner', 'KS', 26519),
#  ('Thomas', 'KS', 8331),
#  ('Trego', 'KS', 3449),
#  ('Wabaunsee', 'KS', 6603),
#  ('Wallace', 'KS', 1798),
#  ('Washington', 'KS', 6833),
#  ('Wichita', 'KS', 2841),
#  ('Wilson', 'KS', 10321),
#  ('Woodson', 'KS', 3999),
#  ('Wyandotte', 'KS', 153826),
#  ('Adair', 'KY', 16292),
#  ('Allen', 'KY', 15706),
#  ('Anderson', 'KY', 17152),
#  ('Ballard', 'KY', 8232),
#  ('Barren', 'KY', 35768),
#  ('Bath', 'KY', 10159),
#  ('Bell', 'KY', 30490),
#  ('Boone', 'KY', 70097),
#  ('Bourbon', 'KY', 19257),
#  ('Boyd', 'KY', 50613),
#  ('Boyle', 'KY', 26699),
#  ('Bracken', 'KY', 8209),
#  ('Breathitt', 'KY', 15539),
#  ...]

# %%
dt3 = [(c,s,int(p)) for (c,s,p) in dt2]
dt3
# Out:
# [('Aleutians East', 'AK', 2305),
#  ('Aleutians West', 'AK', 5259),
#  ('Anchorage', 'AK', 251335),
#  ('Bethel', 'AK', 15525),
#  ('Bristol Bay', 'AK', 1023),
#  ('Dillingham', 'AK', 4360),
#  ('Fairbanks North Star', 'AK', 83374),
#  ('Haines', 'AK', 2181),
#  ('Juneau', 'AK', 29378),
#  ('Kenai Peninsula', 'AK', 46151),
#  ('Ketchikan Gateway', 'AK', 14422),
#  ('Kodiak Island', 'AK', 14987),
#  ('Lake and Peninsula', 'AK', 1787),
#  ('Matanuska-Susitna', 'AK', 50686),
#  ('Nome', 'AK', 8754),
#  ('North Slope', 'AK', 7024),
#  ('Northwest Arctic', 'AK', 6501),
#  ('Prince of Wales-Outer Ketchikan', 'AK', 7109),
#  ('Sitka', 'AK', 8710),
#  ('Skagway-Yakutat-Angoon', 'AK', 4655),
#  ('Southeast Fairbanks', 'AK', 6018),
#  ('Valdez-Cordova', 'AK', 10475),
#  ('Wade Hampton', 'AK', 6574),
#  ('Wrangell-Petersburg', 'AK', 7089),
#  ('Yukon-Koyukuk', 'AK', 6057),
#  ('Autauga', 'AL', 39381),
#  ('Baldwin', 'AL', 120198),
#  ('Barbour', 'AL', 26469),
#  ('Bibb', 'AL', 17942),
#  ('Blount', 'AL', 42721),
#  ('Bullock', 'AL', 11149),
#  ('Butler', 'AL', 21798),
#  ('Calhoun', 'AL', 117263),
#  ('Chambers', 'AL', 37262),
#  ('Cherokee', 'AL', 21038),
#  ('Chilton', 'AL', 34912),
#  ('Choctaw', 'AL', 16079),
#  ('Clarke', 'AL', 27993),
#  ('Clay', 'AL', 13551),
#  ('Cleburne', 'AL', 13272),
#  ('Coffee', 'AL', 42359),
#  ('Colbert', 'AL', 52586),
#  ('Conecuh', 'AL', 14022),
#  ('Coosa', 'AL', 11680),
#  ('Covington', 'AL', 37459),
#  ('Crenshaw', 'AL', 13624),
#  ('Cullman', 'AL', 72489),
#  ('Dale', 'AL', 50001),
#  ('Dallas', 'AL', 48022),
#  ('De Kalb', 'AL', 57271),
#  ('Elmore', 'AL', 57071),
#  ('Escambia', 'AL', 36541),
#  ('Etowah', 'AL', 100259),
#  ('Fayette', 'AL', 18019),
#  ('Franklin', 'AL', 29313),
#  ('Geneva', 'AL', 24727),
#  ('Greene', 'AL', 10076),
#  ('Hale', 'AL', 16212),
#  ('Henry', 'AL', 15752),
#  ('Houston', 'AL', 84367),
#  ('Jackson', 'AL', 50128),
#  ('Jefferson', 'AL', 657827),
#  ('Lamar', 'AL', 15754),
#  ('Lauderdale', 'AL', 83598),
#  ('Lawrence', 'AL', 32803),
#  ('Lee', 'AL', 94029),
#  ('Limestone', 'AL', 59344),
#  ('Lowndes', 'AL', 12946),
#  ('Macon', 'AL', 23959),
#  ('Madison', 'AL', 258340),
#  ('Marengo', 'AL', 23662),
#  ('Marion', 'AL', 30382),
#  ('Marshall', 'AL', 78195),
#  ('Mobile', 'AL', 397413),
#  ('Monroe', 'AL', 24550),
#  ('Montgomery', 'AL', 218880),
#  ('Morgan', 'AL', 107034),
#  ('Perry', 'AL', 12708),
#  ('Pickens', 'AL', 20956),
#  ('Pike', 'AL', 28848),
#  ('Randolph', 'AL', 20323),
#  ('Russell', 'AL', 51436),
#  ('Shelby', 'AL', 123500),
#  ('St. Clair', 'AL', 57713),
#  ('Sumter', 'AL', 16390),
#  ('Talladega', 'AL', 76737),
#  ('Tallapoosa', 'AL', 39737),
#  ('Tuscaloosa', 'AL', 158732),
#  ('Walker', 'AL', 69678),
#  ('Washington', 'AL', 17385),
#  ('Wilcox', 'AL', 13628),
#  ('Winston', 'AL', 23489),
#  ('Arkansas', 'AR', 21032),
#  ('Ashley', 'AR', 24651),
#  ('Baxter', 'AR', 35666),
#  ('Benton', 'AR', 120932),
#  ('Boone', 'AR', 31364),
#  ('Bradley', 'AR', 11650),
#  ('Calhoun', 'AR', 5801),
#  ('Carroll', 'AR', 21933),
#  ('Chicot', 'AR', 15289),
#  ('Clark', 'AR', 22101),
#  ('Clay', 'AR', 17601),
#  ('Cleburne', 'AR', 21865),
#  ('Cleveland', 'AR', 8084),
#  ('Columbia', 'AR', 25670),
#  ('Conway', 'AR', 19671),
#  ('Craighead', 'AR', 74794),
#  ('Crawford', 'AR', 48100),
#  ('Crittenden', 'AR', 49889),
#  ('Cross', 'AR', 19370),
#  ('Dallas', 'AR', 9493),
#  ('Desha', 'AR', 15487),
#  ('Drew', 'AR', 17853),
#  ('Faulkner', 'AR', 71758),
#  ('Franklin', 'AR', 16122),
#  ('Fulton', 'AR', 10732),
#  ('Garland', 'AR', 81049),
#  ('Grant', 'AR', 15022),
#  ('Greene', 'AR', 34620),
#  ('Hempstead', 'AR', 22194),
#  ('Hot Spring', 'AR', 27876),
#  ('Howard', 'AR', 13655),
#  ('Independence', 'AR', 32752),
#  ('Izard', 'AR', 12619),
#  ('Jackson', 'AR', 18622),
#  ('Jefferson', 'AR', 84042),
#  ('Johnson', 'AR', 20508),
#  ('Lafayette', 'AR', 9213),
#  ('Lawrence', 'AR', 17468),
#  ('Lee', 'AR', 12962),
#  ('Lincoln', 'AR', 14119),
#  ('Little River', 'AR', 13413),
#  ('Logan', 'AR', 21050),
#  ('Lonoke', 'AR', 45966),
#  ('Madison', 'AR', 12943),
#  ('Marion', 'AR', 13855),
#  ('Miller', 'AR', 39082),
#  ('Mississippi', 'AR', 50811),
#  ('Monroe', 'AR', 10374),
#  ('Montgomery', 'AR', 8356),
#  ('Nevada', 'AR', 9996),
#  ('Newton', 'AR', 7989),
#  ('Ouachita', 'AR', 28580),
#  ('Perry', 'AR', 8823),
#  ('Phillips', 'AR', 27386),
#  ('Pike', 'AR', 10332),
#  ('Poinsett', 'AR', 24640),
#  ('Polk', 'AR', 18832),
#  ('Pope', 'AR', 51181),
#  ('Prairie', 'AR', 9312),
#  ('Pulaski', 'AR', 352240),
#  ('Randolph', 'AR', 17430),
#  ('Saline', 'AR', 73604),
#  ('Scott', 'AR', 10628),
#  ('Searcy', 'AR', 7626),
#  ('Sebastian', 'AR', 104402),
#  ('Sevier', 'AR', 14501),
#  ('Sharp', 'AR', 16172),
#  ('St. Francis', 'AR', 27859),
#  ('Stone', 'AR', 10784),
#  ('Union', 'AR', 46191),
#  ('Van Buren', 'AR', 15198),
#  ('Washington', 'AR', 131708),
#  ('White', 'AR', 61016),
#  ('Woodruff', 'AR', 9121),
#  ('Yell', 'AR', 18739),
#  ('Apache', 'AZ', 67803),
#  ('Cochise', 'AZ', 110062),
#  ('Coconino', 'AZ', 110498),
#  ('Gila', 'AZ', 46039),
#  ('Graham', 'AZ', 29589),
#  ('Greenlee', 'AZ', 9232),
#  ('La Paz', 'AZ', 14310),
#  ('Maricopa', 'AZ', 2432372),
#  ('Mohave', 'AZ', 121602),
#  ('Navajo', 'AZ', 89253),
#  ('Pima', 'AZ', 752428),
#  ('Pinal', 'AZ', 131210),
#  ('Santa Cruz', 'AZ', 36078),
#  ('Yavapai', 'AZ', 134595),
#  ('Yuma', 'AZ', 132869),
#  ('Alameda', 'CA', 1323312),
#  ('Alpine', 'CA', 1229),
#  ('Amador', 'CA', 33162),
#  ('Butte', 'CA', 192880),
#  ('Calaveras', 'CA', 37694),
#  ('Colusa', 'CA', 17596),
#  ('Contra Costa', 'CA', 872099),
#  ('Del Norte', 'CA', 26956),
#  ('El Dorado', 'CA', 148217),
#  ('Fresno', 'CA', 737289),
#  ('Glenn', 'CA', 26028),
#  ('Humboldt', 'CA', 122747),
#  ('Imperial', 'CA', 138072),
#  ('Inyo', 'CA', 18435),
#  ('Kern', 'CA', 617528),
#  ('Kings', 'CA', 113089),
#  ('Lake', 'CA', 55783),
#  ('Lassen', 'CA', 28279),
#  ('Los Angeles', 'CA', 9138789),
#  ('Madera', 'CA', 107004),
#  ('Marin', 'CA', 233883),
#  ('Mariposa', 'CA', 15772),
#  ('Mendocino', 'CA', 82499),
#  ('Merced', 'CA', 194407),
#  ('Modoc', 'CA', 9559),
#  ('Mono', 'CA', 10433),
#  ('Monterey', 'CA', 348841),
#  ('Napa', 'CA', 115751),
#  ('Nevada', 'CA', 87318),
#  ('Orange', 'CA', 2563971),
#  ('Placer', 'CA', 205239),
#  ('Plumas', 'CA', 20451),
#  ('Riverside', 'CA', 1379801),
#  ('Sacramento', 'CA', 1103499),
#  ('San Benito', 'CA', 42625),
#  ('San Bernardino', 'CA', 1569586),
#  ('San Diego', 'CA', 2644132),
#  ('San Francisco', 'CA', 730570),
#  ('San Joaquin', 'CA', 523969),
#  ('San Luis Obispo', 'CA', 226071),
#  ('San Mateo', 'CA', 681362),
#  ('Santa Barbara', 'CA', 381401),
#  ('Santa Clara', 'CA', 1565253),
#  ('Santa Cruz', 'CA', 236669),
#  ('Shasta', 'CA', 160940),
#  ('Sierra', 'CA', 3399),
#  ('Siskiyou', 'CA', 44253),
#  ('Solano', 'CA', 366134),
#  ('Sonoma', 'CA', 414569),
#  ('Stanislaus', 'CA', 410870),
#  ('Sutter', 'CA', 74963),
#  ('Tehama', 'CA', 53798),
#  ('Trinity', 'CA', 13429),
#  ('Tulare', 'CA', 346843),
#  ('Tuolumne', 'CA', 51777),
#  ('Ventura', 'CA', 710018),
#  ('Yolo', 'CA', 147769),
#  ('Yuba', 'CA', 61141),
#  ('Adams', 'CO', 303297),
#  ('Alamosa', 'CO', 14215),
#  ('Arapahoe', 'CO', 449103),
#  ('Archuleta', 'CO', 7100),
#  ('Baca', 'CO', 4384),
#  ('Bent', 'CO', 5518),
#  ('Boulder', 'CO', 253850),
#  ('Chaffee', 'CO', 14413),
#  ('Cheyenne', 'CO', 2312),
#  ('Clear Creek', 'CO', 8745),
#  ('Conejos', 'CO', 7807),
#  ('Costilla', 'CO', 3384),
#  ('Crowley', 'CO', 4303),
#  ('Custer', 'CO', 2702),
#  ('Delta', 'CO', 25077),
#  ('Denver', 'CO', 494462),
#  ('Dolores', 'CO', 1588),
#  ('Douglas', 'CO', 99577),
#  ('Eagle', 'CO', 28844),
#  ('El Paso', 'CO', 465800),
#  ('Elbert', 'CO', 14565),
#  ('Fremont', 'CO', 39794),
#  ('Garfield', 'CO', 35338),
#  ('Gilpin', 'CO', 3576),
#  ('Grand', 'CO', 9188),
#  ('Gunnison', 'CO', 11931),
#  ('Hinsdale', 'CO', 648),
#  ('Huerfano', 'CO', 6356),
#  ('Jackson', 'CO', 1537),
#  ('Jefferson', 'CO', 484869),
#  ('Kiowa', 'CO', 1627),
#  ('Kit Carson', 'CO', 7301),
#  ('La Plata', 'CO', 38314),
#  ('Lake', 'CO', 6296),
#  ('Larimer', 'CO', 217215),
#  ('Las Animas', 'CO', 14268),
#  ('Lincoln', 'CO', 5602),
#  ('Logan', 'CO', 17869),
#  ('Mesa', 'CO', 106548),
#  ('Mineral', 'CO', 634),
#  ('Moffat', 'CO', 12136),
#  ('Montezuma', 'CO', 21591),
#  ('Montrose', 'CO', 28829),
#  ('Morgan', 'CO', 23729),
#  ('Otero', 'CO', 20788),
#  ('Ouray', 'CO', 3033),
#  ('Park', 'CO', 10589),
#  ('Phillips', 'CO', 4309),
#  ('Pitkin', 'CO', 13589),
#  ('Prowers', 'CO', 13591),
#  ('Pueblo', 'CO', 129759),
#  ('Rio Blanco', 'CO', 6472),
#  ('Rio Grande', 'CO', 11262),
#  ('Routt', 'CO', 16709),
#  ('Saguache', 'CO', 5514),
#  ('San Juan', 'CO', 546),
#  ('San Miguel', 'CO', 4929),
#  ('Sedgwick', 'CO', 2606),
#  ('Summit', 'CO', 17204),
#  ('Teller', 'CO', 17478),
#  ('Washington', 'CO', 4687),
#  ('Weld', 'CO', 148014),
#  ('Yuma', 'CO', 9264),
#  ('Fairfield', 'CT', 830728),
#  ('Hartford', 'CT', 835589),
#  ('Litchfield', 'CT', 179316),
#  ('Middlesex', 'CT', 148030),
#  ('New Haven', 'CT', 794785),
#  ('New London', 'CT', 250404),
#  ('Tolland', 'CT', 131604),
#  ('Windham', 'CT', 104206),
#  ('Washington', 'DC', 554256),
#  ('Kent', 'DE', 121725),
#  ('New Castle', 'DE', 467889),
#  ('Sussex', 'DE', 127583),
#  ('Alachua', 'FL', 196106),
#  ('Baker', 'FL', 20153),
#  ('Bay', 'FL', 142690),
#  ('Bradford', 'FL', 24182),
#  ('Brevard', 'FL', 450646),
#  ('Broward', 'FL', 1412165),
#  ('Calhoun', 'FL', 11858),
#  ('Charlotte', 'FL', 129381),
#  ('Citrus', 'FL', 107333),
#  ('Clay', 'FL', 124431),
#  ('Collier', 'FL', 181381),
#  ('Columbia', 'FL', 48376),
#  ('Dade', 'FL', 2031336),
#  ('De Soto', 'FL', 25048),
#  ('Dixie', 'FL', 12159),
#  ('Duval', 'FL', 701673),
#  ('Escambia', 'FL', 273804),
#  ('Flagler', 'FL', 40643),
#  ('Franklin', 'FL', 10301),
#  ('Gadsden', 'FL', 43378),
#  ('Gilchrist', 'FL', 12332),
#  ('Glades', 'FL', 7665),
#  ('Gulf', 'FL', 13390),
#  ('Hamilton', 'FL', 11773),
#  ('Hardee', 'FL', 19952),
#  ('Hendry', 'FL', 28114),
#  ('Hernando', 'FL', 120054),
#  ('Highlands', 'FL', 74507),
#  ('Hillsborough', 'FL', 884608),
#  ('Holmes', 'FL', 17520),
#  ('Indian River', 'FL', 97144),
#  ('Jackson', 'FL', 43891),
#  ('Jefferson', 'FL', 12950),
#  ('Lafayette', 'FL', 6043),
#  ('Lake', 'FL', 180160),
#  ('Lee', 'FL', 375381),
#  ('Leon', 'FL', 213917),
#  ('Levy', 'FL', 29738),
#  ('Liberty', 'FL', 6400),
#  ('Madison', 'FL', 17231),
#  ('Manatee', 'FL', 229864),
#  ('Marion', 'FL', 226678),
#  ('Martin', 'FL', 111069),
#  ('Monroe', 'FL', 81850),
#  ('Nassau', 'FL', 50767),
#  ('Okaloosa', 'FL', 163707),
#  ('Okeechobee', 'FL', 30222),
#  ('Orange', 'FL', 749631),
#  ('Osceola', 'FL', 130771),
#  ('Palm Beach', 'FL', 972093),
#  ('Pasco', 'FL', 304938),
#  ('Pinellas', 'FL', 870884),
#  ('Polk', 'FL', 436701),
#  ('Putnam', 'FL', 69481),
#  ('Santa Rosa', 'FL', 104110),
#  ('Sarasota', 'FL', 295942),
#  ('Seminole', 'FL', 330012),
#  ('St. Johns', 'FL', 102174),
#  ('St. Lucie', 'FL', 172483),
#  ('Sumter', 'FL', 34788),
#  ('Suwannee', 'FL', 30103),
#  ('Taylor', 'FL', 17445),
#  ('Union', 'FL', 12433),
#  ('Volusia', 'FL', 408261),
#  ('Wakulla', 'FL', 17111),
#  ('Walton', 'FL', 33615),
#  ('Washington', 'FL', 18623),
#  ('Appling', 'GA', 16359),
#  ('Atkinson', 'GA', 6749),
#  ('Bacon', 'GA', 10438),
#  ('Baker', 'GA', 3766),
#  ('Baldwin', 'GA', 41854),
#  ('Banks', 'GA', 11616),
#  ('Barrow', 'GA', 35699),
#  ('Bartow', 'GA', 63732),
#  ('Ben Hill', 'GA', 17258),
#  ('Berrien', 'GA', 15466),
#  ('Bibb', 'GA', 155066),
#  ('Bleckley', 'GA', 10958),
#  ('Brantley', 'GA', 12698),
#  ('Brooks', 'GA', 15837),
#  ('Bryan', 'GA', 21190),
#  ('Bulloch', 'GA', 48642),
#  ('Burke', 'GA', 21742),
#  ('Butts', 'GA', 16025),
#  ('Calhoun', 'GA', 4851),
#  ('Camden', 'GA', 40714),
#  ('Candler', 'GA', 8637),
#  ('Carroll', 'GA', 77977),
#  ('Catoosa', 'GA', 48008),
#  ('Charlton', 'GA', 9296),
#  ('Chatham', 'GA', 226160),
#  ('Chattahoochee', 'GA', 15871),
#  ('Chattooga', 'GA', 22884),
#  ('Cherokee', 'GA', 114751),
#  ('Clarke', 'GA', 90207),
#  ('Clay', 'GA', 3473),
#  ('Clayton', 'GA', 198551),
#  ('Clinch', 'GA', 6438),
#  ('Cobb', 'GA', 525453),
#  ('Coffee', 'GA', 32697),
#  ('Colquitt', 'GA', 38072),
#  ('Columbia', 'GA', 83674),
#  ('Cook', 'GA', 13950),
#  ('Coweta', 'GA', 72021),
#  ('Crawford', 'GA', 10166),
#  ('Crisp', 'GA', 20716),
#  ('Dade', 'GA', 14158),
#  ('Dawson', 'GA', 12237),
#  ('De Kalb', 'GA', 582095),
#  ('Decatur', 'GA', 26390),
#  ('Dodge', 'GA', 17956),
#  ('Dooly', 'GA', 10314),
#  ('Dougherty', 'GA', 97511),
#  ('Douglas', 'GA', 82297),
#  ('Early', 'GA', 12198),
#  ('Echols', 'GA', 2325),
#  ('Effingham', 'GA', 32118),
#  ('Elbert', 'GA', 19173),
#  ('Emanuel', 'GA', 20954),
#  ('Evans', 'GA', 9438),
#  ('Fannin', 'GA', 17480),
#  ('Fayette', 'GA', 78879),
#  ('Floyd', 'GA', 83935),
#  ('Forsyth', 'GA', 62335),
#  ('Franklin', 'GA', 17701),
#  ('Fulton', 'GA', 700689),
#  ('Gilmer', 'GA', 15916),
#  ('Glascock', 'GA', 2456),
#  ('Glynn', 'GA', 65565),
#  ('Gordon', 'GA', 38442),
#  ('Grady', 'GA', 21312),
#  ('Greene', 'GA', 12781),
#  ('Gwinnett', 'GA', 457058),
#  ('Habersham', 'GA', 30146),
#  ('Hall', 'GA', 108238),
#  ('Hancock', 'GA', 9100),
#  ('Haralson', 'GA', 23378),
#  ('Harris', 'GA', 20479),
#  ('Hart', 'GA', 20848),
#  ('Heard', 'GA', 9573),
#  ('Henry', 'GA', 84553),
#  ('Houston', 'GA', 99647),
#  ('Irwin', 'GA', 8725),
#  ('Jackson', 'GA', 33921),
#  ('Jasper', 'GA', 9168),
#  ('Jeff Davis', 'GA', 12366),
#  ('Jefferson', 'GA', 17872),
#  ('Jenkins', 'GA', 8658),
#  ('Johnson', 'GA', 8436),
#  ('Jones', 'GA', 22077),
#  ('Lamar', 'GA', 13797),
#  ('Lanier', 'GA', 6312),
#  ('Laurens', 'GA', 42852),
#  ('Lee', 'GA', 19922),
#  ('Liberty', 'GA', 58749),
#  ('Lincoln', 'GA', 8055),
#  ('Long', 'GA', 7885),
#  ('Lowndes', 'GA', 82952),
#  ('Lumpkin', 'GA', 16822),
#  ('Macon', 'GA', 13249),
#  ('Madison', 'GA', 23396),
#  ('Marion', 'GA', 6370),
#  ('McDuffie', 'GA', 21627),
#  ('McIntosh', 'GA', 9456),
#  ('Meriwether', 'GA', 23041),
#  ('Miller', 'GA', 6161),
#  ('Mitchell', 'GA', 20859),
#  ('Monroe', 'GA', 18950),
#  ('Montgomery', 'GA', 7635),
#  ('Morgan', 'GA', 14006),
#  ('Murray', 'GA', 30032),
#  ('Muscogee', 'GA', 184594),
#  ('Newton', 'GA', 50644),
#  ('Oconee', 'GA', 21190),
#  ('Oglethorpe', 'GA', 10911),
#  ('Paulding', 'GA', 59920),
#  ('Peach', 'GA', 22906),
#  ('Pickens', 'GA', 16881),
#  ('Pierce', 'GA', 14821),
#  ('Pike', 'GA', 11441),
#  ('Polk', 'GA', 34771),
#  ('Pulaski', 'GA', 8245),
#  ('Putnam', 'GA', 15991),
#  ('Quitman', 'GA', 2420),
#  ('Rabun', 'GA', 12738),
#  ('Randolph', 'GA', 8092),
#  ('Richmond', 'GA', 195508),
#  ('Rockdale', 'GA', 64448),
#  ('Schley', 'GA', 3783),
#  ('Screven', 'GA', 14336),
#  ('Seminole', 'GA', 9097),
#  ('Spalding', 'GA', 57306),
#  ('Stephens', 'GA', 25000),
#  ('Stewart', 'GA', 5438),
#  ('Sumter', 'GA', 31245),
#  ('Talbot', 'GA', 6741),
#  ('Taliaferro', 'GA', 1883),
#  ('Tattnall', 'GA', 18588),
#  ('Taylor', 'GA', 8048),
#  ('Telfair', 'GA', 11623),
#  ('Terrell', 'GA', 11007),
#  ('Thomas', 'GA', 41419),
#  ('Tift', 'GA', 35932),
#  ('Toombs', 'GA', 25276),
#  ('Towns', 'GA', 7559),
#  ('Treutlen', 'GA', 5943),
#  ('Troup', 'GA', 57882),
#  ('Turner', 'GA', 8916),
#  ('Twiggs', 'GA', 10060),
#  ('Union', 'GA', 14427),
#  ('Upson', 'GA', 26961),
#  ('Walker', 'GA', 60654),
#  ('Walton', 'GA', 46694),
#  ('Ware', 'GA', 35589),
#  ('Warren', 'GA', 6057),
#  ('Washington', 'GA', 19953),
#  ('Wayne', 'GA', 24818),
#  ('Webster', 'GA', 2260),
#  ('Wheeler', 'GA', 4830),
#  ('White', 'GA', 15330),
#  ('Whitfield', 'GA', 78033),
#  ('Wilcox', 'GA', 7100),
#  ('Wilkes', 'GA', 10615),
#  ('Wilkinson', 'GA', 10627),
#  ('Worth', 'GA', 21643),
#  ('Hawaii', 'HI', 137531),
#  ('Honolulu', 'HI', 877198),
#  ('Kauai', 'HI', 56131),
#  ('Maui', 'HI', 115864),
#  ('Adair', 'IA', 8286),
#  ('Adams', 'IA', 4500),
#  ('Allamakee', 'IA', 14079),
#  ('Appanoose', 'IA', 13674),
#  ('Audubon', 'IA', 6875),
#  ('Benton', 'IA', 24137),
#  ('Black Hawk', 'IA', 123077),
#  ('Boone', 'IA', 25502),
#  ('Bremer', 'IA', 23218),
#  ('Buchanan', 'IA', 21294),
#  ('Buena Vista', 'IA', 20065),
#  ('Butler', 'IA', 15745),
#  ('Calhoun', 'IA', 11430),
#  ('Carroll', 'IA', 21603),
#  ('Cass', 'IA', 15047),
#  ('Cedar', 'IA', 17682),
#  ('Cerro Gordo', 'IA', 46633),
#  ('Cherokee', 'IA', 13591),
#  ('Chickasaw', 'IA', 13429),
#  ('Clarke', 'IA', 8136),
#  ('Clay', 'IA', 17412),
#  ('Clayton', 'IA', 18833),
#  ('Clinton', 'IA', 50889),
#  ('Crawford', 'IA', 16461),
#  ('Dallas', 'IA', 32947),
#  ('Davis', 'IA', 8539),
#  ('Decatur', 'IA', 8177),
#  ('Delaware', 'IA', 18394),
#  ('Des Moines', 'IA', 42679),
#  ('Dickinson', 'IA', 15664),
#  ('Dubuque', 'IA', 88566),
#  ('Emmet', 'IA', 11153),
#  ('Fayette', 'IA', 21799),
#  ('Floyd', 'IA', 16603),
#  ('Franklin', 'IA', 11106),
#  ('Fremont', 'IA', 8097),
#  ('Greene', 'IA', 10080),
#  ('Grundy', 'IA', 12303),
#  ('Guthrie', 'IA', 11406),
#  ('Hamilton', 'IA', 16193),
#  ('Hancock', 'IA', 12184),
#  ('Hardin', 'IA', 18685),
#  ('Harrison', 'IA', 15115),
#  ('Henry', 'IA', 19826),
#  ('Howard', 'IA', 9887),
#  ('Humboldt', 'IA', 10284),
#  ('Ida', 'IA', 8193),
#  ('Iowa', 'IA', 15193),
#  ('Jackson', 'IA', 20120),
#  ('Jasper', 'IA', 35163),
#  ('Jefferson', 'IA', 16829),
#  ('Johnson', 'IA', 101291),
#  ('Jones', 'IA', 20273),
#  ('Keokuk', 'IA', 11564),
#  ('Kossuth', 'IA', 18147),
#  ('Lee', 'IA', 39130),
#  ('Linn', 'IA', 178559),
#  ('Louisa', 'IA', 11793),
#  ('Lucas', 'IA', 9015),
#  ('Lyon', 'IA', 11890),
#  ('Madison', 'IA', 13490),
#  ('Mahaska', 'IA', 21927),
#  ('Marion', 'IA', 31102),
#  ('Marshall', 'IA', 38627),
#  ('Mills', 'IA', 13802),
#  ('Mitchell', 'IA', 11129),
#  ('Monona', 'IA', 9968),
#  ('Monroe', 'IA', 8177),
#  ('Montgomery', 'IA', 11939),
#  ('Muscatine', 'IA', 41435),
#  ("O'Brien", 'IA', 15349),
#  ('Osceola', 'IA', 7077),
#  ('Page', 'IA', 16676),
#  ('Palo Alto', 'IA', 10200),
#  ('Plymouth', 'IA', 24220),
#  ('Pocahontas', 'IA', 9119),
#  ('Polk', 'IA', 349560),
#  ('Pottawattamie', 'IA', 83701),
#  ('Poweshiek', 'IA', 19014),
#  ('Ringgold', 'IA', 5373),
#  ('Sac', 'IA', 12087),
#  ('Scott', 'IA', 156694),
#  ('Shelby', 'IA', 13089),
#  ('Sioux', 'IA', 31398),
#  ('Story', 'IA', 74638),
#  ('Tama', 'IA', 17878),
#  ('Taylor', 'IA', 7152),
#  ('Union', 'IA', 12416),
#  ('Van Buren', 'IA', 7767),
#  ('Wapello', 'IA', 35770),
#  ('Warren', 'IA', 38940),
#  ('Washington', 'IA', 20508),
#  ('Wayne', 'IA', 6866),
#  ('Webster', 'IA', 39206),
#  ('Winnebago', 'IA', 11900),
#  ('Winneshiek', 'IA', 21058),
#  ('Woodbury', 'IA', 101827),
#  ('Worth', 'IA', 7926),
#  ('Wright', 'IA', 14314),
#  ('Ada', 'ID', 251831),
#  ('Adams', 'ID', 3877),
#  ('Bannock', 'ID', 72115),
#  ('Bear Lake', 'ID', 6600),
#  ('Benewah', 'ID', 8780),
#  ('Bingham', 'ID', 41188),
#  ('Blaine', 'ID', 16471),
#  ('Boise', 'ID', 4768),
#  ('Bonner', 'ID', 33080),
#  ('Bonneville', 'ID', 79531),
#  ('Boundary', 'ID', 9548),
#  ('Butte', 'ID', 3008),
#  ('Camas', 'ID', 848),
#  ('Canyon', 'ID', 108510),
#  ('Caribou', 'ID', 7280),
#  ('Cassia', 'ID', 21095),
#  ('Clark', 'ID', 822),
#  ('Clearwater', 'ID', 9115),
#  ('Custer', 'ID', 4316),
#  ('Elmore', 'ID', 23181),
#  ('Franklin', 'ID', 10286),
#  ('Fremont', 'ID', 11532),
#  ('Gem', 'ID', 13856),
#  ('Gooding', 'ID', 12980),
#  ('Idaho', 'ID', 14789),
#  ('Jefferson', 'ID', 18786),
#  ('Jerome', 'ID', 17017),
#  ('Kootenai', 'ID', 91678),
#  ('Latah', 'ID', 32860),
#  ('Lemhi', 'ID', 7973),
#  ('Lewis', 'ID', 3937),
#  ('Lincoln', 'ID', 3729),
#  ('Madison', 'ID', 23811),
#  ('Minidoka', 'ID', 21065),
#  ('Nez Perce', 'ID', 36549),
#  ('Oneida', 'ID', 3843),
#  ('Owyhee', 'ID', 9520),
#  ('Payette', 'ID', 19532),
#  ('Power', 'ID', 7986),
#  ('Shoshone', 'ID', 14042),
#  ('Teton', 'ID', 4706),
#  ('Twin Falls', 'ID', 59480),
#  ('Valley', 'ID', 7877),
#  ('Washington', 'ID', 9463),
#  ('Adams', 'IL', 68043),
#  ('Alexander', 'IL', 10180),
#  ('Bond', 'IL', 15738),
#  ('Boone', 'IL', 36180),
#  ('Brown', 'IL', 6247),
#  ('Bureau', 'IL', 36049),
#  ('Calhoun', 'IL', 4948),
#  ('Carroll', 'IL', 16872),
#  ('Cass', 'IL', 13330),
#  ('Champaign', 'IL', 169096),
#  ('Christian', 'IL', 34920),
#  ('Clark', 'IL', 16284),
#  ('Clay', 'IL', 14435),
#  ('Clinton', 'IL', 35285),
#  ('Coles', 'IL', 52357),
#  ('Cook', 'IL', 5136877),
#  ('Crawford', 'IL', 19911),
#  ('Cumberland', 'IL', 11110),
#  ('De Kalb', 'IL', 83441),
#  ('De Witt', 'IL', 16824),
#  ('Douglas', 'IL', 19799),
#  ('Du Page', 'IL', 853458),
#  ('Edgar', 'IL', 19984),
#  ('Edwards', 'IL', 7262),
#  ('Effingham', 'IL', 33009),
#  ('Fayette', 'IL', 21235),
#  ('Ford', 'IL', 14127),
#  ('Franklin', 'IL', 40809),
#  ('Fulton', 'IL', 38788),
#  ('Gallatin', 'IL', 6779),
#  ('Greene', 'IL', 15643),
#  ('Grundy', 'IL', 35159),
#  ('Hamilton', 'IL', 8525),
#  ('Hancock', 'IL', 21292),
#  ('Hardin', 'IL', 5184),
#  ('Henderson', 'IL', 8432),
#  ('Henry', 'IL', 51719),
#  ('Iroquois', 'IL', 31411),
#  ('Jackson', 'IL', 61502),
#  ('Jasper', 'IL', 10591),
#  ('Jefferson', 'IL', 38998),
#  ('Jersey', 'IL', 21188),
#  ('Jo Daviess', 'IL', 21931),
#  ('Johnson', 'IL', 12426),
#  ('Kane', 'IL', 359950),
#  ('Kankakee', 'IL', 102046),
#  ('Kendall', 'IL', 45398),
#  ('Knox', 'IL', 56070),
#  ('La Salle', 'IL', 109955),
#  ('Lake', 'IL', 572431),
#  ('Lawrence', 'IL', 15918),
#  ('Lee', 'IL', 35798),
#  ('Livingston', 'IL', 40404),
#  ('Logan', 'IL', 31267),
#  ('Macon', 'IL', 116414),
#  ('Macoupin', 'IL', 48729),
#  ('Madison', 'IL', 256458),
#  ('Marion', 'IL', 41997),
#  ('Marshall', 'IL', 12791),
#  ('Mason', 'IL', 16691),
#  ('Massac', 'IL', 15370),
#  ('McDonough', 'IL', 35519),
#  ('McHenry', 'IL', 224677),
#  ('McLean', 'IL', 139274),
#  ('Menard', 'IL', 12284),
#  ('Mercer', 'IL', 17444),
#  ('Monroe', 'IL', 24719),
#  ('Montgomery', 'IL', 30994),
#  ('Morgan', 'IL', 36171),
#  ('Moultrie', 'IL', 14168),
#  ('Ogle', 'IL', 49406),
#  ('Peoria', 'IL', 183377),
#  ('Perry', 'IL', 21295),
#  ('Piatt', 'IL', 16158),
#  ('Pike', 'IL', 17338),
#  ('Pope', 'IL', 4691),
#  ('Pulaski', 'IL', 7464),
#  ('Putnam', 'IL', 5718),
#  ('Randolph', 'IL', 34296),
#  ('Richland', 'IL', 16788),
#  ('Rock Island', 'IL', 149830),
#  ('Saline', 'IL', 26521),
#  ('Sangamon', 'IL', 184731),
#  ('Schuyler', 'IL', 7798),
#  ('Scott', 'IL', 5629),
#  ('Shelby', 'IL', 22561),
#  ('St. Clair', 'IL', 265424),
#  ('Stark', 'IL', 6396),
#  ('Stephenson', 'IL', 48844),
#  ('Tazewell', 'IL', 127602),
#  ('Union', 'IL', 18114),
#  ('Vermilion', 'IL', 86541),
#  ('Wabash', 'IL', 12929),
#  ('Warren', 'IL', 18816),
#  ('Washington', 'IL', 15238),
#  ('Wayne', 'IL', 17208),
#  ('White', 'IL', 15903),
#  ('Whiteside', 'IL', 60352),
#  ('Will', 'IL', 413379),
#  ('Williamson', 'IL', 59750),
#  ('Winnebago', 'IL', 264952),
#  ('Woodford', 'IL', 34576),
#  ('Adams', 'IN', 32311),
#  ('Allen', 'IN', 308503),
#  ('Bartholomew', 'IN', 68065),
#  ('Benton', 'IN', 9703),
#  ('Blackford', 'IN', 14162),
#  ('Boone', 'IN', 41813),
#  ('Brown', 'IN', 15098),
#  ('Carroll', 'IN', 19505),
#  ('Cass', 'IN', 38584),
#  ('Clark', 'IN', 91826),
#  ('Clay', 'IN', 26306),
#  ('Clinton', 'IN', 32594),
#  ('Crawford', 'IN', 10442),
#  ('Daviess', 'IN', 28603),
#  ('De Kalb', 'IN', 37955),
#  ('Dearborn', 'IN', 44367),
#  ('Decatur', 'IN', 24998),
#  ('Delaware', 'IN', 118577),
#  ('Dubois', 'IN', 38732),
#  ('Elkhart', 'IN', 166994),
#  ('Fayette', 'IN', 26430),
#  ('Floyd', 'IN', 70058),
#  ('Fountain', 'IN', 18060),
#  ('Franklin', 'IN', 20957),
#  ('Fulton', 'IN', 19922),
#  ('Gibson', 'IN', 32165),
#  ('Grant', 'IN', 73720),
#  ('Greene', 'IN', 32696),
#  ('Hamilton', 'IN', 140650),
#  ('Hancock', 'IN', 50768),
#  ('Harrison', 'IN', 32594),
#  ('Hendricks', 'IN', 86620),
#  ('Henry', 'IN', 49275),
#  ('Howard', 'IN', 83763),
#  ('Huntington', 'IN', 36807),
#  ('Jackson', 'IN', 40403),
#  ('Jasper', 'IN', 27895),
#  ('Jay', 'IN', 21901),
#  ('Jefferson', 'IN', 30813),
#  ('Jennings', 'IN', 26168),
#  ('Johnson', 'IN', 101690),
#  ('Knox', 'IN', 40194),
#  ('Kosciusko', 'IN', 69210),
#  ('La Porte', 'IN', 110384),
#  ('Lagrange', 'IN', 31653),
#  ('Lake', 'IN', 482672),
#  ('Lawrence', 'IN', 45097),
#  ('Madison', 'IN', 132796),
#  ('Marion', 'IN', 817604),
#  ('Marshall', 'IN', 44879),
#  ('Martin', 'IN', 10545),
#  ('Miami', 'IN', 32611),
#  ('Monroe', 'IN', 115208),
#  ('Montgomery', 'IN', 36090),
#  ('Morgan', 'IN', 62115),
#  ('Newton', 'IN', 14413),
#  ('Noble', 'IN', 40884),
#  ('Ohio', 'IN', 5395),
#  ('Orange', 'IN', 19011),
#  ('Owen', 'IN', 19663),
#  ('Parke', 'IN', 16094),
#  ('Perry', 'IN', 19129),
#  ('Pike', 'IN', 12610),
#  ('Porter', 'IN', 140487),
#  ('Posey', 'IN', 26493),
#  ('Pulaski', 'IN', 12960),
#  ('Putnam', 'IN', 32939),
#  ('Randolph', 'IN', 27377),
#  ('Ripley', 'IN', 26829),
#  ('Rush', 'IN', 18456),
#  ('Scott', 'IN', 22568),
#  ('Shelby', 'IN', 42809),
#  ('Spencer', 'IN', 20374),
#  ('St. Joseph', 'IN', 258083),
#  ('Starke', 'IN', 22620),
#  ('Steuben', 'IN', 30060),
#  ('Sullivan', 'IN', 19879),
#  ('Switzerland', 'IN', 8222),
#  ('Tippecanoe', 'IN', 135285),
#  ('Tipton', 'IN', 16463),
#  ('Union', 'IN', 7292),
#  ('Vanderburgh', 'IN', 168065),
#  ('Vermillion', 'IN', 16841),
#  ('Vigo', 'IN', 106622),
#  ('Wabash', 'IN', 34896),
#  ('Warren', 'IN', 8394),
#  ('Warrick', 'IN', 49380),
#  ('Washington', 'IN', 26088),
#  ('Wayne', 'IN', 72802),
#  ('Wells', 'IN', 26506),
#  ('White', 'IN', 24505),
#  ('Whitley', 'IN', 29426),
#  ('Allen', 'KS', 14739),
#  ('Anderson', 'KS', 8000),
#  ('Atchison', 'KS', 16258),
#  ('Barber', 'KS', 5603),
#  ('Barton', 'KS', 28614),
#  ('Bourbon', 'KS', 15013),
#  ('Brown', 'KS', 11075),
#  ('Butler', 'KS', 57746),
#  ('Chase', 'KS', 2885),
#  ('Chautauqua', 'KS', 4439),
#  ('Cherokee', 'KS', 22437),
#  ('Cheyenne', 'KS', 3230),
#  ('Clark', 'KS', 2379),
#  ('Clay', 'KS', 9317),
#  ('Cloud', 'KS', 10488),
#  ('Coffey', 'KS', 8691),
#  ('Comanche', 'KS', 2099),
#  ('Cowley', 'KS', 37107),
#  ('Crawford', 'KS', 36488),
#  ('Decatur', 'KS', 3547),
#  ('Dickinson', 'KS', 19911),
#  ('Doniphan', 'KS', 7608),
#  ('Douglas', 'KS', 88206),
#  ('Edwards', 'KS', 3564),
#  ('Elk', 'KS', 3356),
#  ('Ellis', 'KS', 26145),
#  ('Ellsworth', 'KS', 6445),
#  ('Finney', 'KS', 34913),
#  ('Ford', 'KS', 28909),
#  ('Franklin', 'KS', 23164),
#  ('Geary', 'KS', 29638),
#  ('Gove', 'KS', 3091),
#  ('Graham', 'KS', 3336),
#  ('Grant', 'KS', 7837),
#  ('Gray', 'KS', 5367),
#  ('Greeley', 'KS', 1834),
#  ('Greenwood', 'KS', 8032),
#  ('Hamilton', 'KS', 2343),
#  ('Harper', 'KS', 6651),
#  ('Harvey', 'KS', 31145),
#  ('Haskell', 'KS', 4027),
#  ('Hodgeman', 'KS', 2268),
#  ('Jackson', 'KS', 11809),
#  ('Jefferson', 'KS', 17133),
#  ('Jewell', 'KS', 3952),
#  ('Johnson', 'KS', 401054),
#  ('Kearny', 'KS', 4182),
#  ('Kingman', 'KS', 8566),
#  ('Kiowa', 'KS', 3605),
#  ('Labette', 'KS', 22862),
#  ('Lane', 'KS', 2275),
#  ('Leavenworth', 'KS', 69323),
#  ('Lincoln', 'KS', 3431),
#  ('Linn', 'KS', 8698),
#  ('Logan', 'KS', 3178),
#  ('Lyon', 'KS', 34650),
#  ('Marion', 'KS', 12961),
#  ('Marshall', 'KS', 11261),
#  ('McPherson', 'KS', 27267),
#  ('Meade', 'KS', 4355),
#  ('Miami', 'KS', 25187),
#  ('Mitchell', 'KS', 7092),
#  ('Montgomery', 'KS', 37694),
#  ('Morris', 'KS', 6327),
#  ('Morton', 'KS', 3303),
#  ('Nemaha', 'KS', 10443),
#  ('Neosho', 'KS', 16994),
#  ('Ness', 'KS', 3752),
#  ('Norton', 'KS', 5735),
#  ('Osage', 'KS', 16729),
#  ('Osborne', 'KS', 4696),
#  ('Ottawa', 'KS', 5749),
#  ('Pawnee', 'KS', 7615),
#  ('Phillips', 'KS', 6270),
#  ('Pottawatomie', 'KS', 17548),
#  ('Pratt', 'KS', 9696),
#  ('Rawlins', 'KS', 3234),
#  ('Reno', 'KS', 63263),
#  ('Republic', 'KS', 6215),
#  ('Rice', 'KS', 10086),
#  ('Riley', 'KS', 69784),
#  ('Rooks', 'KS', 5884),
#  ('Rush', 'KS', 3541),
#  ('Russell', 'KS', 7701),
#  ('Saline', 'KS', 51831),
#  ('Scott', 'KS', 5074),
#  ('Sedgwick', 'KS', 419333),
#  ('Seward', 'KS', 19370),
#  ('Shawnee', 'KS', 165062),
#  ('Sheridan', 'KS', 2824),
#  ('Sherman', 'KS', 6706),
#  ('Smith', 'KS', 4782),
#  ('Stafford', 'KS', 5193),
#  ('Stanton', 'KS', 2331),
#  ('Stevens', 'KS', 5257),
#  ('Sumner', 'KS', 26519),
#  ('Thomas', 'KS', 8331),
#  ('Trego', 'KS', 3449),
#  ('Wabaunsee', 'KS', 6603),
#  ('Wallace', 'KS', 1798),
#  ('Washington', 'KS', 6833),
#  ('Wichita', 'KS', 2841),
#  ('Wilson', 'KS', 10321),
#  ('Woodson', 'KS', 3999),
#  ('Wyandotte', 'KS', 153826),
#  ('Adair', 'KY', 16292),
#  ('Allen', 'KY', 15706),
#  ('Anderson', 'KY', 17152),
#  ('Ballard', 'KY', 8232),
#  ('Barren', 'KY', 35768),
#  ('Bath', 'KY', 10159),
#  ('Bell', 'KY', 30490),
#  ('Boone', 'KY', 70097),
#  ('Bourbon', 'KY', 19257),
#  ('Boyd', 'KY', 50613),
#  ('Boyle', 'KY', 26699),
#  ('Bracken', 'KY', 8209),
#  ('Breathitt', 'KY', 15539),
#  ...]

# %% [markdown]
# ### Exercise
# average VA county size?

# %%
# What transforms to use? And in what order?

# filter, map, reduce

numpy.mean([p for (c,s,p) in dt3 if s == 'VA'])
# Out:
# 48664.39705882353
